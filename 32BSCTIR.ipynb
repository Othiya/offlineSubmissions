# %% [markdown]
# # Setup

# %% [markdown]
# ## Make both T4 GPUs visiable to CUDA

# %%
import os, math, numpy as np
os.environ["CUDA_VISIBLE_DEVICES"]="0,1"

# %% [markdown]
# ## Install vLLM

# %%
# %%time
# !pip uninstall -y torch
# !pip install -U --no-index --find-links=/kaggle/input/vllm-whl -U vllm
# !pip install -U --upgrade /kaggle/input/vllm-t4-fix/grpcio-1.62.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# !pip install -U --upgrade /kaggle/input/vllm-t4-fix/ray-2.11.0-cp310-cp310-manylinux2014_x86_64.whl
# Out:
# Found existing installation: torch 2.4.0
# Uninstalling torch-2.4.0:
#   Successfully uninstalled torch-2.4.0
# Looking in links: /kaggle/input/vllm-whl
# Processing /kaggle/input/vllm-whl/vllm-0.4.0.post1-cp310-cp310-manylinux1_x86_64.whl
# Processing /kaggle/input/vllm-whl/cmake-3.29.0.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from vllm)
# Requirement already satisfied: ninja in /opt/conda/lib/python3.10/site-packages (from vllm) (1.11.1.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from vllm) (5.9.3)
# Requirement already satisfied: ray>=2.9 in /opt/conda/lib/python3.10/site-packages (from vllm) (2.24.0)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from vllm) (0.2.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from vllm) (1.26.4)
# Processing /kaggle/input/vllm-whl/torch-2.1.2-cp310-cp310-manylinux1_x86_64.whl (from vllm)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from vllm) (2.32.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from vllm) (9.0.0)
# Requirement already satisfied: transformers>=4.39.1 in /opt/conda/lib/python3.10/site-packages (from vllm) (4.45.1)
# Processing /kaggle/input/vllm-whl/xformers-0.0.23.post1-cp310-cp310-manylinux2014_x86_64.whl (from vllm)
# Requirement already satisfied: fastapi in /opt/conda/lib/python3.10/site-packages (from vllm) (0.111.0)
# Requirement already satisfied: uvicorn[standard] in /opt/conda/lib/python3.10/site-packages (from vllm) (0.30.1)
# Requirement already satisfied: pydantic>=2.0 in /opt/conda/lib/python3.10/site-packages (from vllm) (2.9.2)
# Requirement already satisfied: prometheus-client>=0.18.0 in /opt/conda/lib/python3.10/site-packages (from vllm) (0.20.0)
# Processing /kaggle/input/vllm-whl/pynvml-11.5.0-py3-none-any.whl (from vllm)
# Processing /kaggle/input/vllm-whl/triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from vllm)
# Processing /kaggle/input/vllm-whl/outlines-0.0.34-py3-none-any.whl (from vllm)
# Processing /kaggle/input/vllm-whl/tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from vllm)
# Processing /kaggle/input/vllm-whl/interegular-0.3.3-py37-none-any.whl (from outlines==0.0.34->vllm)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from outlines==0.0.34->vllm) (3.1.4)
# Processing /kaggle/input/vllm-whl/lark-1.1.9-py3-none-any.whl (from outlines==0.0.34->vllm)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from outlines==0.0.34->vllm) (1.6.0)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.10/site-packages (from outlines==0.0.34->vllm) (3.0.0)
# Processing /kaggle/input/vllm-whl/diskcache-5.6.3-py3-none-any.whl (from outlines==0.0.34->vllm)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from outlines==0.0.34->vllm) (1.14.1)
# Requirement already satisfied: numba in /opt/conda/lib/python3.10/site-packages (from outlines==0.0.34->vllm) (0.60.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from outlines==0.0.34->vllm) (1.4.2)
# Requirement already satisfied: referencing in /opt/conda/lib/python3.10/site-packages (from outlines==0.0.34->vllm) (0.35.1)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.10/site-packages (from outlines==0.0.34->vllm) (4.22.0)
# Requirement already satisfied: regex>=2022.1.18 in /opt/conda/lib/python3.10/site-packages (from tiktoken==0.6.0->vllm) (2024.5.15)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->vllm) (3.15.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->vllm) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->vllm) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->vllm) (3.3)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->vllm) (2024.6.1)
# Processing /kaggle/input/vllm-whl/nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.2->vllm)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2.0->vllm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2.0->vllm) (2.23.4)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from ray>=2.9->vllm) (8.1.7)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ray>=2.9->vllm) (1.0.8)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ray>=2.9->vllm) (21.3)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /opt/conda/lib/python3.10/site-packages (from ray>=2.9->vllm) (3.20.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from ray>=2.9->vllm) (6.0.2)
# Requirement already satisfied: aiosignal in /opt/conda/lib/python3.10/site-packages (from ray>=2.9->vllm) (1.3.1)
# Requirement already satisfied: frozenlist in /opt/conda/lib/python3.10/site-packages (from ray>=2.9->vllm) (1.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->vllm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->vllm) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->vllm) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->vllm) (2024.8.30)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.39.1->vllm) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.39.1->vllm) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.39.1->vllm) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.39.1->vllm) (4.66.4)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /opt/conda/lib/python3.10/site-packages (from fastapi->vllm) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /opt/conda/lib/python3.10/site-packages (from fastapi->vllm) (0.0.4)
# Requirement already satisfied: httpx>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from fastapi->vllm) (0.27.0)
# Requirement already satisfied: python-multipart>=0.0.7 in /opt/conda/lib/python3.10/site-packages (from fastapi->vllm) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from fastapi->vllm) (5.10.0)
# Requirement already satisfied: orjson>=3.2.1 in /opt/conda/lib/python3.10/site-packages (from fastapi->vllm) (3.10.4)
# Requirement already satisfied: email_validator>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from fastapi->vllm) (2.1.1)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]->vllm) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]->vllm) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]->vllm) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]->vllm) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]->vllm) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]->vllm) (12.0)
# Requirement already satisfied: dnspython>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from email_validator>=2.0.0->fastapi->vllm) (2.6.1)
# Requirement already satisfied: typer>=0.12.3 in /opt/conda/lib/python3.10/site-packages (from fastapi-cli>=0.0.2->fastapi->vllm) (0.12.3)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx>=0.23.0->fastapi->vllm) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx>=0.23.0->fastapi->vllm) (1.0.5)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx>=0.23.0->fastapi->vllm) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->outlines==0.0.34->vllm) (2.1.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->ray>=2.9->vllm) (3.1.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema->outlines==0.0.34->vllm) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema->outlines==0.0.34->vllm) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema->outlines==0.0.34->vllm) (0.18.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba->outlines==0.0.34->vllm) (0.43.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch==2.1.2->vllm) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio->httpx>=0.23.0->fastapi->vllm) (1.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->vllm) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/conda/lib/python3.10/site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->vllm) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->vllm) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->vllm) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->vllm) (0.1.2)
# Installing collected packages: triton, pynvml, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lark, interegular, diskcache, cmake, tiktoken, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, xformers, outlines, vllm
#   Attempting uninstall: pynvml
#     Found existing installation: pynvml 11.4.1
#     Uninstalling pynvml-11.4.1:
#       Successfully uninstalled pynvml-11.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ucxx 0.39.1 requires libucx>=1.15.0, which is not installed.
# dask-cuda 24.8.2 requires pynvml<11.5,>=11.0.0, but you have pynvml 11.5.0 which is incompatible.
# Successfully installed cmake-3.29.0.1 diskcache-5.6.3 interegular-0.3.3 lark-1.1.9 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 outlines-0.0.34 pynvml-11.5.0 tiktoken-0.6.0 torch-2.1.2 triton-2.1.0 vllm-0.4.0.post1 xformers-0.0.23.post1
# Processing /kaggle/input/vllm-t4-fix/grpcio-1.62.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# grpcio is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Processing /kaggle/input/vllm-t4-fix/ray-2.11.0-cp310-cp310-manylinux2014_x86_64.whl
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (8.1.7)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (3.15.1)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (4.22.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (1.0.8)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (21.3)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (3.20.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (6.0.2)
# Requirement already satisfied: aiosignal in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (1.3.1)
# Requirement already satisfied: frozenlist in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (1.4.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (2.32.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray==2.11.0) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray==2.11.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray==2.11.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray==2.11.0) (0.18.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->ray==2.11.0) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.11.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.11.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.11.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.11.0) (2024.8.30)
# Installing collected packages: ray
#   Attempting uninstall: ray
#     Found existing installation: ray 2.24.0
#     Uninstalling ray-2.24.0:
#       Successfully uninstalled ray-2.24.0
# Successfully installed ray-2.11.0
# CPU times: user 1.86 s, sys: 426 ms, total: 2.29 s
# Wall time: 2min 37s

# %% [markdown]
# ## Some Configuration

# %%
# In DEBUG mode, infer only on 5 problems
DEBUG = False
# Number of candidate solutions to generate
K = 20
DEPTH = 4
TEMPERATURE = 0.5
TOP_P = 0.9
BATCH_SIZE = 64

# %% [markdown]
# # Imports

# %%
import vllm
import re
import csv
import torch
import gc
from tqdm import tqdm
import pandas as pd
from queue import Queue, Empty
import os
import re
import signal
import subprocess
import tempfile
from collections import Counter
from contextlib import contextmanager

import threading
from concurrent.futures import ThreadPoolExecutor, as_completed
# Out:
# 2024-10-29 18:21:37,380	INFO util.py:124 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.

# %% [markdown]
# # Python Code Execution Environment

# %%
1
# Out:
# 1

# %% [markdown]
# ## Find Python code blocks within text

# %%
def find_python_blocks(text):
    blocks = re.findall(r"(```python.*?```)", text, re.DOTALL)
    # filter blocks by trying to convert them to float or int
    filtered_blocks = []
    for block in blocks:
        code = block[len("```python"):-len("```")].strip()
        try:
            x = int(code)
        except:
            filtered_blocks.append(code)
            continue
        try:
            x = float(code)
        except:
            filtered_blocks.append(code)
    return filtered_blocks

# %% [markdown]
# ## Class to Execute Python code (adopted from Numina)

# %%
class PythonREPL:
    def __init__(self, timeout=5):
        self.timeout = timeout
    # handles timeout
    @contextmanager
    def time_limit(self, seconds):
        def signal_handler(*_):
            raise TimeoutError(f"Timed out after {seconds} seconds.")

        signal.signal(signal.SIGALRM, signal_handler)
        signal.alarm(seconds)
        try:
            yield
        finally:
            signal.alarm(0)

    def __call__(self, query):
        query = "import math\nimport numpy as np\nimport sympy as sp\n" + query
        query = query.strip().split("\n")
        if "print(" not in query[-1]:
            if "#" in query[-1]:
                query[-1] = query[-1].split("#")[0]
            query[-1] = "print(" + query[-1] + ")"
        query = "\n".join(query)
        with tempfile.TemporaryDirectory() as temp_dir:
            temp_file_path = os.path.join(temp_dir, "tmp.py")
            with open(temp_file_path, "w", encoding="utf-8") as f:
                f.write(query)
            with self.time_limit(self.timeout):
                result = subprocess.run(
                    ["python3", temp_file_path],
                    capture_output=True,
                    check=False,
                    text=True,
                    timeout=self.timeout,
                )
                if result.returncode == 0:
                    output = result.stdout
                    return True, output.strip()
                error_msg = result.stderr.strip()
                msgs = error_msg.split("\n")
                new_msgs = []
                want_next = False
                for m in msgs:
                    if "Traceback" in m:
                        new_msgs.append(m)
                    elif m == msgs[-1]:
                        new_msgs.append(m)
                    elif temp_file_path in m:
                        st = m.index('"/') + 1 if '"/' in m else 0
                        ed = m.index(temp_file_path) + 1 if temp_file_path in m else None
                        clr = m[st:ed] if not ed else m[st:]
                        m = m.replace(clr, "")
                        new_msgs.append(m)
                        want_next = True
                    elif want_next:
                        new_msgs.append(m)
                        want_next = False
                error_msg = "\n".join(new_msgs)
                return False, error_msg.strip()

# %% [markdown]
# ## Execute a Python code block

# %%
def execute(executor, code):
    success = False
    for lib in ("subprocess", "venv"):
        if lib in code:
            output = f"{lib} is not allowed"
            outputs.append(output)
            successes.append(success)
            continue
    try:
        success, output = executor(code)
    except TimeoutError as e:
        output = str(e)

    output = output.strip()
    
    return output, success

# %% [markdown]
# ## Test by running some python code

# %%
text = """Block 1
```python
s = 0
for i in range(100):
    s += i
print(s)
```
Block 2
```python
2**12
```
Block 3
```python
3
```
"""

# %%
blocks = find_python_blocks(text)
blocks
# Out:
# ['s = 0\nfor i in range(100):\n    s += i\nprint(s)', '2**12']

# %%
executor = PythonREPL()
outputs = [execute(executor, block) for block in blocks]
outputs
# Out:
# [('4950', True), ('4096', True)]

# %%
# for block, output in zip(blocks, outputs):
#     print(f"""
# ```python
# {block}
# ```
# ```output
# {output[0]}
# ```"""
#     )

# %% [markdown]
# # Load Model on vLLM

# %% [markdown]
# ## We use the Qwen 2.5 7b Instruct Model here by Alibaba. You should explore other models.

# %%
llm = vllm.LLM(
    "Qwen/Qwen2.5-32B-Instruct-AWQ",
    tensor_parallel_size=2, 
    gpu_memory_utilization=0.95, 
    trust_remote_code=True,
    dtype="half", 
    enforce_eager=True,
    max_model_len=4096,
)
tokenizer = llm.get_tokenizer()
# Out:
# config.json:   0%|          | 0.00/841 [00:00<?, ?B/s]
# WARNING 10-29 18:21:41 config.py:211] awq quantization is not fully optimized yet. The speed can be slower than non-quantized models.
# 2024-10-29 18:21:44,382	INFO worker.py:1749 -- Started a local Ray instance.
# INFO 10-29 18:21:46 llm_engine.py:74] Initializing an LLM engine (v0.4.0.post1) with config: model='Qwen/Qwen2.5-32B-Instruct-AWQ', tokenizer='Qwen/Qwen2.5-32B-Instruct-AWQ', tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.float16, max_seq_len=4096, download_dir=None, load_format=auto, tensor_parallel_size=2, disable_custom_all_reduce=True, quantization=awq, enforce_eager=True, kv_cache_dtype=auto, device_config=cuda, seed=0)
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# INFO 10-29 18:22:00 selector.py:40] Cannot use FlashAttention backend for Volta and Turing GPUs.
# INFO 10-29 18:22:00 selector.py:25] Using XFormers backend.
# (RayWorkerVllm pid=374) INFO 10-29 18:22:01 selector.py:40] Cannot use FlashAttention backend for Volta and Turing GPUs.
# (RayWorkerVllm pid=374) INFO 10-29 18:22:01 selector.py:25] Using XFormers backend.
# INFO 10-29 18:22:02 pynccl_utils.py:45] vLLM is using nccl==2.18.1
# (RayWorkerVllm pid=374) INFO 10-29 18:22:01 pynccl_utils.py:45] vLLM is using nccl==2.18.1
# INFO 10-29 18:22:03 weight_utils.py:177] Using model weights format ['*.safetensors']
# (RayWorkerVllm pid=374) INFO 10-29 18:22:03 weight_utils.py:177] Using model weights format ['*.safetensors']
# model-00002-of-00005.safetensors:   0%|          | 0.00/3.98G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/3.48G [00:00<?, ?B/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/3.94G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/3.95G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/3.98G [00:00<?, ?B/s]
# INFO 10-29 18:24:34 model_runner.py:104] Loading model weights took 9.0933 GB
# (RayWorkerVllm pid=374) INFO 10-29 18:24:34 model_runner.py:104] Loading model weights took 9.0933 GB
# INFO 10-29 18:24:42 ray_gpu_executor.py:240] # GPU blocks: 1232, # CPU blocks: 2048

# %% [markdown]
# # Utilites

# %% [markdown]
# ## Extract boxed answer

# %%
def extract_answer(text):
    # find right most boxed answer
    def last_boxed_only_string(text):
        idx = text.rfind("\\boxed")
        if idx < 0:
            idx = text.rfind("\\fbox")
            if idx < 0:
                return None
        i = idx
        right_brace_idx = None
        num_left_braces_open = 0
        while i < len(text):
            if text[i] == "{":
                num_left_braces_open += 1
            if text[i] == "}":
                num_left_braces_open -= 1
                if num_left_braces_open == 0:
                    right_brace_idx = i
                    break
            i += 1
        if right_brace_idx is None:
            return None
        return text[idx : right_brace_idx + 1]
    # get content of boxed
    def remove_boxed(boxed):
        left = "\\boxed{"
        try:
            assert boxed[: len(left)] == left
            assert boxed[-1] == "}"
            length = len(left)
            return boxed[length:-1]
        except Exception:
            return None

    boxed = last_boxed_only_string(text)
    if boxed is None:
        return None
    answer = remove_boxed(boxed)
    return answer

# %% [markdown]
# ## Majority vote (select the most occuring answer)

# %%
# Define the majority voting function to get the most common answer
def majority_vote(answers):
    answers = [answer for answer in answers if answer is not None]

    if not answers:
        return None
    # count the occurence of each answer
    counts = {}
    for answer in answers:
        if answer in counts:
            counts[answer] += 1
        else:
            counts[answer] = 1

    max_answer = None
    max_count = 0
    
    for answer, count in counts.items():
        if count > max_count:
            max_answer = answer
            max_count = count
    
    return max_answer

# %% [markdown]
# # TIR Agent

# %%
# class TIRAgent:
#     def __init__(self, problem_id, id, problem, tokenizer, max_depth, log):
#         # problem id
#         self.problem_id = problem_id
#         # id of the agent
#         self.id = id
#         # number of LLM turns
#         self.depth = 1
#         # maximum number of turns allowed
#         self.max_depth = max_depth
#         # LLM's tokenizer
#         self.tokenizer = tokenizer
#         # Problem statement
#         self.problem = problem
#         # Chat Messages
#         self.messages = [
#             {
#                "role": "user", 
#                 "content": f"""Here is a math problem:
# {self.problem}
# Please solve the problem step by step, providing Python code at each step to verify your reasoning.
# Break your reasoning into:
# 1. Problem understanding.
# 2. Step-by-step logical breakdown.
# 3. Python code to verify.
# Finally, provide the non-negative integer answer within \\boxed{{}}."""
#             }
#         ]
#         # Last response from the LLM
#         self.last_response = None
#         # Code blocks from the last response
#         self.blocks = []
#         # Answers that the LLM generated in \boxed{}
#         self.answers = []
#         # No python code generated in last response or max_depth reached
#         self.is_complete = False
#         # File to log answers
#         self.log = log
#         # Next prompt to the LLM
#         self.next_prompt = None
        
#     def complete(self):
#         # Is the Agent done
#         return self.is_complete
    
#     def add_response(self, response, executor):
#         self.depth += 1
#         # Remember this response
#         self.last_response = response
#         # Add this to the messages history
#         self.messages.append({"role": "assistant", "content": response})
#         # Extract python blocks
#         self.blocks = find_python_blocks(response)
#         # Extract answer from the generated text, if present
#         answer = extract_answer(response)
#         if answer is not None:
#             self.answers.append(answer)
#         # Is it done?
#         self.is_complete = not self._should_continue()
#         # If not, use the python executor to create next prompt
#         if not self.is_complete:
#             self.next_prompt = self._next_prompt(executor)   
#             self.messages.append({"role": "user", "content": self.next_prompt})
    
#     def _should_continue(self):        
#         # Quit if max_depth number of turns reached
#         if self.depth >= self.max_depth:
#             return False
#         # If python code is generated, we can continue
#         elif len(self.blocks) > 0:
#             return True
#         return False
    
#     def _next_prompt(self, executor):
#         assert not self.is_complete
#         assert len(self.blocks) > 0
#         # Get code result from python execution
#         output, status = execute(executor, self.blocks[-1])
        
#         prompt = ''
#         # If code succeeds, give the output
#         if status:
#             prompt = f"""The Python code you provided executed successfully with the following output:
# ```python
# {self.blocks[-1]}

# ```
# ```output
# {output}
# ```"""
#         # if code fails, give the error
#         else:
#             prompt = f"""The python code you provided gives the following error:
# ```python
# {self.blocks[-1]}
# ```
# ```output
# {output}
# Please review the code, correct any mistakes, and provide a new solution with updated logic and code.
# ```"""
#         if self.depth == self.max_depth - 1:
#             prompt += f"\nSince we are nearing the limit of {self.max_depth} attempts, please finalize your response and double-check all steps."
#         return prompt
    
    
#     def next_message(self):
#         assert not self.is_complete 
#         # apply chat template to get the text
#         text = self.tokenizer.apply_chat_template(
#             self.messages,
#             tokenize=False,
#             add_generation_prompt=True
#         )
        
#         return text
        
    
#     def final_answer(self):
#         # if there no answers yet, we have to return None
#         ans = None
#         # otherwise return the latest answer
#         if len(self.answers) > 0:
#             ans = self.answers[-1]
#         # log to file
#         if self.log:
#             self.log.writerow([self.problem_id, self.id, ans])
#         # try to convert to integer
#         try:
#             ans = int(ans)
#         except:
#             ans = None
        
#         return ans

# %%
class TIRAgent:
    def __init__(self, problem_id, id, problem, tokenizer,max_depth, log):
        # problem id
        self.problem_id = problem_id
        # id of the agent
        self.id = id
        # number of LLM turns
        self.depth = 1
        # maximum number of turns allowed
        self.max_depth = max_depth
        # LLM's tokenizer
        self.tokenizer = tokenizer
        # Problem statement
        self.problem = problem
        # Chat Messages
        self.messages = [
            {
               "role": "user", 
                "content": f"""Here is a math problem in Bengali:
{self.problem}
The answer is a non-negative integer. Please reason step by step to solve the problem above. Provide python code to verify your reasoning.
Put your final integer answer within \\boxed{{}}."""
            }
        ]
        # Last response from the LLM
        self.last_response = None
        # Code blocks from the last response
        self.blocks = []
        # Answers that the LLM generated in \boxed{}
        self.answers = []
        # No python code generated in last response or max_depth reached
        self.is_complete = False
        # File to log answers
        self.log = log
        # Next prompt to the LLM
        self.next_prompt = None
        
    def complete(self):
        # is the Agent done
        return self.is_complete
    
    def add_response(self, response, executor):
        self.depth += 1
        # remember this response
        self.last_response = response
        # add this to the messages history
        self.messages.append({"role": "assistant", "content": response})
        # extract python blocks
        self.blocks = find_python_blocks(response)
        # extract answer from the generated text, if present
        answer = extract_answer(response)
        if answer is not None:
            self.answers.append(answer)
        # is it done?
        self.is_complete = not self._should_continue()
        # if not, use the python executor to create next prompt
        if not self.is_complete:
            self.next_prompt = self._next_prompt(executor)   
            self.messages.append({"role": "user", "content": self.next_prompt})
    
    def _should_continue(self):        
        # quit if max_depth number of turns reached
        if self.depth >= self.max_depth:
            return False
        # if no python code generated, we can stop now
        elif len(self.blocks) > 0:
            return True
        return False
    
    def _next_prompt(self, executor):
        assert not self.is_complete
        assert len(self.blocks) > 0
        # get code result from python execution
        output, status = execute(executor, self.blocks[-1])
        
        prompt = ''
        # if code succeeds give the output
        if status:
            prompt = f"""The python code you provided gives the following output:
```python
{self.blocks[-1]}
```
```output
{output}
```"""
        # if code fails, give the error
        else:
            prompt = f"""The python code you provided gives the following error:
```python
{self.blocks[-1]}
```
```output
{output}
```"""
        return prompt
    
    
    def next_message(self):
        assert not self.is_complete 
        # apply chat template to get the text
        text = self.tokenizer.apply_chat_template(
            self.messages,
            tokenize=False,
            add_generation_prompt=True
        )
        
        return text
        
    
    def final_answer(self):
        # if there no answers yet, we have to return None
        ans = None
        # otherwise return the latest answer
        if len(self.answers) > 0:
            ans = self.answers[-1]
        # log to file
        if self.log:
            self.log.writerow([self.problem_id, self.id, ans])
        # try to convert to integer
        try:
            ans = int(ans)
        except:
            ans = None
        
        return ans

# %% [markdown]
# # Sc-TIR Agent

# %%
class SCTIRAgent:
    def __init__(self, problem_id, problem, tokenizer,samples, max_depth, log):
        # problem id
        self.problem_id = problem_id
        # problem statement
        self.problem = problem
        # LLM's tokenizer
        self.tokenizer = tokenizer
        # number of TIRAgents to create
        self.samples = samples
        # maximum number of turns
        self.max_depth = max_depth
        # TIR Agents
        self.agents = [TIRAgent(problem_id, i, problem, tokenizer, max_depth, log) for i in range(samples)]
        # log file
        self.log = log
    
    def complete(self):
        # only complete when all agents are done
        for agent in self.agents:
            if not agent.complete():
                return False
        return True
        
    def get_ready_agents(self):
        # return agents that are not complete yet
        ready_agents = []
        for agent in self.agents:
            if not agent.complete():
                ready_agents.append(agent)
        return ready_agents
    
    def final_answer(self):
        # majority vote agent answers
        assert self.complete()
        answers = [agent.final_answer() for agent in self.agents]
        answer = majority_vote(answers)
        if answer is None:
            return 0
        return answer

# %% [markdown]
# # Load Test Set

# %%
#test_df = pd.read_csv('/kaggle/input/translated-test-df/translated_test_df.csv')

test_df = pd.read_csv('/kaggle/input/dlsprint3/test.csv')
test_df.sample(5)
# Out:
#     ID                                            Problem
# 26  26  $x$, $y$ এবং $z$ এমন বাস্তব সংখ্যা যেন $(4^x +...
# 86  86  একটি ত্রিভুজের বৃহত্তম কোণ 80° হলে, ক্ষুদ্রতম ...
# 2    2  ধরো $f(x) = x^{67-x^{67-x^{67-\dots}}}$, যেখান...
# 55  55  তোমার কাছে অসীম সংখ্যক 2,3 এবং 4 টাকার নোট রয়ে...
# 75  75  যদি $a = 3$ এবং $r = \frac{1}{3}$ হয়, তাহলে\n\...

# %% [markdown]
# ## Load 5 problems since we are short on time

# %%
# if DEBUG:
#     test_df = test_df[:5]
#     torch.cuda.empty_cache()
#     gc.collect()

# %% [markdown]
# # Configure LLM and Python REPL

# %%
sampling_params = vllm.SamplingParams(max_tokens=2048, temperature=TEMPERATURE, top_p=TOP_P)
executor = PythonREPL()

# %% [markdown]
# # Run the Agents

# %% [markdown]
# ## TIR Agent

# %%
# for row in test_df.values[0:2]:
#     problem_id = row[0]
#     problem = row[1]
    
#     agent = TIRAgent(problem_id, 0, problem, tokenizer, max_depth=4, log=None)
    
#     while not agent.complete():
#         text = agent.next_message()
#         # get response from LLM
#         response = llm.generate([text], sampling_params)
#         # pass in python executor, since response might contain python code
#         agent.add_response(response[0].outputs[0].text, executor)
    
#     for message in agent.messages:
#         print(f"Role: {message['role']}\n")
#         print(f"Content:\n {message['content']}\n")
    
#     answer = agent.final_answer()
#     print(f"Final answer: {answer}")

# %% [markdown]
# ## SC-TIR Agent

# %%
# for row in test_df.values[1:2]:
#     problem_id = row[0]
#     problem = row[1]
    
#     agent = SCTIRAgent(problem_id, problem, tokenizer,samples=6, max_depth=6, log=None)
    
#     while not agent.complete():
#         ready_agents = agent.get_ready_agents()
#         texts = [a.next_message() for a in ready_agents]
#         # get response from LLM
#         responses = llm.generate(texts, sampling_params)
#         # pass response to the agents
#         for i, ready_agent in enumerate(ready_agents):
#             ready_agent.add_response(responses[i].outputs[0].text, executor)
    
#     answer = agent.final_answer()
#     print(f"Problem: {problem}")
#     print(f"Final answer: {answer}")

# %% [markdown]
# # Run Inference

# %% [markdown]
# # Create submission

# %% [markdown]
# ## Also log agent answers

# %%
file = open('qwen32B.csv', 'w', encoding='utf-8')
log_file = open('log.csv', 'w', encoding='utf-8')

submission = csv.writer(file)
log = csv.writer(log_file)

submission.writerow(['ID', 'Answer'])
log.writerow(['ID', "Agent ID", 'Answer'])
# Out:
# 20

# %% [markdown]
# ## Configure LLM sampling parameters and Python REPL

# %% [markdown]
# ## Use a queue to Batch inference

# %%
# %%time

boxed_answers = {}
agents = []

q = Queue()

iterator = iter(tqdm(test_df.values))

while True:
    for agent in agents:
        if agent.complete():
            boxed_answers[agent.problem_id] = agent.final_answer()

    agents[:] = list(filter(lambda a: not a.complete(), agents))

    while q.qsize() < BATCH_SIZE:
        try:
            row = next(iterator)
        except StopIteration:
            break

        id = row[0]
        problem = row[1]

        agent = SCTIRAgent(id, problem, tokenizer, K, DEPTH, log)
        
        agents.append(agent)

        for tir_agent in agent.get_ready_agents():
            q.put_nowait(tir_agent)
            
    if q.empty():
        break
        
    
    ready_agents = []
    texts = []
    for _ in range(BATCH_SIZE):
        try:
            agent = q.get_nowait()
            ready_agents.append(agent)
            texts.append(agent.next_message())
        except:
            break

    
    responses = llm.generate(texts, sampling_params)
    responses = [response.outputs[0].text for response in responses]
    
    for i in range(len(ready_agents)):
        agent = ready_agents[i]
        response = responses[i]
        agent.add_response(response, executor)
        if not agent.complete():
            q.put_nowait(agent)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [02:13<2:19:53, 133.23s/it]
# Processed prompts:   3%|▎         | 2/64 [02:17<59:20, 57.43s/it]
# Processed prompts:   5%|▍         | 3/64 [02:21<33:19, 32.77s/it]
# Processed prompts:   6%|▋         | 4/64 [02:21<20:04, 20.08s/it]
# Processed prompts:   8%|▊         | 5/64 [02:25<14:00, 14.25s/it]
# Processed prompts:   9%|▉         | 6/64 [02:27<09:47, 10.13s/it]
# Processed prompts:  11%|█         | 7/64 [02:31<07:33,  7.96s/it]
# Processed prompts:  12%|█▎        | 8/64 [02:33<05:46,  6.19s/it]
# Processed prompts:  14%|█▍        | 9/64 [02:34<04:02,  4.40s/it]
# Processed prompts:  16%|█▌        | 10/64 [02:37<03:38,  4.04s/it]
# Processed prompts:  17%|█▋        | 11/64 [02:37<02:32,  2.87s/it]
# Processed prompts:  19%|█▉        | 12/64 [02:39<02:19,  2.69s/it]
# Processed prompts:  20%|██        | 13/64 [02:42<02:10,  2.55s/it]
# Processed prompts:  22%|██▏       | 14/64 [02:44<02:02,  2.45s/it]
# Processed prompts:  23%|██▎       | 15/64 [02:46<01:56,  2.37s/it]
# Processed prompts:  27%|██▋       | 17/64 [02:50<01:48,  2.32s/it]
# Processed prompts:  28%|██▊       | 18/64 [02:53<01:48,  2.37s/it]
# Processed prompts:  31%|███▏      | 20/64 [02:57<01:41,  2.31s/it]
# Processed prompts:  33%|███▎      | 21/64 [02:59<01:35,  2.22s/it]
# Processed prompts:  34%|███▍      | 22/64 [03:04<01:53,  2.70s/it]
# Processed prompts:  38%|███▊      | 24/64 [03:08<01:40,  2.52s/it]
# Processed prompts:  39%|███▉      | 25/64 [03:11<01:43,  2.66s/it]
# Processed prompts:  41%|████      | 26/64 [03:14<01:42,  2.71s/it]
# Processed prompts:  42%|████▏     | 27/64 [03:23<02:35,  4.22s/it]
# Processed prompts:  44%|████▍     | 28/64 [03:26<02:24,  4.01s/it]
# Processed prompts:  45%|████▌     | 29/64 [03:31<02:32,  4.36s/it]
# Processed prompts:  47%|████▋     | 30/64 [03:33<02:01,  3.56s/it]
# Processed prompts:  48%|████▊     | 31/64 [03:33<01:29,  2.71s/it]
# Processed prompts:  50%|█████     | 32/64 [03:34<01:04,  2.01s/it]
# Processed prompts:  52%|█████▏    | 33/64 [03:34<00:50,  1.62s/it]
# Processed prompts:  53%|█████▎    | 34/64 [03:38<01:01,  2.06s/it]
# Processed prompts:  55%|█████▍    | 35/64 [03:39<00:55,  1.91s/it]
# Processed prompts:  56%|█████▋    | 36/64 [03:45<01:28,  3.17s/it]
# Processed prompts:  58%|█████▊    | 37/64 [03:46<01:05,  2.42s/it]
# Processed prompts:  59%|█████▉    | 38/64 [03:46<00:47,  1.83s/it]
# Processed prompts:  61%|██████    | 39/64 [03:47<00:33,  1.35s/it]
# Processed prompts:  62%|██████▎   | 40/64 [03:54<01:16,  3.18s/it]
# Processed prompts:  64%|██████▍   | 41/64 [03:55<00:59,  2.60s/it]
# Processed prompts:  66%|██████▌   | 42/64 [03:57<00:49,  2.26s/it]
# Processed prompts:  67%|██████▋   | 43/64 [04:03<01:11,  3.39s/it]
# Processed prompts:  69%|██████▉   | 44/64 [04:06<01:09,  3.48s/it]
# Processed prompts:  70%|███████   | 45/64 [04:13<01:21,  4.27s/it]
# Processed prompts:  72%|███████▏  | 46/64 [04:17<01:15,  4.20s/it]
# Processed prompts:  73%|███████▎  | 47/64 [04:24<01:29,  5.28s/it]
# Processed prompts:  75%|███████▌  | 48/64 [04:31<01:28,  5.54s/it]
# Processed prompts:  77%|███████▋  | 49/64 [04:31<01:00,  4.02s/it]
# Processed prompts:  78%|███████▊  | 50/64 [04:32<00:41,  2.99s/it]
# Processed prompts:  81%|████████▏ | 52/64 [04:32<00:20,  1.74s/it]
# Processed prompts:  83%|████████▎ | 53/64 [04:38<00:28,  2.63s/it]
# Processed prompts:  84%|████████▍ | 54/64 [04:39<00:22,  2.23s/it]
# Processed prompts:  86%|████████▌ | 55/64 [04:43<00:26,  2.89s/it]
# Processed prompts:  88%|████████▊ | 56/64 [04:44<00:17,  2.14s/it]
# Processed prompts:  89%|████████▉ | 57/64 [04:46<00:16,  2.37s/it]
# Processed prompts:  91%|█████████ | 58/64 [04:47<00:11,  1.88s/it]
# Processed prompts:  92%|█████████▏| 59/64 [04:49<00:09,  1.87s/it]
# Processed prompts:  94%|█████████▍| 60/64 [04:52<00:08,  2.20s/it]
# Processed prompts:  95%|█████████▌| 61/64 [04:55<00:06,  2.30s/it]
# Processed prompts:  97%|█████████▋| 62/64 [04:55<00:03,  1.70s/it]
# Processed prompts:  98%|█████████▊| 63/64 [04:55<00:01,  1.29s/it]
# Processed prompts: 100%|██████████| 64/64 [04:56<00:00,  4.63s/it]
#
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:47<50:20, 47.94s/it]
# Processed prompts:   3%|▎         | 2/64 [00:48<20:35, 19.93s/it]
# Processed prompts:   5%|▍         | 3/64 [00:50<12:04, 11.87s/it]
# Processed prompts:   6%|▋         | 4/64 [00:52<08:04,  8.08s/it]
# Processed prompts:   9%|▉         | 6/64 [00:55<04:14,  4.39s/it]
# Processed prompts:  11%|█         | 7/64 [00:58<03:51,  4.07s/it]
# Processed prompts:  14%|█▍        | 9/64 [01:00<02:32,  2.77s/it]
# Processed prompts:  16%|█▌        | 10/64 [01:02<02:23,  2.67s/it]
# Processed prompts:  19%|█▉        | 12/64 [01:04<01:44,  2.01s/it]
# Processed prompts:  22%|██▏       | 14/64 [01:08<01:40,  2.00s/it]
# Processed prompts:  23%|██▎       | 15/64 [01:10<01:33,  1.91s/it]
# Processed prompts:  25%|██▌       | 16/64 [01:14<01:49,  2.28s/it]
# Processed prompts:  27%|██▋       | 17/64 [01:19<02:29,  3.19s/it]
# Processed prompts:  30%|██▉       | 19/64 [01:23<02:00,  2.69s/it]
# Processed prompts:  33%|███▎      | 21/64 [01:27<01:42,  2.39s/it]
# Processed prompts:  34%|███▍      | 22/64 [01:31<01:50,  2.64s/it]
# Processed prompts:  36%|███▌      | 23/64 [01:33<01:47,  2.62s/it]
# Processed prompts:  38%|███▊      | 24/64 [01:38<02:03,  3.08s/it]
# Processed prompts:  39%|███▉      | 25/64 [01:39<01:35,  2.46s/it]
# Processed prompts:  41%|████      | 26/64 [01:43<01:59,  3.14s/it]
# Processed prompts:  44%|████▍     | 28/64 [01:49<01:49,  3.05s/it]
# Processed prompts:  45%|████▌     | 29/64 [01:52<01:45,  3.00s/it]
# Processed prompts:  47%|████▋     | 30/64 [01:56<01:52,  3.32s/it]
# Processed prompts:  48%|████▊     | 31/64 [01:59<01:39,  3.01s/it]
# Processed prompts:  50%|█████     | 32/64 [02:02<01:41,  3.18s/it]
# Processed prompts:  52%|█████▏    | 33/64 [02:05<01:33,  3.02s/it]
# Processed prompts:  53%|█████▎    | 34/64 [02:09<01:42,  3.43s/it]
# Processed prompts:  55%|█████▍    | 35/64 [02:12<01:34,  3.26s/it]
# Processed prompts:  56%|█████▋    | 36/64 [02:14<01:21,  2.90s/it]
# Processed prompts:  59%|█████▉    | 38/64 [02:14<00:42,  1.63s/it]
# Processed prompts:  61%|██████    | 39/64 [02:15<00:34,  1.39s/it]
# Processed prompts:  62%|██████▎   | 40/64 [02:17<00:38,  1.59s/it]
# Processed prompts:  66%|██████▌   | 42/64 [02:18<00:22,  1.00s/it]
# Processed prompts:  67%|██████▋   | 43/64 [02:19<00:21,  1.01s/it]
# Processed prompts:  69%|██████▉   | 44/64 [02:21<00:26,  1.32s/it]
# Processed prompts:  70%|███████   | 45/64 [02:22<00:21,  1.14s/it]
# Processed prompts:  72%|███████▏  | 46/64 [02:25<00:29,  1.64s/it]
# Processed prompts:  73%|███████▎  | 47/64 [02:32<00:56,  3.34s/it]
# Processed prompts:  75%|███████▌  | 48/64 [02:36<00:56,  3.56s/it]
# Processed prompts:  77%|███████▋  | 49/64 [03:04<02:37, 10.49s/it]
# Processed prompts:  78%|███████▊  | 50/64 [03:08<02:02,  8.73s/it]
# Processed prompts:  80%|███████▉  | 51/64 [03:08<01:20,  6.19s/it]
# Processed prompts:  81%|████████▏ | 52/64 [03:14<01:12,  6.01s/it]
# Processed prompts:  83%|████████▎ | 53/64 [03:15<00:50,  4.60s/it]
# Processed prompts:  84%|████████▍ | 54/64 [03:16<00:34,  3.46s/it]
# Processed prompts:  86%|████████▌ | 55/64 [03:17<00:24,  2.68s/it]
# Processed prompts:  88%|████████▊ | 56/64 [03:17<00:15,  1.97s/it]
# Processed prompts:  89%|████████▉ | 57/64 [03:20<00:15,  2.27s/it]
# Processed prompts:  91%|█████████ | 58/64 [03:21<00:10,  1.74s/it]
# Processed prompts:  92%|█████████▏| 59/64 [03:21<00:06,  1.34s/it]
# Processed prompts:  94%|█████████▍| 60/64 [03:24<00:06,  1.73s/it]
# Processed prompts:  95%|█████████▌| 61/64 [03:24<00:03,  1.27s/it]
# Processed prompts:  97%|█████████▋| 62/64 [03:24<00:02,  1.07s/it]
# Processed prompts:  98%|█████████▊| 63/64 [03:28<00:01,  1.68s/it]
# Processed prompts: 100%|██████████| 64/64 [03:31<00:00,  3.30s/it]
#   4%|▍         | 4/100 [09:19<3:43:45, 139.85s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:41<43:32, 41.47s/it]
# Processed prompts:   3%|▎         | 2/64 [00:42<18:09, 17.57s/it]
# Processed prompts:   5%|▍         | 3/64 [00:45<11:12, 11.02s/it]
# Processed prompts:   6%|▋         | 4/64 [00:48<07:42,  7.70s/it]
# Processed prompts:   8%|▊         | 5/64 [00:51<06:03,  6.16s/it]
# Processed prompts:   9%|▉         | 6/64 [00:54<04:54,  5.07s/it]
# Processed prompts:  12%|█▎        | 8/64 [00:57<02:59,  3.20s/it]
# Processed prompts:  14%|█▍        | 9/64 [00:59<02:49,  3.09s/it]
# Processed prompts:  16%|█▌        | 10/64 [01:02<02:42,  3.00s/it]
# Processed prompts:  20%|██        | 13/64 [01:06<01:48,  2.13s/it]
# Processed prompts:  22%|██▏       | 14/64 [01:09<01:49,  2.19s/it]
# Processed prompts:  23%|██▎       | 15/64 [01:12<01:57,  2.40s/it]
# Processed prompts:  27%|██▋       | 17/64 [01:15<01:34,  2.01s/it]
# Processed prompts:  28%|██▊       | 18/64 [01:22<02:27,  3.20s/it]
# Processed prompts:  30%|██▉       | 19/64 [01:23<01:56,  2.59s/it]
# Processed prompts:  31%|███▏      | 20/64 [01:28<02:20,  3.19s/it]
# Processed prompts:  33%|███▎      | 21/64 [01:31<02:14,  3.13s/it]
# Processed prompts:  34%|███▍      | 22/64 [01:34<02:15,  3.22s/it]
# Processed prompts:  36%|███▌      | 23/64 [01:40<02:45,  4.03s/it]
# Processed prompts:  38%|███▊      | 24/64 [01:56<04:55,  7.38s/it]
# Processed prompts:  39%|███▉      | 25/64 [02:23<08:36, 13.26s/it]
# Processed prompts:  41%|████      | 26/64 [02:31<07:23, 11.67s/it]
# Processed prompts:  42%|████▏     | 27/64 [02:32<05:15,  8.52s/it]
# Processed prompts:  44%|████▍     | 28/64 [02:34<03:57,  6.60s/it]
# Processed prompts:  45%|████▌     | 29/64 [02:40<03:43,  6.39s/it]
# Processed prompts:  47%|████▋     | 30/64 [02:45<03:25,  6.04s/it]
# Processed prompts:  48%|████▊     | 31/64 [02:48<02:46,  5.05s/it]
# Processed prompts:  50%|█████     | 32/64 [02:53<02:36,  4.91s/it]
# Processed prompts:  52%|█████▏    | 33/64 [02:57<02:26,  4.74s/it]
# Processed prompts:  53%|█████▎    | 34/64 [03:07<03:09,  6.31s/it]
# Processed prompts:  55%|█████▍    | 35/64 [03:10<02:37,  5.42s/it]
# Processed prompts:  56%|█████▋    | 36/64 [03:14<02:12,  4.73s/it]
# Processed prompts:  58%|█████▊    | 37/64 [03:16<01:52,  4.16s/it]
# Processed prompts:  59%|█████▉    | 38/64 [03:23<02:09,  4.98s/it]
# Processed prompts:  61%|██████    | 39/64 [03:26<01:50,  4.43s/it]
# Processed prompts:  62%|██████▎   | 40/64 [03:32<01:55,  4.82s/it]
# Processed prompts:  64%|██████▍   | 41/64 [03:35<01:34,  4.09s/it]
# Processed prompts:  66%|██████▌   | 42/64 [03:36<01:12,  3.32s/it]
# Processed prompts:  67%|██████▋   | 43/64 [03:37<00:56,  2.70s/it]
# Processed prompts:  69%|██████▉   | 44/64 [03:38<00:41,  2.07s/it]
# Processed prompts:  70%|███████   | 45/64 [03:42<00:51,  2.72s/it]
# Processed prompts:  72%|███████▏  | 46/64 [03:44<00:46,  2.56s/it]
# Processed prompts:  73%|███████▎  | 47/64 [03:47<00:43,  2.56s/it]
# Processed prompts:  75%|███████▌  | 48/64 [04:02<01:39,  6.20s/it]
# Processed prompts:  77%|███████▋  | 49/64 [04:02<01:05,  4.38s/it]
# Processed prompts:  78%|███████▊  | 50/64 [04:02<00:44,  3.17s/it]
# Processed prompts:  80%|███████▉  | 51/64 [04:04<00:38,  2.93s/it]
# Processed prompts:  81%|████████▏ | 52/64 [04:05<00:27,  2.28s/it]
# Processed prompts:  83%|████████▎ | 53/64 [04:08<00:26,  2.45s/it]
# Processed prompts:  84%|████████▍ | 54/64 [04:11<00:26,  2.63s/it]
# Processed prompts:  86%|████████▌ | 55/64 [04:36<01:24,  9.38s/it]
# Processed prompts:  88%|████████▊ | 56/64 [04:39<00:58,  7.33s/it]
# Processed prompts:  89%|████████▉ | 57/64 [04:39<00:36,  5.19s/it]
# Processed prompts:  92%|█████████▏| 59/64 [04:40<00:15,  3.15s/it]
# Processed prompts:  94%|█████████▍| 60/64 [04:41<00:10,  2.53s/it]
# Processed prompts:  95%|█████████▌| 61/64 [04:47<00:10,  3.36s/it]
# Processed prompts:  97%|█████████▋| 62/64 [04:47<00:05,  2.52s/it]
# Processed prompts:  98%|█████████▊| 63/64 [04:48<00:02,  2.10s/it]
# Processed prompts: 100%|██████████| 64/64 [04:48<00:00,  4.51s/it]
#   6%|▌         | 6/100 [14:32<3:49:56, 146.77s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:45<48:07, 45.84s/it]
# Processed prompts:   3%|▎         | 2/64 [00:48<21:05, 20.41s/it]
# Processed prompts:   5%|▍         | 3/64 [00:51<12:36, 12.40s/it]
# Processed prompts:   6%|▋         | 4/64 [00:55<09:09,  9.16s/it]
# Processed prompts:   9%|▉         | 6/64 [00:58<04:56,  5.11s/it]
# Processed prompts:  12%|█▎        | 8/64 [01:02<03:30,  3.77s/it]
# Processed prompts:  14%|█▍        | 9/64 [01:04<03:06,  3.39s/it]
# Processed prompts:  16%|█▌        | 10/64 [01:11<03:43,  4.14s/it]
# Processed prompts:  17%|█▋        | 11/64 [01:12<03:05,  3.50s/it]
# Processed prompts:  19%|█▉        | 12/64 [01:14<02:38,  3.05s/it]
# Processed prompts:  23%|██▎       | 15/64 [01:19<01:50,  2.25s/it]
# Processed prompts:  25%|██▌       | 16/64 [01:19<01:30,  1.88s/it]
# Processed prompts:  27%|██▋       | 17/64 [01:22<01:39,  2.11s/it]
# Processed prompts:  28%|██▊       | 18/64 [01:22<01:15,  1.65s/it]
# Processed prompts:  30%|██▉       | 19/64 [01:25<01:22,  1.84s/it]
# Processed prompts:  31%|███▏      | 20/64 [01:28<01:34,  2.15s/it]
# Processed prompts:  33%|███▎      | 21/64 [01:34<02:14,  3.14s/it]
# Processed prompts:  34%|███▍      | 22/64 [01:36<02:04,  2.96s/it]
# Processed prompts:  36%|███▌      | 23/64 [01:43<02:54,  4.25s/it]
# Processed prompts:  38%|███▊      | 24/64 [01:46<02:35,  3.88s/it]
# Processed prompts:  39%|███▉      | 25/64 [01:52<02:49,  4.34s/it]
# Processed prompts:  41%|████      | 26/64 [01:54<02:20,  3.70s/it]
# Processed prompts:  42%|████▏     | 27/64 [01:59<02:33,  4.15s/it]
# Processed prompts:  44%|████▍     | 28/64 [02:03<02:29,  4.14s/it]
# Processed prompts:  45%|████▌     | 29/64 [02:07<02:22,  4.08s/it]
# Processed prompts:  47%|████▋     | 30/64 [02:14<02:46,  4.89s/it]
# Processed prompts:  48%|████▊     | 31/64 [02:20<02:50,  5.17s/it]
# Processed prompts:  50%|█████     | 32/64 [02:24<02:38,  4.95s/it]
# Processed prompts:  52%|█████▏    | 33/64 [02:53<06:15, 12.12s/it]
# Processed prompts:  53%|█████▎    | 34/64 [03:23<08:43, 17.46s/it]
# Processed prompts:  55%|█████▍    | 35/64 [03:28<06:39, 13.79s/it]
# Processed prompts:  56%|█████▋    | 36/64 [03:37<05:43, 12.28s/it]
# Processed prompts:  58%|█████▊    | 37/64 [03:39<04:08,  9.20s/it]
# Processed prompts:  59%|█████▉    | 38/64 [03:41<03:01,  6.97s/it]
# Processed prompts:  61%|██████    | 39/64 [03:45<02:31,  6.06s/it]
# Processed prompts:  62%|██████▎   | 40/64 [04:02<03:48,  9.52s/it]
# Processed prompts:  64%|██████▍   | 41/64 [04:06<02:57,  7.72s/it]
# Processed prompts:  66%|██████▌   | 42/64 [04:06<02:00,  5.47s/it]
# Processed prompts:  67%|██████▋   | 43/64 [04:09<01:35,  4.53s/it]
# Processed prompts:  69%|██████▉   | 44/64 [04:12<01:22,  4.11s/it]
# Processed prompts:  70%|███████   | 45/64 [04:17<01:27,  4.62s/it]
# Processed prompts:  72%|███████▏  | 46/64 [04:24<01:31,  5.07s/it]
# Processed prompts:  73%|███████▎  | 47/64 [04:40<02:23,  8.42s/it]
# Processed prompts:  75%|███████▌  | 48/64 [04:40<01:37,  6.07s/it]
# Processed prompts:  77%|███████▋  | 49/64 [04:45<01:23,  5.60s/it]
# Processed prompts:  78%|███████▊  | 50/64 [04:45<00:55,  3.95s/it]
# Processed prompts:  80%|███████▉  | 51/64 [04:47<00:43,  3.38s/it]
# Processed prompts:  81%|████████▏ | 52/64 [04:52<00:47,  3.97s/it]
# Processed prompts:  83%|████████▎ | 53/64 [04:53<00:31,  2.85s/it]
# Processed prompts:  84%|████████▍ | 54/64 [04:53<00:20,  2.03s/it]
# Processed prompts:  86%|████████▌ | 55/64 [04:53<00:13,  1.55s/it]
# Processed prompts:  88%|████████▊ | 56/64 [04:58<00:19,  2.46s/it]
# Processed prompts:  89%|████████▉ | 57/64 [05:00<00:17,  2.53s/it]
# Processed prompts:  91%|█████████ | 58/64 [05:01<00:12,  2.07s/it]
# Processed prompts:  92%|█████████▏| 59/64 [05:03<00:09,  1.86s/it]
# Processed prompts:  94%|█████████▍| 60/64 [05:05<00:07,  1.88s/it]
# Processed prompts:  95%|█████████▌| 61/64 [05:12<00:10,  3.62s/it]
# Processed prompts:  97%|█████████▋| 62/64 [05:21<00:10,  5.07s/it]
# Processed prompts:  98%|█████████▊| 63/64 [05:29<00:06,  6.13s/it]
# Processed prompts: 100%|██████████| 64/64 [06:34<00:00,  6.17s/it]
#   7%|▋         | 7/100 [21:25<5:22:12, 207.87s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:47<49:39, 47.30s/it]
# Processed prompts:   3%|▎         | 2/64 [00:48<20:45, 20.09s/it]
# Processed prompts:   5%|▍         | 3/64 [00:51<12:46, 12.57s/it]
# Processed prompts:   6%|▋         | 4/64 [00:55<09:08,  9.14s/it]
# Processed prompts:   9%|▉         | 6/64 [01:00<05:20,  5.53s/it]
# Processed prompts:  12%|█▎        | 8/64 [01:04<03:47,  4.06s/it]
# Processed prompts:  14%|█▍        | 9/64 [01:04<02:53,  3.15s/it]
# Processed prompts:  16%|█▌        | 10/64 [01:08<03:01,  3.36s/it]
# Processed prompts:  17%|█▋        | 11/64 [01:11<02:52,  3.26s/it]
# Processed prompts:  19%|█▉        | 12/64 [01:17<03:15,  3.76s/it]
# Processed prompts:  20%|██        | 13/64 [01:18<02:39,  3.12s/it]
# Processed prompts:  22%|██▏       | 14/64 [01:21<02:36,  3.14s/it]
# Processed prompts:  23%|██▎       | 15/64 [01:24<02:32,  3.11s/it]
# Processed prompts:  25%|██▌       | 16/64 [01:28<02:36,  3.26s/it]
# Processed prompts:  27%|██▋       | 17/64 [01:30<02:23,  3.06s/it]
# Processed prompts:  28%|██▊       | 18/64 [01:34<02:26,  3.19s/it]
# Processed prompts:  30%|██▉       | 19/64 [01:37<02:19,  3.10s/it]
# Processed prompts:  31%|███▏      | 20/64 [01:40<02:16,  3.10s/it]
# Processed prompts:  33%|███▎      | 21/64 [01:45<02:37,  3.67s/it]
# Processed prompts:  34%|███▍      | 22/64 [01:49<02:34,  3.68s/it]
# Processed prompts:  36%|███▌      | 23/64 [02:03<04:37,  6.76s/it]
# Processed prompts:  38%|███▊      | 24/64 [02:11<04:54,  7.37s/it]
# Processed prompts:  39%|███▉      | 25/64 [02:36<08:14, 12.67s/it]
# Processed prompts:  41%|████      | 26/64 [02:58<09:38, 15.22s/it]
# Processed prompts:  42%|████▏     | 27/64 [04:15<20:48, 33.74s/it]
# Processed prompts:  44%|████▍     | 28/64 [04:28<16:34, 27.62s/it]
# Processed prompts:  45%|████▌     | 29/64 [04:35<12:32, 21.50s/it]
# Processed prompts:  47%|████▋     | 30/64 [04:59<12:34, 22.20s/it]
# Processed prompts:  48%|████▊     | 31/64 [05:16<11:19, 20.59s/it]
# Processed prompts:  50%|█████     | 32/64 [05:19<08:11, 15.37s/it]
# Processed prompts:  52%|█████▏    | 33/64 [05:23<06:15, 12.11s/it]
# Processed prompts:  53%|█████▎    | 34/64 [05:27<04:45,  9.53s/it]
# Processed prompts:  55%|█████▍    | 35/64 [05:34<04:15,  8.82s/it]
# Processed prompts:  56%|█████▋    | 36/64 [05:37<03:12,  6.88s/it]
# Processed prompts:  58%|█████▊    | 37/64 [05:42<02:57,  6.56s/it]
# Processed prompts:  59%|█████▉    | 38/64 [05:52<03:15,  7.53s/it]
# Processed prompts:  61%|██████    | 39/64 [05:55<02:31,  6.08s/it]
# Processed prompts:  62%|██████▎   | 40/64 [06:03<02:39,  6.67s/it]
# Processed prompts:  64%|██████▍   | 41/64 [06:06<02:08,  5.60s/it]
# Processed prompts:  66%|██████▌   | 42/64 [06:12<02:03,  5.60s/it]
# Processed prompts:  67%|██████▋   | 43/64 [06:17<01:58,  5.64s/it]
# Processed prompts:  69%|██████▉   | 44/64 [06:17<01:20,  4.01s/it]
# Processed prompts:  70%|███████   | 45/64 [06:21<01:14,  3.92s/it]
# Processed prompts:  72%|███████▏  | 46/64 [06:31<01:42,  5.68s/it]
# Processed prompts:  75%|███████▌  | 48/64 [06:34<01:00,  3.75s/it]
# Processed prompts:  77%|███████▋  | 49/64 [06:36<00:48,  3.25s/it]
# Processed prompts:  78%|███████▊  | 50/64 [06:36<00:35,  2.53s/it]
# Processed prompts:  80%|███████▉  | 51/64 [06:39<00:34,  2.65s/it]
# Processed prompts:  81%|████████▏ | 52/64 [06:40<00:27,  2.26s/it]
# Processed prompts:  83%|████████▎ | 53/64 [06:41<00:19,  1.77s/it]
# Processed prompts:  84%|████████▍ | 54/64 [06:42<00:14,  1.42s/it]
# Processed prompts:  86%|████████▌ | 55/64 [06:47<00:24,  2.75s/it]
# Processed prompts:  88%|████████▊ | 56/64 [06:51<00:24,  3.04s/it]
# Processed prompts:  89%|████████▉ | 57/64 [06:52<00:15,  2.23s/it]
# Processed prompts:  91%|█████████ | 58/64 [07:03<00:30,  5.06s/it]
# Processed prompts:  92%|█████████▏| 59/64 [07:07<00:23,  4.67s/it]
# Processed prompts:  94%|█████████▍| 60/64 [07:09<00:15,  3.98s/it]
# Processed prompts:  95%|█████████▌| 61/64 [07:21<00:18,  6.29s/it]
# Processed prompts:  98%|█████████▊| 63/64 [07:24<00:04,  4.01s/it]
# Processed prompts: 100%|██████████| 64/64 [07:37<00:00,  7.15s/it]
#   9%|▉         | 9/100 [29:26<5:34:51, 220.78s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:43<45:22, 43.22s/it]
# Processed prompts:   3%|▎         | 2/64 [00:44<19:14, 18.62s/it]
# Processed prompts:   5%|▍         | 3/64 [00:48<12:14, 12.04s/it]
# Processed prompts:   6%|▋         | 4/64 [00:58<10:54, 10.92s/it]
# Processed prompts:   8%|▊         | 5/64 [01:05<09:36,  9.77s/it]
# Processed prompts:   9%|▉         | 6/64 [01:25<12:48, 13.25s/it]
# Processed prompts:  11%|█         | 7/64 [01:39<12:52, 13.54s/it]
# Processed prompts:  12%|█▎        | 8/64 [01:45<10:16, 11.01s/it]
# Processed prompts:  14%|█▍        | 9/64 [01:46<07:08,  7.80s/it]
# Processed prompts:  16%|█▌        | 10/64 [01:49<05:53,  6.55s/it]
# Processed prompts:  17%|█▋        | 11/64 [01:50<04:12,  4.76s/it]
# Processed prompts:  19%|█▉        | 12/64 [01:57<04:43,  5.44s/it]
# Processed prompts:  20%|██        | 13/64 [01:58<03:28,  4.08s/it]
# Processed prompts:  22%|██▏       | 14/64 [02:02<03:21,  4.03s/it]
# Processed prompts:  23%|██▎       | 15/64 [02:33<09:51, 12.08s/it]
# Processed prompts:  25%|██▌       | 16/64 [02:48<10:21, 12.96s/it]
# Processed prompts:  27%|██▋       | 17/64 [02:57<09:18, 11.88s/it]
# Processed prompts:  28%|██▊       | 18/64 [03:22<12:12, 15.91s/it]
# Processed prompts:  30%|██▉       | 19/64 [03:32<10:34, 14.09s/it]
# Processed prompts:  31%|███▏      | 20/64 [03:37<08:15, 11.27s/it]
# Processed prompts:  33%|███▎      | 21/64 [03:48<07:54, 11.04s/it]
# Processed prompts:  34%|███▍      | 22/64 [04:02<08:21, 11.94s/it]
# Processed prompts:  36%|███▌      | 23/64 [04:13<07:58, 11.66s/it]
# Processed prompts:  38%|███▊      | 24/64 [04:30<09:00, 13.52s/it]
# Processed prompts:  39%|███▉      | 25/64 [04:38<07:33, 11.62s/it]
# Processed prompts:  41%|████      | 26/64 [04:48<07:04, 11.18s/it]
# Processed prompts:  42%|████▏     | 27/64 [04:50<05:14,  8.50s/it]
# Processed prompts:  44%|████▍     | 28/64 [04:52<03:59,  6.65s/it]
# Processed prompts:  45%|████▌     | 29/64 [04:55<03:11,  5.47s/it]
# Processed prompts:  47%|████▋     | 30/64 [04:59<02:47,  4.94s/it]
# Processed prompts:  48%|████▊     | 31/64 [05:01<02:13,  4.04s/it]
# Processed prompts:  50%|█████     | 32/64 [05:06<02:24,  4.50s/it]
# Processed prompts:  52%|█████▏    | 33/64 [05:09<01:58,  3.83s/it]
# Processed prompts:  53%|█████▎    | 34/64 [05:11<01:42,  3.40s/it]
# Processed prompts:  55%|█████▍    | 35/64 [05:16<01:54,  3.93s/it]
# Processed prompts:  56%|█████▋    | 36/64 [05:20<01:46,  3.82s/it]
# Processed prompts:  58%|█████▊    | 37/64 [05:38<03:39,  8.13s/it]
# Processed prompts:  59%|█████▉    | 38/64 [05:46<03:29,  8.05s/it]
# Processed prompts:  61%|██████    | 39/64 [05:57<03:44,  9.00s/it]
# Processed prompts:  62%|██████▎   | 40/64 [06:07<03:42,  9.28s/it]
# Processed prompts:  64%|██████▍   | 41/64 [06:22<04:16, 11.14s/it]
# Processed prompts:  66%|██████▌   | 42/64 [06:48<05:38, 15.38s/it]
# Processed prompts:  67%|██████▋   | 43/64 [06:59<04:55, 14.07s/it]
# Processed prompts:  69%|██████▉   | 44/64 [07:04<03:49, 11.46s/it]
# Processed prompts:  70%|███████   | 45/64 [07:09<03:02,  9.61s/it]
# Processed prompts:  72%|███████▏  | 46/64 [07:12<02:16,  7.56s/it]
# Processed prompts:  73%|███████▎  | 47/64 [07:15<01:44,  6.14s/it]
# Processed prompts:  75%|███████▌  | 48/64 [07:20<01:32,  5.75s/it]
# Processed prompts:  77%|███████▋  | 49/64 [07:25<01:23,  5.56s/it]
# Processed prompts:  78%|███████▊  | 50/64 [07:27<01:04,  4.58s/it]
# Processed prompts:  80%|███████▉  | 51/64 [07:29<00:47,  3.64s/it]
# Processed prompts:  81%|████████▏ | 52/64 [07:32<00:44,  3.69s/it]
# Processed prompts:  83%|████████▎ | 53/64 [07:37<00:44,  4.06s/it]
# Processed prompts:  84%|████████▍ | 54/64 [07:44<00:49,  4.93s/it]
# Processed prompts:  86%|████████▌ | 55/64 [07:48<00:41,  4.64s/it]
# Processed prompts:  88%|████████▊ | 56/64 [07:55<00:41,  5.18s/it]
# Processed prompts:  89%|████████▉ | 57/64 [08:04<00:44,  6.41s/it]
# Processed prompts:  91%|█████████ | 58/64 [08:06<00:30,  5.07s/it]
# Processed prompts:  92%|█████████▏| 59/64 [08:06<00:18,  3.60s/it]
# Processed prompts:  94%|█████████▍| 60/64 [08:12<00:17,  4.26s/it]
# Processed prompts:  95%|█████████▌| 61/64 [08:13<00:10,  3.44s/it]
# Processed prompts:  97%|█████████▋| 62/64 [08:15<00:05,  2.80s/it]
# Processed prompts:  98%|█████████▊| 63/64 [08:16<00:02,  2.26s/it]
# Processed prompts: 100%|██████████| 64/64 [08:17<00:00,  7.77s/it]
#  10%|█         | 10/100 [38:09<7:11:06, 287.41s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# WARNING 10-29 19:02:58 scheduler.py:245] Input prompt (4588 tokens) is too long and exceeds limit of 4096
# Processed prompts:   2%|▏         | 1/64 [00:07<07:32,  7.18s/it]
# Processed prompts:   3%|▎         | 2/64 [00:39<22:59, 22.25s/it]
# Processed prompts:   6%|▋         | 4/64 [00:52<12:12, 12.22s/it]
# Processed prompts:   8%|▊         | 5/64 [00:53<08:28,  8.61s/it]
# WARNING 10-29 19:03:51 scheduler.py:245] Input prompt (4658 tokens) is too long and exceeds limit of 4096
# Processed prompts:  11%|█         | 7/64 [00:58<05:30,  5.79s/it]
# Processed prompts:  12%|█▎        | 8/64 [01:05<05:46,  6.18s/it]
# Processed prompts:  14%|█▍        | 9/64 [01:06<04:22,  4.78s/it]
# Processed prompts:  16%|█▌        | 10/64 [01:06<03:09,  3.50s/it]
# Processed prompts:  19%|█▉        | 12/64 [01:15<03:21,  3.88s/it]
# Processed prompts:  22%|██▏       | 14/64 [01:33<04:59,  5.98s/it]
# Processed prompts:  23%|██▎       | 15/64 [01:39<04:48,  5.89s/it]
# Processed prompts:  25%|██▌       | 16/64 [01:48<05:12,  6.51s/it]
# Processed prompts:  27%|██▋       | 17/64 [01:51<04:24,  5.62s/it]
# Processed prompts:  28%|██▊       | 18/64 [01:53<03:43,  4.85s/it]
# Processed prompts:  30%|██▉       | 19/64 [01:57<03:25,  4.56s/it]
# Processed prompts:  31%|███▏      | 20/64 [02:01<03:11,  4.34s/it]
# Processed prompts:  33%|███▎      | 21/64 [02:09<03:59,  5.58s/it]
# Processed prompts:  34%|███▍      | 22/64 [02:12<03:19,  4.75s/it]
# Processed prompts:  36%|███▌      | 23/64 [02:16<03:00,  4.40s/it]
# Processed prompts:  38%|███▊      | 24/64 [02:20<02:58,  4.46s/it]
# Processed prompts:  39%|███▉      | 25/64 [02:24<02:40,  4.12s/it]
# Processed prompts:  41%|████      | 26/64 [02:27<02:27,  3.88s/it]
# Processed prompts:  42%|████▏     | 27/64 [02:33<02:51,  4.64s/it]
# Processed prompts:  45%|████▌     | 29/64 [02:46<03:12,  5.49s/it]
# Processed prompts:  47%|████▋     | 30/64 [02:51<03:02,  5.37s/it]
# Processed prompts:  48%|████▊     | 31/64 [03:04<04:00,  7.28s/it]
# Processed prompts:  50%|█████     | 32/64 [03:08<03:28,  6.50s/it]
# Processed prompts:  52%|█████▏    | 33/64 [03:24<04:43,  9.14s/it]
# Processed prompts:  53%|█████▎    | 34/64 [03:29<03:56,  7.90s/it]
# Processed prompts:  55%|█████▍    | 35/64 [03:34<03:19,  6.88s/it]
# Processed prompts:  56%|█████▋    | 36/64 [03:35<02:29,  5.33s/it]
# Processed prompts:  58%|█████▊    | 37/64 [04:27<08:31, 18.94s/it]
# Processed prompts:  59%|█████▉    | 38/64 [04:38<07:12, 16.62s/it]
# Processed prompts:  61%|██████    | 39/64 [04:48<06:04, 14.58s/it]
# Processed prompts:  62%|██████▎   | 40/64 [04:54<04:52, 12.17s/it]
# Processed prompts:  64%|██████▍   | 41/64 [04:55<03:23,  8.86s/it]
# Processed prompts:  66%|██████▌   | 42/64 [05:00<02:46,  7.55s/it]
# Processed prompts:  67%|██████▋   | 43/64 [05:00<01:56,  5.54s/it]
# Processed prompts:  70%|███████   | 45/64 [05:01<00:58,  3.08s/it]
# Processed prompts:  72%|███████▏  | 46/64 [05:03<00:51,  2.87s/it]
# Processed prompts:  73%|███████▎  | 47/64 [05:08<00:57,  3.36s/it]
# Processed prompts:  75%|███████▌  | 48/64 [05:17<01:20,  5.04s/it]
# Processed prompts:  77%|███████▋  | 49/64 [05:19<00:59,  3.96s/it]
# Processed prompts:  78%|███████▊  | 50/64 [05:19<00:42,  3.03s/it]
# Processed prompts:  80%|███████▉  | 51/64 [05:20<00:31,  2.45s/it]
# Processed prompts:  81%|████████▏ | 52/64 [05:27<00:43,  3.60s/it]
# Processed prompts:  83%|████████▎ | 53/64 [05:31<00:42,  3.90s/it]
# Processed prompts:  84%|████████▍ | 54/64 [05:33<00:31,  3.16s/it]
# Processed prompts:  86%|████████▌ | 55/64 [05:36<00:29,  3.23s/it]
# Processed prompts:  88%|████████▊ | 56/64 [05:37<00:19,  2.46s/it]
# Processed prompts:  89%|████████▉ | 57/64 [05:39<00:17,  2.45s/it]
# Processed prompts:  91%|█████████ | 58/64 [05:42<00:14,  2.50s/it]
# Processed prompts:  92%|█████████▏| 59/64 [05:44<00:12,  2.42s/it]
# Processed prompts:  94%|█████████▍| 60/64 [05:45<00:08,  2.06s/it]
# Processed prompts:  95%|█████████▌| 61/64 [05:49<00:07,  2.46s/it]
# Processed prompts:  97%|█████████▋| 62/64 [05:57<00:08,  4.26s/it]
# Processed prompts:  98%|█████████▊| 63/64 [05:58<00:03,  3.34s/it]
# Processed prompts: 100%|██████████| 64/64 [07:13<00:00,  6.78s/it]
#  12%|█▏        | 12/100 [45:42<6:26:56, 263.82s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:43<45:28, 43.32s/it]
# Processed prompts:   3%|▎         | 2/64 [00:48<21:43, 21.03s/it]
# Processed prompts:   5%|▍         | 3/64 [00:53<13:53, 13.66s/it]
# Processed prompts:   6%|▋         | 4/64 [01:01<11:33, 11.55s/it]
# Processed prompts:   8%|▊         | 5/64 [01:04<08:13,  8.37s/it]
# Processed prompts:   9%|▉         | 6/64 [01:08<06:37,  6.85s/it]
# Processed prompts:  11%|█         | 7/64 [01:11<05:14,  5.51s/it]
# Processed prompts:  12%|█▎        | 8/64 [01:16<05:01,  5.39s/it]
# Processed prompts:  16%|█▌        | 10/64 [01:23<04:01,  4.47s/it]
# Processed prompts:  17%|█▋        | 11/64 [01:25<03:22,  3.82s/it]
# Processed prompts:  19%|█▉        | 12/64 [01:28<03:07,  3.61s/it]
# Processed prompts:  20%|██        | 13/64 [01:36<04:06,  4.84s/it]
# Processed prompts:  22%|██▏       | 14/64 [01:42<04:13,  5.07s/it]
# Processed prompts:  23%|██▎       | 15/64 [01:46<04:03,  4.97s/it]
# Processed prompts:  25%|██▌       | 16/64 [01:49<03:29,  4.37s/it]
# Processed prompts:  27%|██▋       | 17/64 [01:58<04:29,  5.73s/it]
# Processed prompts:  28%|██▊       | 18/64 [02:04<04:26,  5.80s/it]
# Processed prompts:  30%|██▉       | 19/64 [02:15<05:31,  7.36s/it]
# Processed prompts:  31%|███▏      | 20/64 [02:35<08:09, 11.12s/it]
# Processed prompts:  33%|███▎      | 21/64 [02:44<07:29, 10.46s/it]
# Processed prompts:  34%|███▍      | 22/64 [02:50<06:17,  8.98s/it]
# Processed prompts:  36%|███▌      | 23/64 [02:57<05:45,  8.44s/it]
# Processed prompts:  38%|███▊      | 24/64 [03:00<04:35,  6.90s/it]
# Processed prompts:  39%|███▉      | 25/64 [03:22<07:23, 11.38s/it]
# Processed prompts:  41%|████      | 26/64 [03:22<05:05,  8.03s/it]
# Processed prompts:  42%|████▏     | 27/64 [03:26<04:08,  6.73s/it]
# Processed prompts:  44%|████▍     | 28/64 [03:29<03:28,  5.80s/it]
# Processed prompts:  45%|████▌     | 29/64 [03:32<02:53,  4.97s/it]
# Processed prompts:  47%|████▋     | 30/64 [03:35<02:28,  4.38s/it]
# Processed prompts:  48%|████▊     | 31/64 [03:38<02:06,  3.82s/it]
# Processed prompts:  50%|█████     | 32/64 [03:46<02:37,  4.93s/it]
# Processed prompts:  52%|█████▏    | 33/64 [03:48<02:12,  4.27s/it]
# Processed prompts:  53%|█████▎    | 34/64 [03:54<02:22,  4.77s/it]
# Processed prompts:  55%|█████▍    | 35/64 [03:59<02:17,  4.74s/it]
# Processed prompts:  56%|█████▋    | 36/64 [04:04<02:15,  4.84s/it]
# Processed prompts:  58%|█████▊    | 37/64 [04:18<03:24,  7.57s/it]
# Processed prompts:  59%|█████▉    | 38/64 [04:35<04:30, 10.42s/it]
# Processed prompts:  61%|██████    | 39/64 [04:44<04:06,  9.87s/it]
# Processed prompts:  62%|██████▎   | 40/64 [04:45<02:56,  7.37s/it]
# Processed prompts:  64%|██████▍   | 41/64 [04:47<02:09,  5.62s/it]
# Processed prompts:  66%|██████▌   | 42/64 [04:54<02:17,  6.25s/it]
# Processed prompts:  67%|██████▋   | 43/64 [04:55<01:33,  4.44s/it]
# Processed prompts:  69%|██████▉   | 44/64 [04:57<01:19,  3.99s/it]
# Processed prompts:  70%|███████   | 45/64 [04:59<01:01,  3.22s/it]
# Processed prompts:  72%|███████▏  | 46/64 [04:59<00:42,  2.38s/it]
# Processed prompts:  73%|███████▎  | 47/64 [05:25<02:37,  9.27s/it]
# Processed prompts:  75%|███████▌  | 48/64 [05:47<03:32, 13.30s/it]
# Processed prompts:  78%|███████▊  | 50/64 [05:48<01:43,  7.36s/it]
# Processed prompts:  80%|███████▉  | 51/64 [05:52<01:24,  6.50s/it]
# Processed prompts:  81%|████████▏ | 52/64 [05:53<01:01,  5.13s/it]
# Processed prompts:  83%|████████▎ | 53/64 [05:55<00:45,  4.14s/it]
# Processed prompts:  84%|████████▍ | 54/64 [05:57<00:37,  3.72s/it]
# Processed prompts:  86%|████████▌ | 55/64 [06:00<00:29,  3.27s/it]
# Processed prompts:  88%|████████▊ | 56/64 [06:01<00:21,  2.74s/it]
# Processed prompts:  89%|████████▉ | 57/64 [06:02<00:14,  2.11s/it]
# Processed prompts:  91%|█████████ | 58/64 [06:03<00:12,  2.03s/it]
# Processed prompts:  92%|█████████▏| 59/64 [06:04<00:07,  1.60s/it]
# Processed prompts:  94%|█████████▍| 60/64 [06:06<00:06,  1.58s/it]
# Processed prompts:  95%|█████████▌| 61/64 [06:13<00:09,  3.33s/it]
# Processed prompts:  97%|█████████▋| 62/64 [06:14<00:05,  2.62s/it]
# Processed prompts:  98%|█████████▊| 63/64 [06:14<00:01,  1.92s/it]
# Processed prompts: 100%|██████████| 64/64 [07:15<00:00,  6.80s/it]
#  13%|█▎        | 13/100 [53:20<7:23:28, 305.84s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:47<49:38, 47.28s/it]
# Processed prompts:   3%|▎         | 2/64 [00:50<21:48, 21.11s/it]
# Processed prompts:   5%|▍         | 3/64 [00:51<12:08, 11.95s/it]
# Processed prompts:   6%|▋         | 4/64 [01:00<10:59, 10.98s/it]
# Processed prompts:   8%|▊         | 5/64 [01:04<08:27,  8.60s/it]
# Processed prompts:   9%|▉         | 6/64 [01:12<07:48,  8.07s/it]
# Processed prompts:  11%|█         | 7/64 [01:16<06:30,  6.85s/it]
# Processed prompts:  12%|█▎        | 8/64 [01:22<06:14,  6.70s/it]
# Processed prompts:  14%|█▍        | 9/64 [01:24<04:37,  5.05s/it]
# Processed prompts:  16%|█▌        | 10/64 [01:31<05:14,  5.82s/it]
# Processed prompts:  17%|█▋        | 11/64 [01:34<04:11,  4.74s/it]
# Processed prompts:  19%|█▉        | 12/64 [01:40<04:37,  5.34s/it]
# Processed prompts:  20%|██        | 13/64 [01:43<03:55,  4.62s/it]
# Processed prompts:  22%|██▏       | 14/64 [01:48<03:52,  4.65s/it]
# Processed prompts:  23%|██▎       | 15/64 [01:51<03:28,  4.26s/it]
# Processed prompts:  25%|██▌       | 16/64 [02:00<04:35,  5.74s/it]
# Processed prompts:  27%|██▋       | 17/64 [02:03<03:49,  4.89s/it]
# Processed prompts:  28%|██▊       | 18/64 [02:12<04:42,  6.14s/it]
# Processed prompts:  30%|██▉       | 19/64 [02:19<04:44,  6.32s/it]
# Processed prompts:  31%|███▏      | 20/64 [02:25<04:25,  6.04s/it]
# Processed prompts:  33%|███▎      | 21/64 [02:27<03:28,  4.84s/it]
# Processed prompts:  34%|███▍      | 22/64 [02:30<02:59,  4.27s/it]
# Processed prompts:  36%|███▌      | 23/64 [02:40<04:09,  6.07s/it]
# Processed prompts:  38%|███▊      | 24/64 [02:43<03:30,  5.27s/it]
# Processed prompts:  39%|███▉      | 25/64 [02:53<04:23,  6.77s/it]
# Processed prompts:  41%|████      | 26/64 [02:59<03:57,  6.26s/it]
# Processed prompts:  42%|████▏     | 27/64 [03:09<04:33,  7.40s/it]
# Processed prompts:  44%|████▍     | 28/64 [03:16<04:23,  7.32s/it]
# Processed prompts:  45%|████▌     | 29/64 [03:19<03:28,  5.97s/it]
# Processed prompts:  48%|████▊     | 31/64 [03:24<02:25,  4.41s/it]
# Processed prompts:  50%|█████     | 32/64 [03:37<03:31,  6.60s/it]
# Processed prompts:  52%|█████▏    | 33/64 [03:47<03:53,  7.53s/it]
# Processed prompts:  53%|█████▎    | 34/64 [03:53<03:30,  7.02s/it]
# Processed prompts:  55%|█████▍    | 35/64 [03:55<02:48,  5.82s/it]
# Processed prompts:  56%|█████▋    | 36/64 [03:59<02:23,  5.12s/it]
# Processed prompts:  58%|█████▊    | 37/64 [04:02<02:04,  4.62s/it]
# Processed prompts:  59%|█████▉    | 38/64 [04:07<02:02,  4.71s/it]
# Processed prompts:  61%|██████    | 39/64 [04:09<01:36,  3.86s/it]
# Processed prompts:  64%|██████▍   | 41/64 [04:10<00:52,  2.30s/it]
# Processed prompts:  66%|██████▌   | 42/64 [04:11<00:43,  1.99s/it]
# Processed prompts:  67%|██████▋   | 43/64 [04:13<00:42,  2.02s/it]
# Processed prompts:  69%|██████▉   | 44/64 [04:16<00:47,  2.37s/it]
# Processed prompts:  70%|███████   | 45/64 [04:18<00:38,  2.05s/it]
# Processed prompts:  72%|███████▏  | 46/64 [04:19<00:33,  1.87s/it]
# Processed prompts:  73%|███████▎  | 47/64 [04:20<00:29,  1.74s/it]
# Processed prompts:  75%|███████▌  | 48/64 [04:21<00:20,  1.29s/it]
# Processed prompts:  77%|███████▋  | 49/64 [04:21<00:15,  1.02s/it]
# Processed prompts:  78%|███████▊  | 50/64 [04:21<00:10,  1.33it/s]
# Processed prompts:  81%|████████▏ | 52/64 [04:24<00:13,  1.12s/it]
# Processed prompts:  83%|████████▎ | 53/64 [04:24<00:09,  1.12it/s]
# Processed prompts:  84%|████████▍ | 54/64 [04:25<00:06,  1.45it/s]
# Processed prompts:  86%|████████▌ | 55/64 [04:26<00:07,  1.26it/s]
# Processed prompts:  88%|████████▊ | 56/64 [04:26<00:05,  1.45it/s]
# Processed prompts:  89%|████████▉ | 57/64 [04:30<00:10,  1.53s/it]
# Processed prompts:  91%|█████████ | 58/64 [04:32<00:11,  1.90s/it]
# Processed prompts:  92%|█████████▏| 59/64 [05:06<00:55, 11.14s/it]
# Processed prompts:  94%|█████████▍| 60/64 [05:22<00:50, 12.64s/it]
# Processed prompts:  95%|█████████▌| 61/64 [05:25<00:29,  9.84s/it]
# Processed prompts:  97%|█████████▋| 62/64 [05:52<00:29, 14.71s/it]
# Processed prompts:  98%|█████████▊| 63/64 [06:04<00:14, 14.02s/it]
# Processed prompts: 100%|██████████| 64/64 [06:24<00:00,  6.01s/it]
#  15%|█▌        | 15/100 [1:00:09<6:18:35, 267.24s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:44<46:28, 44.26s/it]
# Processed prompts:   3%|▎         | 2/64 [00:44<19:14, 18.62s/it]
# Processed prompts:   5%|▍         | 3/64 [00:49<12:11, 11.99s/it]
# Processed prompts:   6%|▋         | 4/64 [00:52<08:42,  8.70s/it]
# Processed prompts:   8%|▊         | 5/64 [01:02<09:05,  9.25s/it]
# Processed prompts:   9%|▉         | 6/64 [01:07<07:16,  7.52s/it]
# Processed prompts:  11%|█         | 7/64 [01:13<06:44,  7.10s/it]
# Processed prompts:  12%|█▎        | 8/64 [01:27<08:45,  9.38s/it]
# Processed prompts:  14%|█▍        | 9/64 [01:28<06:12,  6.77s/it]
# Processed prompts:  16%|█▌        | 10/64 [01:43<08:16,  9.20s/it]
# Processed prompts:  17%|█▋        | 11/64 [01:51<07:54,  8.94s/it]
# Processed prompts:  19%|█▉        | 12/64 [01:59<07:24,  8.55s/it]
# Processed prompts:  20%|██        | 13/64 [02:04<06:28,  7.62s/it]
# Processed prompts:  23%|██▎       | 15/64 [02:07<03:52,  4.74s/it]
# Processed prompts:  25%|██▌       | 16/64 [02:09<03:15,  4.08s/it]
# Processed prompts:  27%|██▋       | 17/64 [02:11<02:46,  3.54s/it]
# Processed prompts:  28%|██▊       | 18/64 [02:13<02:26,  3.18s/it]
# Processed prompts:  30%|██▉       | 19/64 [02:17<02:25,  3.23s/it]
# Processed prompts:  31%|███▏      | 20/64 [02:19<02:14,  3.06s/it]
# Processed prompts:  33%|███▎      | 21/64 [02:20<01:44,  2.43s/it]
# Processed prompts:  34%|███▍      | 22/64 [02:22<01:37,  2.31s/it]
# Processed prompts:  36%|███▌      | 23/64 [02:24<01:29,  2.17s/it]
# Processed prompts:  39%|███▉      | 25/64 [02:30<01:35,  2.45s/it]
# Processed prompts:  41%|████      | 26/64 [02:34<01:53,  2.97s/it]
# Processed prompts:  42%|████▏     | 27/64 [02:35<01:31,  2.48s/it]
# Processed prompts:  44%|████▍     | 28/64 [02:38<01:32,  2.58s/it]
# Processed prompts:  45%|████▌     | 29/64 [02:38<01:07,  1.92s/it]
# Processed prompts:  47%|████▋     | 30/64 [02:39<00:52,  1.55s/it]
# Processed prompts:  50%|█████     | 32/64 [02:49<01:37,  3.04s/it]
# Processed prompts:  52%|█████▏    | 33/64 [03:08<03:32,  6.84s/it]
# Processed prompts:  53%|█████▎    | 34/64 [03:39<06:32, 13.08s/it]
# Processed prompts:  55%|█████▍    | 35/64 [03:45<05:25, 11.21s/it]
# Processed prompts:  56%|█████▋    | 36/64 [03:53<04:48, 10.30s/it]
# Processed prompts:  58%|█████▊    | 37/64 [03:53<03:20,  7.41s/it]
# Processed prompts:  59%|█████▉    | 38/64 [04:07<04:01,  9.28s/it]
# Processed prompts:  61%|██████    | 39/64 [04:12<03:21,  8.07s/it]
# Processed prompts:  62%|██████▎   | 40/64 [04:14<02:35,  6.48s/it]
# Processed prompts:  64%|██████▍   | 41/64 [04:20<02:23,  6.25s/it]
# Processed prompts:  66%|██████▌   | 42/64 [04:25<02:07,  5.81s/it]
# Processed prompts:  67%|██████▋   | 43/64 [04:29<01:52,  5.36s/it]
# Processed prompts:  69%|██████▉   | 44/64 [04:32<01:31,  4.58s/it]
# Processed prompts:  70%|███████   | 45/64 [04:32<01:02,  3.27s/it]
# Processed prompts:  72%|███████▏  | 46/64 [04:43<01:39,  5.52s/it]
# Processed prompts:  73%|███████▎  | 47/64 [04:54<02:00,  7.11s/it]
# Processed prompts:  75%|███████▌  | 48/64 [04:59<01:42,  6.42s/it]
# Processed prompts:  77%|███████▋  | 49/64 [05:04<01:30,  6.07s/it]
# Processed prompts:  78%|███████▊  | 50/64 [05:06<01:07,  4.82s/it]
# Processed prompts:  80%|███████▉  | 51/64 [05:12<01:08,  5.25s/it]
# Processed prompts:  81%|████████▏ | 52/64 [05:19<01:10,  5.89s/it]
# Processed prompts:  83%|████████▎ | 53/64 [05:22<00:55,  5.03s/it]
# Processed prompts:  84%|████████▍ | 54/64 [05:34<01:09,  6.95s/it]
# Processed prompts:  86%|████████▌ | 55/64 [05:50<01:27,  9.69s/it]
# Processed prompts:  88%|████████▊ | 56/64 [05:57<01:11,  8.89s/it]
# Processed prompts:  89%|████████▉ | 57/64 [05:59<00:48,  6.93s/it]
# Processed prompts:  91%|█████████ | 58/64 [06:03<00:35,  5.85s/it]
# Processed prompts:  92%|█████████▏| 59/64 [06:03<00:21,  4.22s/it]
# Processed prompts:  94%|█████████▍| 60/64 [06:04<00:12,  3.15s/it]
# Processed prompts:  95%|█████████▌| 61/64 [06:04<00:07,  2.37s/it]
# Processed prompts:  97%|█████████▋| 62/64 [06:06<00:04,  2.31s/it]
# Processed prompts:  98%|█████████▊| 63/64 [06:25<00:07,  7.34s/it]
# Processed prompts: 100%|██████████| 64/64 [07:07<00:00,  6.67s/it]
#  16%|█▌        | 16/100 [1:07:40<7:09:07, 306.52s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:42<44:49, 42.70s/it]
# Processed prompts:   3%|▎         | 2/64 [00:45<20:01, 19.38s/it]
# Processed prompts:   5%|▍         | 3/64 [00:59<17:00, 16.73s/it]
# Processed prompts:   6%|▋         | 4/64 [01:11<15:06, 15.11s/it]
# Processed prompts:   8%|▊         | 5/64 [01:20<12:38, 12.85s/it]
# Processed prompts:   9%|▉         | 6/64 [01:57<20:06, 20.80s/it]
# Processed prompts:  11%|█         | 7/64 [02:37<25:45, 27.11s/it]
# Processed prompts:  12%|█▎        | 8/64 [02:50<21:09, 22.66s/it]
# Processed prompts:  14%|█▍        | 9/64 [03:02<17:40, 19.27s/it]
# Processed prompts:  16%|█▌        | 10/64 [03:08<13:48, 15.35s/it]
# Processed prompts:  17%|█▋        | 11/64 [03:09<09:36, 10.87s/it]
# Processed prompts:  19%|█▉        | 12/64 [03:13<07:37,  8.80s/it]
# Processed prompts:  20%|██        | 13/64 [03:14<05:36,  6.61s/it]
# Processed prompts:  22%|██▏       | 14/64 [03:21<05:22,  6.46s/it]
# Processed prompts:  23%|██▎       | 15/64 [03:27<05:18,  6.49s/it]
# Processed prompts:  25%|██▌       | 16/64 [03:29<04:07,  5.16s/it]
# Processed prompts:  27%|██▋       | 17/64 [03:31<03:13,  4.11s/it]
# Processed prompts:  28%|██▊       | 18/64 [03:39<04:06,  5.36s/it]
# Processed prompts:  30%|██▉       | 19/64 [03:45<04:11,  5.59s/it]
# Processed prompts:  31%|███▏      | 20/64 [04:11<08:28, 11.56s/it]
# Processed prompts:  33%|███▎      | 21/64 [04:20<07:51, 10.96s/it]
# Processed prompts:  34%|███▍      | 22/64 [04:43<10:13, 14.61s/it]
# Processed prompts:  36%|███▌      | 23/64 [05:09<12:16, 17.95s/it]
# Processed prompts:  38%|███▊      | 24/64 [05:24<11:18, 16.95s/it]
# Processed prompts:  39%|███▉      | 25/64 [05:25<08:01, 12.35s/it]
# Processed prompts:  41%|████      | 26/64 [05:33<06:59, 11.05s/it]
# Processed prompts:  42%|████▏     | 27/64 [05:43<06:31, 10.59s/it]
# Processed prompts:  44%|████▍     | 28/64 [06:01<07:46, 12.96s/it]
# Processed prompts:  45%|████▌     | 29/64 [06:09<06:33, 11.23s/it]
# Processed prompts:  47%|████▋     | 30/64 [06:18<06:01, 10.64s/it]
# Processed prompts:  48%|████▊     | 31/64 [06:24<05:07,  9.33s/it]
# Processed prompts:  50%|█████     | 32/64 [06:31<04:32,  8.53s/it]
# Processed prompts:  52%|█████▏    | 33/64 [07:22<11:01, 21.33s/it]
# Processed prompts:  53%|█████▎    | 34/64 [07:47<11:08, 22.28s/it]
# Processed prompts:  55%|█████▍    | 35/64 [08:06<10:17, 21.28s/it]
# Processed prompts:  58%|█████▊    | 37/64 [08:12<05:48, 12.91s/it]
# Processed prompts:  59%|█████▉    | 38/64 [08:15<04:32, 10.50s/it]
# Processed prompts:  61%|██████    | 39/64 [08:18<03:31,  8.48s/it]
# Processed prompts:  62%|██████▎   | 40/64 [08:19<02:38,  6.59s/it]
# Processed prompts:  64%|██████▍   | 41/64 [08:25<02:24,  6.27s/it]
# Processed prompts:  66%|██████▌   | 42/64 [08:26<01:46,  4.85s/it]
# Processed prompts:  67%|██████▋   | 43/64 [08:35<02:09,  6.15s/it]
# Processed prompts:  69%|██████▉   | 44/64 [08:40<01:52,  5.65s/it]
# Processed prompts:  70%|███████   | 45/64 [08:49<02:08,  6.74s/it]
# Processed prompts:  72%|███████▏  | 46/64 [08:52<01:38,  5.47s/it]
# Processed prompts:  73%|███████▎  | 47/64 [08:55<01:23,  4.91s/it]
# Processed prompts:  75%|███████▌  | 48/64 [08:57<01:05,  4.10s/it]
# Processed prompts:  77%|███████▋  | 49/64 [09:03<01:06,  4.44s/it]
# Processed prompts:  78%|███████▊  | 50/64 [09:13<01:25,  6.13s/it]
# Processed prompts:  80%|███████▉  | 51/64 [09:17<01:13,  5.63s/it]
# Processed prompts:  81%|████████▏ | 52/64 [09:18<00:49,  4.09s/it]
# Processed prompts:  83%|████████▎ | 53/64 [09:19<00:36,  3.35s/it]
# Processed prompts:  84%|████████▍ | 54/64 [09:21<00:30,  3.00s/it]
# Processed prompts:  86%|████████▌ | 55/64 [09:32<00:46,  5.14s/it]
# Processed prompts:  88%|████████▊ | 56/64 [09:35<00:36,  4.52s/it]
# Processed prompts:  89%|████████▉ | 57/64 [09:38<00:30,  4.29s/it]
# Processed prompts:  91%|█████████ | 58/64 [09:44<00:28,  4.76s/it]
# Processed prompts:  92%|█████████▏| 59/64 [09:45<00:17,  3.48s/it]
# Processed prompts:  94%|█████████▍| 60/64 [09:52<00:18,  4.58s/it]
# Processed prompts:  95%|█████████▌| 61/64 [10:20<00:34, 11.59s/it]
# Processed prompts:  97%|█████████▋| 62/64 [10:33<00:24, 12.02s/it]
# Processed prompts:  98%|█████████▊| 63/64 [10:38<00:09,  9.87s/it]
# Processed prompts: 100%|██████████| 64/64 [10:42<00:00, 10.04s/it]
#  18%|█▊        | 18/100 [1:19:04<7:17:21, 320.02s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:36<38:32, 36.70s/it]
# Processed prompts:   3%|▎         | 2/64 [00:49<23:26, 22.69s/it]
# Processed prompts:   5%|▍         | 3/64 [00:58<16:28, 16.21s/it]
# Processed prompts:   6%|▋         | 4/64 [00:58<10:08, 10.15s/it]
# Processed prompts:   9%|▉         | 6/64 [01:03<05:43,  5.92s/it]
# Processed prompts:  14%|█▍        | 9/64 [01:09<03:34,  3.90s/it]
# Processed prompts:  16%|█▌        | 10/64 [01:15<03:49,  4.24s/it]
# Processed prompts:  17%|█▋        | 11/64 [02:29<17:38, 19.97s/it]
# Processed prompts:  19%|█▉        | 12/64 [02:46<16:39, 19.22s/it]
# Processed prompts:  20%|██        | 13/64 [02:47<12:19, 14.51s/it]
# Processed prompts:  22%|██▏       | 14/64 [03:11<14:12, 17.06s/it]
# Processed prompts:  23%|██▎       | 15/64 [03:13<10:33, 12.93s/it]
# Processed prompts:  25%|██▌       | 16/64 [03:47<15:02, 18.81s/it]
# Processed prompts:  27%|██▋       | 17/64 [03:58<12:56, 16.53s/it]
# Processed prompts:  28%|██▊       | 18/64 [04:04<10:26, 13.62s/it]
# Processed prompts:  30%|██▉       | 19/64 [04:08<08:08, 10.85s/it]
# Processed prompts:  31%|███▏      | 20/64 [04:11<06:12,  8.48s/it]
# Processed prompts:  33%|███▎      | 21/64 [04:27<07:35, 10.60s/it]
# Processed prompts:  34%|███▍      | 22/64 [04:37<07:21, 10.51s/it]
# Processed prompts:  36%|███▌      | 23/64 [04:42<06:06,  8.93s/it]
# Processed prompts:  38%|███▊      | 24/64 [04:54<06:26,  9.66s/it]
# Processed prompts:  39%|███▉      | 25/64 [04:54<04:27,  6.87s/it]
# Processed prompts:  41%|████      | 26/64 [05:11<06:12,  9.81s/it]
# Processed prompts:  42%|████▏     | 27/64 [05:18<05:31,  8.95s/it]
# Processed prompts:  44%|████▍     | 28/64 [05:42<08:05, 13.48s/it]
# Processed prompts:  45%|████▌     | 29/64 [05:48<06:30, 11.16s/it]
# Processed prompts:  47%|████▋     | 30/64 [05:51<04:56,  8.72s/it]
# Processed prompts:  48%|████▊     | 31/64 [06:01<05:08,  9.35s/it]
# Processed prompts:  50%|█████     | 32/64 [06:02<03:35,  6.73s/it]
# Processed prompts:  52%|█████▏    | 33/64 [06:37<07:51, 15.20s/it]
# Processed prompts:  53%|█████▎    | 34/64 [06:50<07:20, 14.67s/it]
# Processed prompts:  55%|█████▍    | 35/64 [06:52<05:15, 10.87s/it]
# ...
# Processed prompts:  19%|█▉        | 12/64 [01:20<03:23,  3.91s/it]
# Processed prompts:  20%|██        | 13/64 [01:24<03:15,  3.83s/it]
# Processed prompts:  22%|██▏       | 14/64 [01:27<03:05,  3.72s/it]
# Processed prompts:  23%|██▎       | 15/64 [01:30<02:52,  3.53s/it]
# Processed prompts:  25%|██▌       | 16/64 [01:34<02:53,  3.62s/it]
# Processed prompts:  27%|██▋       | 17/64 [01:40<03:21,  4.28s/it]
# Processed prompts:  28%|██▊       | 18/64 [01:42<02:53,  3.78s/it]
# Processed prompts:  30%|██▉       | 19/64 [01:45<02:39,  3.55s/it]
# Processed prompts:  31%|███▏      | 20/64 [02:11<07:28, 10.19s/it]
# Processed prompts:  33%|███▎      | 21/64 [02:17<06:26,  8.98s/it]
# Processed prompts:  34%|███▍      | 22/64 [02:43<09:47, 13.98s/it]
# Processed prompts:  36%|███▌      | 23/64 [02:55<09:08, 13.39s/it]
# Processed prompts:  38%|███▊      | 24/64 [03:07<08:37, 12.94s/it]
# Processed prompts:  39%|███▉      | 25/64 [03:25<09:21, 14.40s/it]
# Processed prompts:  41%|████      | 26/64 [03:36<08:31, 13.45s/it]
# Processed prompts:  42%|████▏     | 27/64 [03:40<06:36, 10.71s/it]
# Processed prompts:  44%|████▍     | 28/64 [03:43<05:05,  8.49s/it]
# Processed prompts:  45%|████▌     | 29/64 [03:53<05:09,  8.84s/it]
# Processed prompts:  47%|████▋     | 30/64 [03:58<04:19,  7.63s/it]
# Processed prompts:  48%|████▊     | 31/64 [04:04<03:54,  7.11s/it]
# Processed prompts:  50%|█████     | 32/64 [04:06<02:58,  5.58s/it]
# Processed prompts:  52%|█████▏    | 33/64 [04:08<02:20,  4.53s/it]
# Processed prompts:  53%|█████▎    | 34/64 [04:13<02:25,  4.85s/it]
# Processed prompts:  55%|█████▍    | 35/64 [04:14<01:46,  3.66s/it]
# Processed prompts:  56%|█████▋    | 36/64 [04:16<01:21,  2.90s/it]
# Processed prompts:  58%|█████▊    | 37/64 [04:18<01:12,  2.70s/it]
# Processed prompts:  59%|█████▉    | 38/64 [04:20<01:05,  2.53s/it]
# Processed prompts:  61%|██████    | 39/64 [04:21<00:54,  2.17s/it]
# Processed prompts:  62%|██████▎   | 40/64 [04:22<00:42,  1.79s/it]
# Processed prompts:  64%|██████▍   | 41/64 [04:24<00:40,  1.77s/it]
# Processed prompts:  66%|██████▌   | 42/64 [04:24<00:29,  1.36s/it]
# Processed prompts:  67%|██████▋   | 43/64 [04:24<00:21,  1.02s/it]
# Processed prompts:  69%|██████▉   | 44/64 [04:26<00:25,  1.27s/it]
# Processed prompts:  70%|███████   | 45/64 [04:28<00:23,  1.26s/it]
# Processed prompts:  73%|███████▎  | 47/64 [04:29<00:16,  1.05it/s]
# Processed prompts:  75%|███████▌  | 48/64 [04:30<00:16,  1.00s/it]
# Processed prompts:  77%|███████▋  | 49/64 [04:32<00:19,  1.27s/it]
# Processed prompts:  78%|███████▊  | 50/64 [04:34<00:21,  1.53s/it]
# Processed prompts:  80%|███████▉  | 51/64 [04:35<00:15,  1.23s/it]
# Processed prompts:  81%|████████▏ | 52/64 [04:35<00:11,  1.03it/s]
# Processed prompts:  83%|████████▎ | 53/64 [04:36<00:11,  1.00s/it]
# Processed prompts:  84%|████████▍ | 54/64 [04:37<00:10,  1.08s/it]
# Processed prompts:  86%|████████▌ | 55/64 [04:40<00:13,  1.45s/it]
# Processed prompts:  88%|████████▊ | 56/64 [04:42<00:12,  1.59s/it]
# Processed prompts:  89%|████████▉ | 57/64 [04:44<00:12,  1.83s/it]
# Processed prompts:  91%|█████████ | 58/64 [04:46<00:10,  1.80s/it]
# Processed prompts:  92%|█████████▏| 59/64 [04:49<00:11,  2.36s/it]
# Processed prompts:  94%|█████████▍| 60/64 [04:53<00:10,  2.69s/it]
# Processed prompts:  95%|█████████▌| 61/64 [05:01<00:13,  4.43s/it]
# Processed prompts:  97%|█████████▋| 62/64 [05:02<00:06,  3.28s/it]
# Processed prompts:  98%|█████████▊| 63/64 [05:10<00:04,  4.87s/it]
# Processed prompts: 100%|██████████| 64/64 [05:13<00:00,  4.90s/it]
#  95%|█████████▌| 95/100 [7:14:14<21:04, 252.85s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:44<46:49, 44.59s/it]
# Processed prompts:   5%|▍         | 3/64 [00:48<13:17, 13.07s/it]
# Processed prompts:   6%|▋         | 4/64 [00:51<09:41,  9.69s/it]
# Processed prompts:   8%|▊         | 5/64 [00:54<07:13,  7.34s/it]
# Processed prompts:   9%|▉         | 6/64 [00:58<05:59,  6.19s/it]
# Processed prompts:  11%|█         | 7/64 [01:00<04:39,  4.90s/it]
# Processed prompts:  12%|█▎        | 8/64 [01:02<03:47,  4.06s/it]
# Processed prompts:  14%|█▍        | 9/64 [01:04<03:10,  3.47s/it]
# Processed prompts:  17%|█▋        | 11/64 [01:09<02:34,  2.92s/it]
# Processed prompts:  19%|█▉        | 12/64 [01:12<02:30,  2.89s/it]
# Processed prompts:  22%|██▏       | 14/64 [01:18<02:26,  2.92s/it]
# Processed prompts:  23%|██▎       | 15/64 [01:20<02:18,  2.82s/it]
# Processed prompts:  25%|██▌       | 16/64 [01:23<02:15,  2.82s/it]
# Processed prompts:  27%|██▋       | 17/64 [01:25<02:06,  2.69s/it]
# Processed prompts:  30%|██▉       | 19/64 [01:30<01:59,  2.66s/it]
# Processed prompts:  31%|███▏      | 20/64 [01:31<01:36,  2.19s/it]
# Processed prompts:  33%|███▎      | 21/64 [01:35<01:51,  2.60s/it]
# Processed prompts:  34%|███▍      | 22/64 [01:38<01:53,  2.71s/it]
# Processed prompts:  36%|███▌      | 23/64 [01:41<01:52,  2.74s/it]
# Processed prompts:  39%|███▉      | 25/64 [01:45<01:35,  2.45s/it]
# Processed prompts:  41%|████      | 26/64 [01:48<01:36,  2.55s/it]
# Processed prompts:  42%|████▏     | 27/64 [01:51<01:43,  2.81s/it]
# Processed prompts:  44%|████▍     | 28/64 [01:53<01:33,  2.59s/it]
# Processed prompts:  45%|████▌     | 29/64 [02:00<02:06,  3.62s/it]
# Processed prompts:  47%|████▋     | 30/64 [02:02<01:50,  3.26s/it]
# Processed prompts:  48%|████▊     | 31/64 [02:05<01:42,  3.10s/it]
# Processed prompts:  50%|█████     | 32/64 [02:06<01:23,  2.62s/it]
# Processed prompts:  52%|█████▏    | 33/64 [02:07<01:09,  2.25s/it]
# Processed prompts:  53%|█████▎    | 34/64 [02:09<01:03,  2.12s/it]
# Processed prompts:  55%|█████▍    | 35/64 [02:10<00:46,  1.62s/it]
# Processed prompts:  56%|█████▋    | 36/64 [02:10<00:33,  1.20s/it]
# Processed prompts:  58%|█████▊    | 37/64 [02:11<00:28,  1.04s/it]
# Processed prompts:  59%|█████▉    | 38/64 [02:22<01:47,  4.15s/it]
# Processed prompts:  61%|██████    | 39/64 [02:26<01:41,  4.06s/it]
# Processed prompts:  62%|██████▎   | 40/64 [02:32<01:54,  4.75s/it]
# Processed prompts:  64%|██████▍   | 41/64 [02:33<01:22,  3.58s/it]
# Processed prompts:  66%|██████▌   | 42/64 [02:58<03:42, 10.10s/it]
# Processed prompts:  67%|██████▋   | 43/64 [03:20<04:44, 13.57s/it]
# Processed prompts:  69%|██████▉   | 44/64 [03:26<03:43, 11.18s/it]
# Processed prompts:  70%|███████   | 45/64 [03:30<02:54,  9.18s/it]
# Processed prompts:  72%|███████▏  | 46/64 [03:37<02:32,  8.45s/it]
# Processed prompts:  73%|███████▎  | 47/64 [03:39<01:51,  6.59s/it]
# Processed prompts:  75%|███████▌  | 48/64 [03:39<01:14,  4.67s/it]
# Processed prompts:  77%|███████▋  | 49/64 [03:51<01:39,  6.63s/it]
# Processed prompts:  78%|███████▊  | 50/64 [04:00<01:42,  7.34s/it]
# Processed prompts:  80%|███████▉  | 51/64 [04:00<01:09,  5.32s/it]
# Processed prompts:  81%|████████▏ | 52/64 [04:01<00:48,  4.00s/it]
# Processed prompts:  84%|████████▍ | 54/64 [04:05<00:31,  3.13s/it]
# Processed prompts:  86%|████████▌ | 55/64 [04:08<00:27,  3.03s/it]
# Processed prompts:  88%|████████▊ | 56/64 [04:09<00:20,  2.51s/it]
# Processed prompts:  89%|████████▉ | 57/64 [04:09<00:13,  1.89s/it]
# Processed prompts:  91%|█████████ | 58/64 [04:13<00:14,  2.48s/it]
# Processed prompts:  92%|█████████▏| 59/64 [04:14<00:09,  1.97s/it]
# Processed prompts:  94%|█████████▍| 60/64 [04:19<00:11,  2.82s/it]
# Processed prompts:  95%|█████████▌| 61/64 [04:21<00:08,  2.69s/it]
# Processed prompts:  97%|█████████▋| 62/64 [04:22<00:04,  2.18s/it]
# Processed prompts:  98%|█████████▊| 63/64 [04:24<00:01,  1.94s/it]
# Processed prompts: 100%|██████████| 64/64 [04:25<00:00,  4.14s/it]
#  96%|█████████▌| 96/100 [7:18:56<17:16, 259.15s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:43<45:16, 43.11s/it]
# Processed prompts:   3%|▎         | 2/64 [00:47<21:04, 20.39s/it]
# Processed prompts:   5%|▍         | 3/64 [00:51<12:57, 12.75s/it]
# Processed prompts:   6%|▋         | 4/64 [00:54<08:54,  8.90s/it]
# Processed prompts:   8%|▊         | 5/64 [00:55<05:53,  5.99s/it]
# Processed prompts:  11%|█         | 7/64 [01:00<04:06,  4.32s/it]
# Processed prompts:  14%|█▍        | 9/64 [01:05<03:12,  3.51s/it]
# Processed prompts:  16%|█▌        | 10/64 [01:06<02:35,  2.88s/it]
# Processed prompts:  17%|█▋        | 11/64 [01:09<02:34,  2.92s/it]
# Processed prompts:  20%|██        | 13/64 [01:14<02:23,  2.81s/it]
# Processed prompts:  22%|██▏       | 14/64 [01:17<02:22,  2.85s/it]
# Processed prompts:  23%|██▎       | 15/64 [01:20<02:25,  2.96s/it]
# Processed prompts:  25%|██▌       | 16/64 [01:25<02:44,  3.43s/it]
# Processed prompts:  27%|██▋       | 17/64 [01:29<02:50,  3.63s/it]
# Processed prompts:  28%|██▊       | 18/64 [01:32<02:35,  3.38s/it]
# Processed prompts:  30%|██▉       | 19/64 [01:35<02:29,  3.31s/it]
# Processed prompts:  31%|███▏      | 20/64 [01:40<02:44,  3.73s/it]
# Processed prompts:  33%|███▎      | 21/64 [01:43<02:28,  3.45s/it]
# Processed prompts:  34%|███▍      | 22/64 [01:45<02:17,  3.26s/it]
# Processed prompts:  36%|███▌      | 23/64 [01:49<02:18,  3.39s/it]
# Processed prompts:  38%|███▊      | 24/64 [01:54<02:32,  3.81s/it]
# Processed prompts:  39%|███▉      | 25/64 [01:57<02:15,  3.48s/it]
# Processed prompts:  41%|████      | 26/64 [02:13<04:43,  7.45s/it]
# Processed prompts:  42%|████▏     | 27/64 [03:47<20:34, 33.36s/it]
# Processed prompts:  44%|████▍     | 28/64 [04:01<16:25, 27.38s/it]
# Processed prompts:  45%|████▌     | 29/64 [04:10<12:52, 22.07s/it]
# Processed prompts:  47%|████▋     | 30/64 [04:14<09:18, 16.44s/it]
# Processed prompts:  48%|████▊     | 31/64 [04:16<06:43, 12.24s/it]
# Processed prompts:  50%|█████     | 32/64 [04:21<05:21, 10.06s/it]
# Processed prompts:  52%|█████▏    | 33/64 [04:27<04:33,  8.82s/it]
# Processed prompts:  53%|█████▎    | 34/64 [04:31<03:40,  7.34s/it]
# Processed prompts:  55%|█████▍    | 35/64 [04:35<03:04,  6.35s/it]
# Processed prompts:  56%|█████▋    | 36/64 [04:37<02:20,  5.02s/it]
# Processed prompts:  58%|█████▊    | 37/64 [04:40<02:00,  4.48s/it]
# Processed prompts:  61%|██████    | 39/64 [04:44<01:22,  3.30s/it]
# Processed prompts:  62%|██████▎   | 40/64 [04:45<01:07,  2.80s/it]
# Processed prompts:  64%|██████▍   | 41/64 [04:48<01:02,  2.73s/it]
# Processed prompts:  66%|██████▌   | 42/64 [04:53<01:16,  3.48s/it]
# Processed prompts:  67%|██████▋   | 43/64 [04:54<00:56,  2.68s/it]
# Processed prompts:  70%|███████   | 45/64 [04:59<00:49,  2.61s/it]
# Processed prompts:  72%|███████▏  | 46/64 [05:03<00:54,  3.03s/it]
# Processed prompts:  73%|███████▎  | 47/64 [05:13<01:22,  4.86s/it]
# Processed prompts:  75%|███████▌  | 48/64 [05:29<02:03,  7.73s/it]
# Processed prompts:  77%|███████▋  | 49/64 [05:33<01:41,  6.76s/it]
# Processed prompts:  78%|███████▊  | 50/64 [05:43<01:46,  7.59s/it]
# Processed prompts:  80%|███████▉  | 51/64 [05:44<01:14,  5.70s/it]
# Processed prompts:  81%|████████▏ | 52/64 [06:26<03:16, 16.41s/it]
# Processed prompts:  83%|████████▎ | 53/64 [06:33<02:27, 13.42s/it]
# Processed prompts:  84%|████████▍ | 54/64 [06:39<01:52, 11.20s/it]
# Processed prompts:  86%|████████▌ | 55/64 [06:40<01:14,  8.26s/it]
# Processed prompts:  88%|████████▊ | 56/64 [06:45<00:58,  7.30s/it]
# Processed prompts:  89%|████████▉ | 57/64 [06:57<01:01,  8.84s/it]
# Processed prompts:  91%|█████████ | 58/64 [06:58<00:38,  6.50s/it]
# Processed prompts:  92%|█████████▏| 59/64 [06:59<00:24,  4.82s/it]
# Processed prompts:  94%|█████████▍| 60/64 [07:10<00:26,  6.61s/it]
# Processed prompts:  95%|█████████▌| 61/64 [07:11<00:14,  4.96s/it]
# Processed prompts:  97%|█████████▋| 62/64 [07:14<00:08,  4.25s/it]
# Processed prompts:  98%|█████████▊| 63/64 [07:20<00:04,  4.75s/it]
# Processed prompts: 100%|██████████| 64/64 [08:14<00:00,  7.72s/it]
#  98%|█████████▊| 98/100 [7:27:36<08:38, 259.44s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:40<42:40, 40.65s/it]
# Processed prompts:   3%|▎         | 2/64 [00:45<19:59, 19.35s/it]
# Processed prompts:   5%|▍         | 3/64 [00:49<12:33, 12.36s/it]
# Processed prompts:   6%|▋         | 4/64 [00:52<08:39,  8.66s/it]
# Processed prompts:   8%|▊         | 5/64 [00:55<06:39,  6.77s/it]
# Processed prompts:   9%|▉         | 6/64 [00:58<05:17,  5.47s/it]
# Processed prompts:  12%|█▎        | 8/64 [01:04<04:03,  4.35s/it]
# Processed prompts:  14%|█▍        | 9/64 [01:08<03:53,  4.24s/it]
# Processed prompts:  16%|█▌        | 10/64 [01:09<02:49,  3.15s/it]
# Processed prompts:  17%|█▋        | 11/64 [01:18<04:14,  4.81s/it]
# Processed prompts:  19%|█▉        | 12/64 [01:20<03:40,  4.24s/it]
# Processed prompts:  20%|██        | 13/64 [01:24<03:19,  3.92s/it]
# Processed prompts:  22%|██▏       | 14/64 [01:27<03:06,  3.73s/it]
# Processed prompts:  25%|██▌       | 16/64 [01:32<02:39,  3.32s/it]
# Processed prompts:  27%|██▋       | 17/64 [01:36<02:38,  3.37s/it]
# Processed prompts:  28%|██▊       | 18/64 [01:44<03:31,  4.60s/it]
# Processed prompts:  30%|██▉       | 19/64 [01:46<02:55,  3.90s/it]
# Processed prompts:  31%|███▏      | 20/64 [01:52<03:13,  4.39s/it]
# Processed prompts:  33%|███▎      | 21/64 [01:56<03:10,  4.44s/it]
# Processed prompts:  34%|███▍      | 22/64 [01:58<02:34,  3.67s/it]
# Processed prompts:  36%|███▌      | 23/64 [02:04<03:00,  4.40s/it]
# Processed prompts:  38%|███▊      | 24/64 [02:14<03:53,  5.84s/it]
# Processed prompts:  39%|███▉      | 25/64 [02:19<03:39,  5.63s/it]
# Processed prompts:  41%|████      | 26/64 [02:23<03:22,  5.32s/it]
# Processed prompts:  44%|████▍     | 28/64 [02:32<02:51,  4.77s/it]
# Processed prompts:  45%|████▌     | 29/64 [02:43<03:44,  6.42s/it]
# Processed prompts:  47%|████▋     | 30/64 [02:44<02:51,  5.04s/it]
# Processed prompts:  48%|████▊     | 31/64 [03:05<05:12,  9.46s/it]
# Processed prompts:  50%|█████     | 32/64 [03:27<06:51, 12.86s/it]
# Processed prompts:  52%|█████▏    | 33/64 [03:33<05:36, 10.84s/it]
# Processed prompts:  53%|█████▎    | 34/64 [03:36<04:16,  8.55s/it]
# Processed prompts:  55%|█████▍    | 35/64 [03:48<04:42,  9.74s/it]
# Processed prompts:  56%|█████▋    | 36/64 [03:59<04:35,  9.85s/it]
# Processed prompts:  58%|█████▊    | 37/64 [04:04<03:51,  8.56s/it]
# Processed prompts:  59%|█████▉    | 38/64 [04:06<02:48,  6.47s/it]
# Processed prompts:  61%|██████    | 39/64 [04:09<02:16,  5.44s/it]
# Processed prompts:  62%|██████▎   | 40/64 [04:11<01:45,  4.40s/it]
# Processed prompts:  64%|██████▍   | 41/64 [04:15<01:43,  4.49s/it]
# Processed prompts:  66%|██████▌   | 42/64 [04:17<01:23,  3.77s/it]
# Processed prompts:  67%|██████▋   | 43/64 [04:20<01:12,  3.44s/it]
# Processed prompts:  69%|██████▉   | 44/64 [04:21<00:51,  2.60s/it]
# Processed prompts:  72%|███████▏  | 46/64 [04:22<00:31,  1.77s/it]
# Processed prompts:  73%|███████▎  | 47/64 [04:23<00:27,  1.63s/it]
# Processed prompts:  75%|███████▌  | 48/64 [04:25<00:24,  1.51s/it]
# Processed prompts:  77%|███████▋  | 49/64 [04:25<00:18,  1.20s/it]
# Processed prompts:  78%|███████▊  | 50/64 [04:26<00:15,  1.10s/it]
# Processed prompts:  80%|███████▉  | 51/64 [04:26<00:11,  1.17it/s]
# Processed prompts:  81%|████████▏ | 52/64 [04:27<00:09,  1.30it/s]
# Processed prompts:  83%|████████▎ | 53/64 [04:28<00:10,  1.02it/s]
# Processed prompts:  84%|████████▍ | 54/64 [04:29<00:09,  1.09it/s]
# Processed prompts:  86%|████████▌ | 55/64 [04:30<00:08,  1.03it/s]
# Processed prompts:  88%|████████▊ | 56/64 [04:31<00:07,  1.04it/s]
# Processed prompts:  89%|████████▉ | 57/64 [04:32<00:06,  1.08it/s]
# Processed prompts:  91%|█████████ | 58/64 [04:34<00:08,  1.46s/it]
# Processed prompts:  92%|█████████▏| 59/64 [04:52<00:31,  6.26s/it]
# Processed prompts:  94%|█████████▍| 60/64 [04:53<00:18,  4.70s/it]
# Processed prompts:  95%|█████████▌| 61/64 [04:57<00:13,  4.45s/it]
# Processed prompts:  97%|█████████▋| 62/64 [05:08<00:13,  6.53s/it]
# Processed prompts:  98%|█████████▊| 63/64 [05:10<00:04,  4.98s/it]
# Processed prompts: 100%|██████████| 64/64 [06:07<00:00,  5.74s/it]
# 100%|██████████| 100/100 [7:34:04<00:00, 272.44s/it]
# Processed prompts: 100%|██████████| 51/51 [03:11<00:00,  3.75s/it]
# Processed prompts: 100%|██████████| 25/25 [02:19<00:00,  5.57s/it]
# Processed prompts: 100%|██████████| 1/1 [00:05<00:00,  5.79s/it]
# CPU times: user 7h 10min 56s, sys: 5min 12s, total: 7h 16min 8s
# Wall time: 7h 39min 57s

# %% [markdown]
# ## Write to submission file

# %%
for id, answer in boxed_answers.items():
    submission.writerow([id, answer])

# %% [markdown]
# ## Close files

# %%
   
file.close()
log_file.close()

# %% [markdown]
# Combined Prompts inference

# %%
# import pandas as pd
# import torch

# # Load the CSV file with problems and prompts
# df = pd.read_csv("/kaggle/input/dlsprint3/test.csv")

# # Specify the ID of the test problem (change as needed)
# test_id = 7  # Example test case ID
# test_problem = df.loc[test_id, 'Problem']
# #similar_problems_solutions = df.loc[test_id, 'prompts']  # Get the related problems and solutions
# print(test_problem)

# # Create the prompt for the model
# prompt = f"""Here is a math problem in Bengali:
# {test_problem}. Here is a problem.)
# The answer is a non-negative integer. Please reason step by step to solve the problem above. 
# Put your final integer answer within \\boxed{{}}."""

# prompts = [{"role": "system", "content": "You are a helpful math assistant."},{"role": "user", "content": prompt}]

# # Tokenize the input prompt
# tokens = tokenizer.apply_chat_template(
#             prompts,
#             tokenize=False,
#             add_generation_prompt=True
#         )

# # Generate the solution using the model
# generated_solution = llm.generate(tokens,sampling_params)

# # Output the generated solution
# print(f"Generated solution for test problem {test_id}:")
# print(generated_solution[0].outputs[0].text)

# %%
# import pandas as pd

# # Load the CSV file
# df = pd.read_csv("pruned_prompts.csv")

# # Define a function to prune the 5th problem and its solution from each 'prompts' entry
# def prune_fifth_problem(prompts_text):
#     # Split the prompts into individual problems/solutions
#     problems = prompts_text.split("Problem:")
    
#     # Check if there are at least 5 problems
#     if len(problems) > 2:
#         # Remove the 5th problem (index 5 is actually the 6th element, as index starts from 0)
#         del problems[2]
        
#     # Rejoin the remaining problems and solutions
#     return "Problem:".join(problems)

# # Apply the function to the 'prompts' column
# df['prompts'] = df['prompts'].apply(prune_fifth_problem)

# # Now the 'pruned_prompts' column contains the updated text with the 5th problem removed
# print(df[['ID', 'prompts']].head())  # Display the updated prompts for the first few rows

# # You can save the updated DataFrame to a new CSV if needed
# # df.to_csv("pruned_prompts.csv", index=False)

# %%
# df.to_csv("pruned_prompts.csv", index=False)

# %%
# df['prompts'] = df['prompts'].str.replace("Here are a list of math problems and solutions:", "", regex=False)

# # Display the updated DataFrame to confirm the string has been removed
# print(df.head())

# %%
# df.to_csv("pruned_prompts.csv", index=False)
