# %% [markdown]
# # Setup

# %% [markdown]
# ## Make both T4 GPUs visiable to CUDA

# %%
import os, math, numpy as np
os.environ["CUDA_VISIBLE_DEVICES"]="0,1"

# %% [markdown]
# ## Install vLLM

# %%
# %%time
# !pip uninstall -y torch
# !pip install -U --no-index --find-links=/kaggle/input/vllm-whl -U vllm
# !pip install -U --upgrade /kaggle/input/vllm-t4-fix/grpcio-1.62.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# !pip install -U --upgrade /kaggle/input/vllm-t4-fix/ray-2.11.0-cp310-cp310-manylinux2014_x86_64.whl
# Out:
# Found existing installation: torch 2.4.0
# Uninstalling torch-2.4.0:
#   Successfully uninstalled torch-2.4.0
# Looking in links: /kaggle/input/vllm-whl
# Processing /kaggle/input/vllm-whl/vllm-0.4.0.post1-cp310-cp310-manylinux1_x86_64.whl
# Processing /kaggle/input/vllm-whl/cmake-3.29.0.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from vllm)
# Requirement already satisfied: ninja in /opt/conda/lib/python3.10/site-packages (from vllm) (1.11.1.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from vllm) (5.9.3)
# Requirement already satisfied: ray>=2.9 in /opt/conda/lib/python3.10/site-packages (from vllm) (2.24.0)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from vllm) (0.2.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from vllm) (1.26.4)
# Processing /kaggle/input/vllm-whl/torch-2.1.2-cp310-cp310-manylinux1_x86_64.whl (from vllm)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from vllm) (2.32.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from vllm) (9.0.0)
# Requirement already satisfied: transformers>=4.39.1 in /opt/conda/lib/python3.10/site-packages (from vllm) (4.45.1)
# Processing /kaggle/input/vllm-whl/xformers-0.0.23.post1-cp310-cp310-manylinux2014_x86_64.whl (from vllm)
# Requirement already satisfied: fastapi in /opt/conda/lib/python3.10/site-packages (from vllm) (0.111.0)
# Requirement already satisfied: uvicorn[standard] in /opt/conda/lib/python3.10/site-packages (from vllm) (0.30.1)
# Requirement already satisfied: pydantic>=2.0 in /opt/conda/lib/python3.10/site-packages (from vllm) (2.9.2)
# Requirement already satisfied: prometheus-client>=0.18.0 in /opt/conda/lib/python3.10/site-packages (from vllm) (0.20.0)
# Processing /kaggle/input/vllm-whl/pynvml-11.5.0-py3-none-any.whl (from vllm)
# Processing /kaggle/input/vllm-whl/triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from vllm)
# Processing /kaggle/input/vllm-whl/outlines-0.0.34-py3-none-any.whl (from vllm)
# Processing /kaggle/input/vllm-whl/tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from vllm)
# Processing /kaggle/input/vllm-whl/interegular-0.3.3-py37-none-any.whl (from outlines==0.0.34->vllm)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from outlines==0.0.34->vllm) (3.1.4)
# Processing /kaggle/input/vllm-whl/lark-1.1.9-py3-none-any.whl (from outlines==0.0.34->vllm)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from outlines==0.0.34->vllm) (1.6.0)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.10/site-packages (from outlines==0.0.34->vllm) (3.0.0)
# Processing /kaggle/input/vllm-whl/diskcache-5.6.3-py3-none-any.whl (from outlines==0.0.34->vllm)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from outlines==0.0.34->vllm) (1.14.1)
# Requirement already satisfied: numba in /opt/conda/lib/python3.10/site-packages (from outlines==0.0.34->vllm) (0.60.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from outlines==0.0.34->vllm) (1.4.2)
# Requirement already satisfied: referencing in /opt/conda/lib/python3.10/site-packages (from outlines==0.0.34->vllm) (0.35.1)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.10/site-packages (from outlines==0.0.34->vllm) (4.22.0)
# Requirement already satisfied: regex>=2022.1.18 in /opt/conda/lib/python3.10/site-packages (from tiktoken==0.6.0->vllm) (2024.5.15)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->vllm) (3.15.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->vllm) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->vllm) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->vllm) (3.3)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->vllm) (2024.6.1)
# Processing /kaggle/input/vllm-whl/nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from torch==2.1.2->vllm)
# Processing /kaggle/input/vllm-whl/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.2->vllm)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2.0->vllm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2.0->vllm) (2.23.4)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from ray>=2.9->vllm) (8.1.7)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ray>=2.9->vllm) (1.0.8)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ray>=2.9->vllm) (21.3)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /opt/conda/lib/python3.10/site-packages (from ray>=2.9->vllm) (3.20.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from ray>=2.9->vllm) (6.0.2)
# Requirement already satisfied: aiosignal in /opt/conda/lib/python3.10/site-packages (from ray>=2.9->vllm) (1.3.1)
# Requirement already satisfied: frozenlist in /opt/conda/lib/python3.10/site-packages (from ray>=2.9->vllm) (1.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->vllm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->vllm) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->vllm) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->vllm) (2024.8.30)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.39.1->vllm) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.39.1->vllm) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.39.1->vllm) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.39.1->vllm) (4.66.4)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /opt/conda/lib/python3.10/site-packages (from fastapi->vllm) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /opt/conda/lib/python3.10/site-packages (from fastapi->vllm) (0.0.4)
# Requirement already satisfied: httpx>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from fastapi->vllm) (0.27.0)
# Requirement already satisfied: python-multipart>=0.0.7 in /opt/conda/lib/python3.10/site-packages (from fastapi->vllm) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from fastapi->vllm) (5.10.0)
# Requirement already satisfied: orjson>=3.2.1 in /opt/conda/lib/python3.10/site-packages (from fastapi->vllm) (3.10.4)
# Requirement already satisfied: email_validator>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from fastapi->vllm) (2.1.1)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]->vllm) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]->vllm) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]->vllm) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]->vllm) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]->vllm) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]->vllm) (12.0)
# Requirement already satisfied: dnspython>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from email_validator>=2.0.0->fastapi->vllm) (2.6.1)
# Requirement already satisfied: typer>=0.12.3 in /opt/conda/lib/python3.10/site-packages (from fastapi-cli>=0.0.2->fastapi->vllm) (0.12.3)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx>=0.23.0->fastapi->vllm) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx>=0.23.0->fastapi->vllm) (1.0.5)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx>=0.23.0->fastapi->vllm) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->outlines==0.0.34->vllm) (2.1.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->ray>=2.9->vllm) (3.1.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema->outlines==0.0.34->vllm) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema->outlines==0.0.34->vllm) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema->outlines==0.0.34->vllm) (0.18.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba->outlines==0.0.34->vllm) (0.43.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch==2.1.2->vllm) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio->httpx>=0.23.0->fastapi->vllm) (1.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->vllm) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/conda/lib/python3.10/site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->vllm) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->vllm) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->vllm) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->vllm) (0.1.2)
# Installing collected packages: triton, pynvml, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lark, interegular, diskcache, cmake, tiktoken, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, xformers, outlines, vllm
#   Attempting uninstall: pynvml
#     Found existing installation: pynvml 11.4.1
#     Uninstalling pynvml-11.4.1:
#       Successfully uninstalled pynvml-11.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ucxx 0.39.1 requires libucx>=1.15.0, which is not installed.
# dask-cuda 24.8.2 requires pynvml<11.5,>=11.0.0, but you have pynvml 11.5.0 which is incompatible.
# Successfully installed cmake-3.29.0.1 diskcache-5.6.3 interegular-0.3.3 lark-1.1.9 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 outlines-0.0.34 pynvml-11.5.0 tiktoken-0.6.0 torch-2.1.2 triton-2.1.0 vllm-0.4.0.post1 xformers-0.0.23.post1
# Processing /kaggle/input/vllm-t4-fix/grpcio-1.62.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# grpcio is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Processing /kaggle/input/vllm-t4-fix/ray-2.11.0-cp310-cp310-manylinux2014_x86_64.whl
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (8.1.7)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (3.15.1)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (4.22.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (1.0.8)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (21.3)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (3.20.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (6.0.2)
# Requirement already satisfied: aiosignal in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (1.3.1)
# Requirement already satisfied: frozenlist in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (1.4.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from ray==2.11.0) (2.32.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray==2.11.0) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray==2.11.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray==2.11.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema->ray==2.11.0) (0.18.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->ray==2.11.0) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.11.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.11.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.11.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->ray==2.11.0) (2024.8.30)
# Installing collected packages: ray
#   Attempting uninstall: ray
#     Found existing installation: ray 2.24.0
#     Uninstalling ray-2.24.0:
#       Successfully uninstalled ray-2.24.0
# Successfully installed ray-2.11.0
# CPU times: user 1.85 s, sys: 452 ms, total: 2.3 s
# Wall time: 2min 35s

# %% [markdown]
# ## Some Configuration

# %%
# In DEBUG mode, infer only on 5 problems
DEBUG = False
# Number of candidate solutions to generate
K = 20
DEPTH = 4
TEMPERATURE = 0.5
TOP_P = 0.9
BATCH_SIZE = 64

# %% [markdown]
# # Imports

# %%
import vllm
import re
import csv
import torch
import gc
from tqdm import tqdm
import pandas as pd
from queue import Queue, Empty
import os
import re
import signal
import subprocess
import tempfile
from collections import Counter
from contextlib import contextmanager

import threading
from concurrent.futures import ThreadPoolExecutor, as_completed
# Out:
# 2024-10-27 08:45:46,469	INFO util.py:124 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.

# %% [markdown]
# # Python Code Execution Environment

# %%
1
# Out:
# 1

# %% [markdown]
# ## Find Python code blocks within text

# %%
def find_python_blocks(text):
    blocks = re.findall(r"(```python.*?```)", text, re.DOTALL)
    # filter blocks by trying to convert them to float or int
    filtered_blocks = []
    for block in blocks:
        code = block[len("```python"):-len("```")].strip()
        try:
            x = int(code)
        except:
            filtered_blocks.append(code)
            continue
        try:
            x = float(code)
        except:
            filtered_blocks.append(code)
    return filtered_blocks

# %% [markdown]
# ## Class to Execute Python code (adopted from Numina)

# %%
class PythonREPL:
    def __init__(self, timeout=5):
        self.timeout = timeout
    # handles timeout
    @contextmanager
    def time_limit(self, seconds):
        def signal_handler(*_):
            raise TimeoutError(f"Timed out after {seconds} seconds.")

        signal.signal(signal.SIGALRM, signal_handler)
        signal.alarm(seconds)
        try:
            yield
        finally:
            signal.alarm(0)

    def __call__(self, query):
        query = "import math\nimport numpy as np\nimport sympy as sp\n" + query
        query = query.strip().split("\n")
        if "print(" not in query[-1]:
            if "#" in query[-1]:
                query[-1] = query[-1].split("#")[0]
            query[-1] = "print(" + query[-1] + ")"
        query = "\n".join(query)
        with tempfile.TemporaryDirectory() as temp_dir:
            temp_file_path = os.path.join(temp_dir, "tmp.py")
            with open(temp_file_path, "w", encoding="utf-8") as f:
                f.write(query)
            with self.time_limit(self.timeout):
                result = subprocess.run(
                    ["python3", temp_file_path],
                    capture_output=True,
                    check=False,
                    text=True,
                    timeout=self.timeout,
                )
                if result.returncode == 0:
                    output = result.stdout
                    return True, output.strip()
                error_msg = result.stderr.strip()
                msgs = error_msg.split("\n")
                new_msgs = []
                want_next = False
                for m in msgs:
                    if "Traceback" in m:
                        new_msgs.append(m)
                    elif m == msgs[-1]:
                        new_msgs.append(m)
                    elif temp_file_path in m:
                        st = m.index('"/') + 1 if '"/' in m else 0
                        ed = m.index(temp_file_path) + 1 if temp_file_path in m else None
                        clr = m[st:ed] if not ed else m[st:]
                        m = m.replace(clr, "")
                        new_msgs.append(m)
                        want_next = True
                    elif want_next:
                        new_msgs.append(m)
                        want_next = False
                error_msg = "\n".join(new_msgs)
                return False, error_msg.strip()

# %% [markdown]
# ## Execute a Python code block

# %%
def execute(executor, code):
    success = False
    for lib in ("subprocess", "venv"):
        if lib in code:
            output = f"{lib} is not allowed"
            outputs.append(output)
            successes.append(success)
            continue
    try:
        success, output = executor(code)
    except TimeoutError as e:
        output = str(e)

    output = output.strip()
    
    return output, success

# %% [markdown]
# ## Test by running some python code

# %%
text = """Block 1
```python
s = 0
for i in range(100):
    s += i
print(s)
```
Block 2
```python
2**12
```
Block 3
```python
3
```
"""

# %%
blocks = find_python_blocks(text)
blocks
# Out:
# ['s = 0\nfor i in range(100):\n    s += i\nprint(s)', '2**12']

# %%
executor = PythonREPL()
outputs = [execute(executor, block) for block in blocks]
outputs
# Out:
# [('4950', True), ('4096', True)]

# %%
# for block, output in zip(blocks, outputs):
#     print(f"""
# ```python
# {block}
# ```
# ```output
# {output[0]}
# ```"""
#     )

# %% [markdown]
# # Load Model on vLLM

# %% [markdown]
# ## We use the Qwen 2.5 7b Instruct Model here by Alibaba. You should explore other models.

# %%
llm = vllm.LLM(
    "AI-MO/NuminaMath-7B-TIR",
    tensor_parallel_size=2, 
    gpu_memory_utilization=0.95, 
    trust_remote_code=True,
    dtype="half", 
    enforce_eager=True,
    max_model_len=4096,
)
tokenizer = llm.get_tokenizer()
# Out:
# config.json:   0%|          | 0.00/716 [00:00<?, ?B/s]
# WARNING 10-27 08:45:50 config.py:767] Casting torch.bfloat16 to torch.float16.
# 2024-10-27 08:45:53,097	INFO worker.py:1749 -- Started a local Ray instance.
# INFO 10-27 08:45:54 llm_engine.py:74] Initializing an LLM engine (v0.4.0.post1) with config: model='AI-MO/NuminaMath-7B-TIR', tokenizer='AI-MO/NuminaMath-7B-TIR', tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.float16, max_seq_len=4096, download_dir=None, load_format=auto, tensor_parallel_size=2, disable_custom_all_reduce=True, quantization=None, enforce_eager=True, kv_cache_dtype=auto, device_config=cuda, seed=0)
# tokenizer_config.json:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/4.61M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# INFO 10-27 08:46:03 selector.py:40] Cannot use FlashAttention backend for Volta and Turing GPUs.
# INFO 10-27 08:46:03 selector.py:25] Using XFormers backend.
# (RayWorkerVllm pid=364) INFO 10-27 08:46:04 selector.py:40] Cannot use FlashAttention backend for Volta and Turing GPUs.
# (RayWorkerVllm pid=364) INFO 10-27 08:46:04 selector.py:25] Using XFormers backend.
# INFO 10-27 08:46:05 pynccl_utils.py:45] vLLM is using nccl==2.18.1
# (RayWorkerVllm pid=364) INFO 10-27 08:46:05 pynccl_utils.py:45] vLLM is using nccl==2.18.1
# INFO 10-27 08:46:05 weight_utils.py:177] Using model weights format ['*.safetensors']
# (RayWorkerVllm pid=364) INFO 10-27 08:46:06 weight_utils.py:177] Using model weights format ['*.safetensors']
# model-00003-of-00003.safetensors:   0%|          | 0.00/3.85G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# INFO 10-27 08:48:29 model_runner.py:104] Loading model weights took 6.4663 GB
# (RayWorkerVllm pid=364) INFO 10-27 08:48:32 model_runner.py:104] Loading model weights took 6.4663 GB
# INFO 10-27 08:48:34 ray_gpu_executor.py:240] # GPU blocks: 1755, # CPU blocks: 1092

# %% [markdown]
# # Utilites

# %% [markdown]
# ## Extract boxed answer

# %%
def extract_answer(text):
    # find right most boxed answer
    def last_boxed_only_string(text):
        idx = text.rfind("\\boxed")
        if idx < 0:
            idx = text.rfind("\\fbox")
            if idx < 0:
                return None
        i = idx
        right_brace_idx = None
        num_left_braces_open = 0
        while i < len(text):
            if text[i] == "{":
                num_left_braces_open += 1
            if text[i] == "}":
                num_left_braces_open -= 1
                if num_left_braces_open == 0:
                    right_brace_idx = i
                    break
            i += 1
        if right_brace_idx is None:
            return None
        return text[idx : right_brace_idx + 1]
    # get content of boxed
    def remove_boxed(boxed):
        left = "\\boxed{"
        try:
            assert boxed[: len(left)] == left
            assert boxed[-1] == "}"
            length = len(left)
            return boxed[length:-1]
        except Exception:
            return None

    boxed = last_boxed_only_string(text)
    if boxed is None:
        return None
    answer = remove_boxed(boxed)
    return answer

# %% [markdown]
# ## Majority vote (select the most occuring answer)

# %%
# Define the majority voting function to get the most common answer
def majority_vote(answers):
    answers = [answer for answer in answers if answer is not None]

    if not answers:
        return None
    # count the occurence of each answer
    counts = {}
    for answer in answers:
        if answer in counts:
            counts[answer] += 1
        else:
            counts[answer] = 1

    max_answer = None
    max_count = 0
    
    for answer, count in counts.items():
        if count > max_count:
            max_answer = answer
            max_count = count
    
    return max_answer

# %% [markdown]
# # TIR Agent

# %%
# class TIRAgent:
#     def __init__(self, problem_id, id, problem, tokenizer, max_depth, log):
#         # problem id
#         self.problem_id = problem_id
#         # id of the agent
#         self.id = id
#         # number of LLM turns
#         self.depth = 1
#         # maximum number of turns allowed
#         self.max_depth = max_depth
#         # LLM's tokenizer
#         self.tokenizer = tokenizer
#         # Problem statement
#         self.problem = problem
#         # Chat Messages
#         self.messages = [
#             {
#                "role": "user", 
#                 "content": f"""Here is a math problem:
# {self.problem}
# Please solve the problem step by step, providing Python code at each step to verify your reasoning.
# Break your reasoning into:
# 1. Problem understanding.
# 2. Step-by-step logical breakdown.
# 3. Python code to verify.
# Finally, provide the non-negative integer answer within \\boxed{{}}."""
#             }
#         ]
#         # Last response from the LLM
#         self.last_response = None
#         # Code blocks from the last response
#         self.blocks = []
#         # Answers that the LLM generated in \boxed{}
#         self.answers = []
#         # No python code generated in last response or max_depth reached
#         self.is_complete = False
#         # File to log answers
#         self.log = log
#         # Next prompt to the LLM
#         self.next_prompt = None
        
#     def complete(self):
#         # Is the Agent done
#         return self.is_complete
    
#     def add_response(self, response, executor):
#         self.depth += 1
#         # Remember this response
#         self.last_response = response
#         # Add this to the messages history
#         self.messages.append({"role": "assistant", "content": response})
#         # Extract python blocks
#         self.blocks = find_python_blocks(response)
#         # Extract answer from the generated text, if present
#         answer = extract_answer(response)
#         if answer is not None:
#             self.answers.append(answer)
#         # Is it done?
#         self.is_complete = not self._should_continue()
#         # If not, use the python executor to create next prompt
#         if not self.is_complete:
#             self.next_prompt = self._next_prompt(executor)   
#             self.messages.append({"role": "user", "content": self.next_prompt})
    
#     def _should_continue(self):        
#         # Quit if max_depth number of turns reached
#         if self.depth >= self.max_depth:
#             return False
#         # If python code is generated, we can continue
#         elif len(self.blocks) > 0:
#             return True
#         return False
    
#     def _next_prompt(self, executor):
#         assert not self.is_complete
#         assert len(self.blocks) > 0
#         # Get code result from python execution
#         output, status = execute(executor, self.blocks[-1])
        
#         prompt = ''
#         # If code succeeds, give the output
#         if status:
#             prompt = f"""The Python code you provided executed successfully with the following output:
# ```python
# {self.blocks[-1]}

# ```
# ```output
# {output}
# ```"""
#         # if code fails, give the error
#         else:
#             prompt = f"""The python code you provided gives the following error:
# ```python
# {self.blocks[-1]}
# ```
# ```output
# {output}
# Please review the code, correct any mistakes, and provide a new solution with updated logic and code.
# ```"""
#         if self.depth == self.max_depth - 1:
#             prompt += f"\nSince we are nearing the limit of {self.max_depth} attempts, please finalize your response and double-check all steps."
#         return prompt
    
    
#     def next_message(self):
#         assert not self.is_complete 
#         # apply chat template to get the text
#         text = self.tokenizer.apply_chat_template(
#             self.messages,
#             tokenize=False,
#             add_generation_prompt=True
#         )
        
#         return text
        
    
#     def final_answer(self):
#         # if there no answers yet, we have to return None
#         ans = None
#         # otherwise return the latest answer
#         if len(self.answers) > 0:
#             ans = self.answers[-1]
#         # log to file
#         if self.log:
#             self.log.writerow([self.problem_id, self.id, ans])
#         # try to convert to integer
#         try:
#             ans = int(ans)
#         except:
#             ans = None
        
#         return ans

# %%
class TIRAgent:
    def __init__(self, problem_id, id, problem, tokenizer,max_depth, log):
        # problem id
        self.problem_id = problem_id
        # id of the agent
        self.id = id
        # number of LLM turns
        self.depth = 1
        # maximum number of turns allowed
        self.max_depth = max_depth
        # LLM's tokenizer
        self.tokenizer = tokenizer
        # Problem statement
        self.problem = problem
        # Chat Messages
        self.messages = [
            {
               "role": "user", 
                "content": f"""Here is a math problem in Bengali:
{self.problem}
The answer is a non-negative integer. Please reason step by step to solve the problem above. Provide python code to verify your reasoning.
Put your final integer answer within \\boxed{{}}."""
            }
        ]
        # Last response from the LLM
        self.last_response = None
        # Code blocks from the last response
        self.blocks = []
        # Answers that the LLM generated in \boxed{}
        self.answers = []
        # No python code generated in last response or max_depth reached
        self.is_complete = False
        # File to log answers
        self.log = log
        # Next prompt to the LLM
        self.next_prompt = None
        
    def complete(self):
        # is the Agent done
        return self.is_complete
    
    def add_response(self, response, executor):
        self.depth += 1
        # remember this response
        self.last_response = response
        # add this to the messages history
        self.messages.append({"role": "assistant", "content": response})
        # extract python blocks
        self.blocks = find_python_blocks(response)
        # extract answer from the generated text, if present
        answer = extract_answer(response)
        if answer is not None:
            self.answers.append(answer)
        # is it done?
        self.is_complete = not self._should_continue()
        # if not, use the python executor to create next prompt
        if not self.is_complete:
            self.next_prompt = self._next_prompt(executor)   
            self.messages.append({"role": "user", "content": self.next_prompt})
    
    def _should_continue(self):        
        # quit if max_depth number of turns reached
        if self.depth >= self.max_depth:
            return False
        # if no python code generated, we can stop now
        elif len(self.blocks) > 0:
            return True
        return False
    
    def _next_prompt(self, executor):
        assert not self.is_complete
        assert len(self.blocks) > 0
        # get code result from python execution
        output, status = execute(executor, self.blocks[-1])
        
        prompt = ''
        # if code succeeds give the output
        if status:
            prompt = f"""The python code you provided gives the following output:
```python
{self.blocks[-1]}
```
```output
{output}
```"""
        # if code fails, give the error
        else:
            prompt = f"""The python code you provided gives the following error:
```python
{self.blocks[-1]}
```
```output
{output}
```"""
        return prompt
    
    
    def next_message(self):
        assert not self.is_complete 
        # apply chat template to get the text
        text = self.tokenizer.apply_chat_template(
            self.messages,
            tokenize=False,
            add_generation_prompt=True
        )
        
        return text
        
    
    def final_answer(self):
        # if there no answers yet, we have to return None
        ans = None
        # otherwise return the latest answer
        if len(self.answers) > 0:
            ans = self.answers[-1]
        # log to file
        if self.log:
            self.log.writerow([self.problem_id, self.id, ans])
        # try to convert to integer
        try:
            ans = int(ans)
        except:
            ans = None
        
        return ans

# %% [markdown]
# # Sc-TIR Agent

# %%
class SCTIRAgent:
    def __init__(self, problem_id, problem, tokenizer,samples, max_depth, log):
        # problem id
        self.problem_id = problem_id
        # problem statement
        self.problem = problem
        # LLM's tokenizer
        self.tokenizer = tokenizer
        # number of TIRAgents to create
        self.samples = samples
        # maximum number of turns
        self.max_depth = max_depth
        # TIR Agents
        self.agents = [TIRAgent(problem_id, i, problem, tokenizer, max_depth, log) for i in range(samples)]
        # log file
        self.log = log
    
    def complete(self):
        # only complete when all agents are done
        for agent in self.agents:
            if not agent.complete():
                return False
        return True
        
    def get_ready_agents(self):
        # return agents that are not complete yet
        ready_agents = []
        for agent in self.agents:
            if not agent.complete():
                ready_agents.append(agent)
        return ready_agents
    
    def final_answer(self):
        # majority vote agent answers
        assert self.complete()
        answers = [agent.final_answer() for agent in self.agents]
        answer = majority_vote(answers)
        if answer is None:
            return 0
        return answer

# %% [markdown]
# # Load Test Set

# %%
#test_df = pd.read_csv('/kaggle/input/translated-test-df/translated_test_df.csv')

test_df = pd.read_csv('/kaggle/input/dlsprint3/test.csv')
test_df.sample(5)
# Out:
#     ID                                            Problem
# 26  26  $x$, $y$ এবং $z$ এমন বাস্তব সংখ্যা যেন $(4^x +...
# 86  86  একটি ত্রিভুজের বৃহত্তম কোণ 80° হলে, ক্ষুদ্রতম ...
# 2    2  ধরো $f(x) = x^{67-x^{67-x^{67-\dots}}}$, যেখান...
# 55  55  তোমার কাছে অসীম সংখ্যক 2,3 এবং 4 টাকার নোট রয়ে...
# 75  75  যদি $a = 3$ এবং $r = \frac{1}{3}$ হয়, তাহলে\n\...

# %% [markdown]
# ## Load 5 problems since we are short on time

# %%
# if DEBUG:
#     test_df = test_df[:5]
#     torch.cuda.empty_cache()
#     gc.collect()

# %% [markdown]
# # Configure LLM and Python REPL

# %%
sampling_params = vllm.SamplingParams(max_tokens=2048, temperature=TEMPERATURE, top_p=TOP_P)
executor = PythonREPL()

# %% [markdown]
# # Run the Agents

# %% [markdown]
# ## TIR Agent

# %%
# for row in test_df.values[0:2]:
#     problem_id = row[0]
#     problem = row[1]
    
#     agent = TIRAgent(problem_id, 0, problem, tokenizer, max_depth=4, log=None)
    
#     while not agent.complete():
#         text = agent.next_message()
#         # get response from LLM
#         response = llm.generate([text], sampling_params)
#         # pass in python executor, since response might contain python code
#         agent.add_response(response[0].outputs[0].text, executor)
    
#     for message in agent.messages:
#         print(f"Role: {message['role']}\n")
#         print(f"Content:\n {message['content']}\n")
    
#     answer = agent.final_answer()
#     print(f"Final answer: {answer}")

# %% [markdown]
# ## SC-TIR Agent

# %%
# for row in test_df.values[1:2]:
#     problem_id = row[0]
#     problem = row[1]
    
#     agent = SCTIRAgent(problem_id, problem, tokenizer,samples=6, max_depth=6, log=None)
    
#     while not agent.complete():
#         ready_agents = agent.get_ready_agents()
#         texts = [a.next_message() for a in ready_agents]
#         # get response from LLM
#         responses = llm.generate(texts, sampling_params)
#         # pass response to the agents
#         for i, ready_agent in enumerate(ready_agents):
#             ready_agent.add_response(responses[i].outputs[0].text, executor)
    
#     answer = agent.final_answer()
#     print(f"Problem: {problem}")
#     print(f"Final answer: {answer}")

# %% [markdown]
# # Run Inference

# %% [markdown]
# # Create submission

# %% [markdown]
# ## Also log agent answers

# %%
file = open('NuiminaOldPrompt.csv', 'w', encoding='utf-8')
log_file = open('log.csv', 'w', encoding='utf-8')

submission = csv.writer(file)
log = csv.writer(log_file)

submission.writerow(['ID', 'Answer'])
log.writerow(['ID', "Agent ID", 'Answer'])
# Out:
# 20

# %% [markdown]
# ## Configure LLM sampling parameters and Python REPL

# %% [markdown]
# ## Use a queue to Batch inference

# %%
# %%time

boxed_answers = {}
agents = []

q = Queue()

iterator = iter(tqdm(test_df.values))

while True:
    for agent in agents:
        if agent.complete():
            boxed_answers[agent.problem_id] = agent.final_answer()

    agents[:] = list(filter(lambda a: not a.complete(), agents))

    while q.qsize() < BATCH_SIZE:
        try:
            row = next(iterator)
        except StopIteration:
            break

        id = row[0]
        problem = row[1]

        agent = SCTIRAgent(id, problem, tokenizer, K, DEPTH, log)
        
        agents.append(agent)

        for tir_agent in agent.get_ready_agents():
            q.put_nowait(tir_agent)
            
    if q.empty():
        break
        
    
    ready_agents = []
    texts = []
    for _ in range(BATCH_SIZE):
        try:
            agent = q.get_nowait()
            ready_agents.append(agent)
            texts.append(agent.next_message())
        except:
            break

    
    responses = llm.generate(texts, sampling_params)
    responses = [response.outputs[0].text for response in responses]
    
    for i in range(len(ready_agents)):
        agent = ready_agents[i]
        response = responses[i]
        agent.add_response(response, executor)
        if not agent.complete():
            q.put_nowait(agent)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:31<32:55, 31.36s/it]
# Processed prompts:   3%|▎         | 2/64 [00:37<17:13, 16.67s/it]
# Processed prompts:   5%|▍         | 3/64 [00:38<09:24,  9.25s/it]
# Processed prompts:   6%|▋         | 4/64 [00:38<05:53,  5.89s/it]
# Processed prompts:   8%|▊         | 5/64 [00:39<03:55,  4.00s/it]
# Processed prompts:   9%|▉         | 6/64 [00:40<02:45,  2.86s/it]
# Processed prompts:  11%|█         | 7/64 [00:40<01:56,  2.04s/it]
# Processed prompts:  12%|█▎        | 8/64 [00:41<01:34,  1.69s/it]
# Processed prompts:  14%|█▍        | 9/64 [00:42<01:21,  1.49s/it]
# Processed prompts:  16%|█▌        | 10/64 [00:43<01:08,  1.27s/it]
# Processed prompts:  17%|█▋        | 11/64 [00:43<00:56,  1.06s/it]
# Processed prompts:  19%|█▉        | 12/64 [00:45<00:58,  1.13s/it]
# Processed prompts:  22%|██▏       | 14/64 [00:45<00:36,  1.35it/s]
# Processed prompts:  23%|██▎       | 15/64 [00:46<00:34,  1.44it/s]
# Processed prompts:  25%|██▌       | 16/64 [00:46<00:32,  1.47it/s]
# Processed prompts:  27%|██▋       | 17/64 [00:47<00:28,  1.64it/s]
# Processed prompts:  28%|██▊       | 18/64 [00:48<00:35,  1.31it/s]
# Processed prompts:  30%|██▉       | 19/64 [00:49<00:38,  1.17it/s]
# Processed prompts:  31%|███▏      | 20/64 [00:50<00:36,  1.20it/s]
# Processed prompts:  33%|███▎      | 21/64 [00:50<00:32,  1.33it/s]
# Processed prompts:  34%|███▍      | 22/64 [00:51<00:31,  1.31it/s]
# Processed prompts:  36%|███▌      | 23/64 [00:52<00:30,  1.35it/s]
# Processed prompts:  38%|███▊      | 24/64 [00:53<00:37,  1.06it/s]
# Processed prompts:  39%|███▉      | 25/64 [00:54<00:31,  1.23it/s]
# Processed prompts:  41%|████      | 26/64 [00:55<00:30,  1.26it/s]
# Processed prompts:  42%|████▏     | 27/64 [00:55<00:25,  1.46it/s]
# Processed prompts:  45%|████▌     | 29/64 [00:56<00:24,  1.43it/s]
# Processed prompts:  48%|████▊     | 31/64 [00:57<00:18,  1.81it/s]
# Processed prompts:  50%|█████     | 32/64 [00:58<00:18,  1.70it/s]
# Processed prompts:  52%|█████▏    | 33/64 [00:58<00:16,  1.84it/s]
# Processed prompts:  53%|█████▎    | 34/64 [01:01<00:34,  1.14s/it]
# Processed prompts:  55%|█████▍    | 35/64 [01:02<00:29,  1.02s/it]
# Processed prompts:  56%|█████▋    | 36/64 [01:03<00:27,  1.01it/s]
# Processed prompts:  58%|█████▊    | 37/64 [01:03<00:20,  1.29it/s]
# Processed prompts:  59%|█████▉    | 38/64 [01:03<00:15,  1.68it/s]
# Processed prompts:  61%|██████    | 39/64 [01:04<00:15,  1.57it/s]
# Processed prompts:  62%|██████▎   | 40/64 [01:05<00:16,  1.43it/s]
# Processed prompts:  66%|██████▌   | 42/64 [01:07<00:17,  1.26it/s]
# Processed prompts:  67%|██████▋   | 43/64 [01:07<00:14,  1.47it/s]
# Processed prompts:  69%|██████▉   | 44/64 [01:10<00:24,  1.22s/it]
# Processed prompts:  70%|███████   | 45/64 [01:11<00:21,  1.15s/it]
# Processed prompts:  72%|███████▏  | 46/64 [01:11<00:17,  1.02it/s]
# Processed prompts:  73%|███████▎  | 47/64 [01:12<00:16,  1.04it/s]
# Processed prompts:  75%|███████▌  | 48/64 [01:12<00:12,  1.29it/s]
# Processed prompts:  77%|███████▋  | 49/64 [01:16<00:22,  1.53s/it]
# Processed prompts:  78%|███████▊  | 50/64 [01:18<00:25,  1.81s/it]
# Processed prompts:  80%|███████▉  | 51/64 [01:19<00:20,  1.60s/it]
# Processed prompts:  81%|████████▏ | 52/64 [01:20<00:15,  1.27s/it]
# Processed prompts:  84%|████████▍ | 54/64 [01:20<00:07,  1.36it/s]
# Processed prompts:  86%|████████▌ | 55/64 [01:21<00:07,  1.24it/s]
# Processed prompts:  88%|████████▊ | 56/64 [01:21<00:05,  1.52it/s]
# Processed prompts:  89%|████████▉ | 57/64 [01:23<00:06,  1.16it/s]
# Processed prompts:  91%|█████████ | 58/64 [01:25<00:07,  1.20s/it]
# Processed prompts:  92%|█████████▏| 59/64 [01:26<00:06,  1.30s/it]
# Processed prompts:  94%|█████████▍| 60/64 [01:27<00:04,  1.07s/it]
# Processed prompts:  95%|█████████▌| 61/64 [01:32<00:06,  2.31s/it]
# Processed prompts:  97%|█████████▋| 62/64 [01:34<00:04,  2.26s/it]
# Processed prompts:  98%|█████████▊| 63/64 [01:54<00:07,  7.46s/it]
# Processed prompts: 100%|██████████| 64/64 [02:03<00:00,  1.93s/it]
#
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:12<13:38, 12.99s/it]
# Processed prompts:   3%|▎         | 2/64 [00:13<05:52,  5.69s/it]
# Processed prompts:   5%|▍         | 3/64 [00:15<03:49,  3.76s/it]
# Processed prompts:   6%|▋         | 4/64 [00:15<02:24,  2.41s/it]
# Processed prompts:   8%|▊         | 5/64 [00:17<02:07,  2.16s/it]
# Processed prompts:   9%|▉         | 6/64 [00:18<01:46,  1.83s/it]
# Processed prompts:  11%|█         | 7/64 [00:22<02:26,  2.58s/it]
# Processed prompts:  12%|█▎        | 8/64 [00:29<03:53,  4.18s/it]
# Processed prompts:  14%|█▍        | 9/64 [00:31<03:03,  3.34s/it]
# Processed prompts:  16%|█▌        | 10/64 [00:38<03:56,  4.38s/it]
# Processed prompts:  17%|█▋        | 11/64 [00:39<02:59,  3.39s/it]
# Processed prompts:  19%|█▉        | 12/64 [00:44<03:29,  4.03s/it]
# Processed prompts:  20%|██        | 13/64 [00:46<02:54,  3.43s/it]
# Processed prompts:  22%|██▏       | 14/64 [00:47<02:09,  2.59s/it]
# Processed prompts:  23%|██▎       | 15/64 [00:48<01:35,  1.96s/it]
# Processed prompts:  25%|██▌       | 16/64 [00:50<01:35,  1.98s/it]
# Processed prompts:  27%|██▋       | 17/64 [00:51<01:18,  1.68s/it]
# Processed prompts:  28%|██▊       | 18/64 [00:51<01:06,  1.44s/it]
# Processed prompts:  30%|██▉       | 19/64 [00:53<01:04,  1.43s/it]
# Processed prompts:  31%|███▏      | 20/64 [00:53<00:46,  1.05s/it]
# Processed prompts:  33%|███▎      | 21/64 [00:54<00:45,  1.06s/it]
# Processed prompts:  34%|███▍      | 22/64 [00:56<00:54,  1.30s/it]
# Processed prompts:  36%|███▌      | 23/64 [00:58<00:58,  1.44s/it]
# Processed prompts:  38%|███▊      | 24/64 [00:59<00:50,  1.25s/it]
# Processed prompts:  39%|███▉      | 25/64 [01:00<00:54,  1.39s/it]
# Processed prompts:  41%|████      | 26/64 [01:04<01:17,  2.05s/it]
# Processed prompts:  42%|████▏     | 27/64 [01:05<01:07,  1.83s/it]
# Processed prompts:  44%|████▍     | 28/64 [01:06<00:53,  1.48s/it]
# Processed prompts:  45%|████▌     | 29/64 [01:07<00:47,  1.36s/it]
# Processed prompts:  47%|████▋     | 30/64 [01:08<00:44,  1.31s/it]
# Processed prompts:  48%|████▊     | 31/64 [01:11<00:54,  1.67s/it]
# Processed prompts:  50%|█████     | 32/64 [01:12<00:49,  1.55s/it]
# Processed prompts:  52%|█████▏    | 33/64 [01:16<01:16,  2.46s/it]
# Processed prompts:  53%|█████▎    | 34/64 [01:18<01:02,  2.07s/it]
# Processed prompts:  55%|█████▍    | 35/64 [01:25<01:46,  3.66s/it]
# Processed prompts:  56%|█████▋    | 36/64 [01:26<01:20,  2.88s/it]
# Processed prompts:  58%|█████▊    | 37/64 [01:36<02:11,  4.88s/it]
# Processed prompts:  59%|█████▉    | 38/64 [01:40<02:06,  4.88s/it]
# Processed prompts:  61%|██████    | 39/64 [01:48<02:25,  5.81s/it]
# Processed prompts:  62%|██████▎   | 40/64 [01:53<02:11,  5.49s/it]
# Processed prompts:  64%|██████▍   | 41/64 [01:56<01:50,  4.82s/it]
# Processed prompts:  66%|██████▌   | 42/64 [01:58<01:24,  3.83s/it]
# Processed prompts:  67%|██████▋   | 43/64 [02:01<01:13,  3.50s/it]
# Processed prompts:  69%|██████▉   | 44/64 [02:04<01:08,  3.41s/it]
# Processed prompts:  70%|███████   | 45/64 [02:07<01:01,  3.22s/it]
# Processed prompts:  72%|███████▏  | 46/64 [02:11<01:06,  3.67s/it]
# Processed prompts:  73%|███████▎  | 47/64 [02:14<00:56,  3.30s/it]
# Processed prompts:  75%|███████▌  | 48/64 [02:20<01:05,  4.12s/it]
# Processed prompts:  77%|███████▋  | 49/64 [02:31<01:33,  6.25s/it]
# Processed prompts:  78%|███████▊  | 50/64 [02:42<01:45,  7.51s/it]
# Processed prompts:  80%|███████▉  | 51/64 [02:59<02:16, 10.52s/it]
# Processed prompts:  81%|████████▏ | 52/64 [03:03<01:41,  8.46s/it]
# Processed prompts:  89%|████████▉ | 57/64 [03:07<00:23,  3.29s/it]
# Processed prompts:  91%|█████████ | 58/64 [03:27<00:35,  5.98s/it]
# Processed prompts:  92%|█████████▏| 59/64 [03:30<00:27,  5.50s/it]
# Processed prompts:  94%|█████████▍| 60/64 [03:31<00:17,  4.39s/it]
# Processed prompts:  95%|█████████▌| 61/64 [03:31<00:10,  3.43s/it]
# Processed prompts:  97%|█████████▋| 62/64 [03:37<00:08,  4.04s/it]
# Processed prompts:  98%|█████████▊| 63/64 [03:49<00:06,  6.11s/it]
# Processed prompts: 100%|██████████| 64/64 [04:03<00:00,  3.80s/it]
#   4%|▍         | 4/100 [07:23<2:57:15, 110.79s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:13<13:57, 13.30s/it]
# Processed prompts:   3%|▎         | 2/64 [00:13<05:48,  5.62s/it]
# Processed prompts:   5%|▍         | 3/64 [00:14<03:25,  3.36s/it]
# Processed prompts:   6%|▋         | 4/64 [00:15<02:32,  2.55s/it]
# Processed prompts:   8%|▊         | 5/64 [00:16<01:58,  2.00s/it]
# Processed prompts:   9%|▉         | 6/64 [00:17<01:30,  1.57s/it]
# Processed prompts:  11%|█         | 7/64 [00:18<01:17,  1.36s/it]
# Processed prompts:  12%|█▎        | 8/64 [00:19<01:18,  1.40s/it]
# Processed prompts:  16%|█▌        | 10/64 [00:20<00:54,  1.00s/it]
# Processed prompts:  17%|█▋        | 11/64 [00:23<01:08,  1.30s/it]
# Processed prompts:  19%|█▉        | 12/64 [00:24<01:04,  1.25s/it]
# Processed prompts:  20%|██        | 13/64 [00:25<01:08,  1.35s/it]
# Processed prompts:  22%|██▏       | 14/64 [00:27<01:20,  1.60s/it]
# Processed prompts:  23%|██▎       | 15/64 [00:29<01:11,  1.46s/it]
# Processed prompts:  25%|██▌       | 16/64 [00:29<01:01,  1.28s/it]
# Processed prompts:  27%|██▋       | 17/64 [00:36<02:14,  2.86s/it]
# Processed prompts:  28%|██▊       | 18/64 [00:41<02:37,  3.43s/it]
# Processed prompts:  30%|██▉       | 19/64 [00:42<02:05,  2.78s/it]
# Processed prompts:  31%|███▏      | 20/64 [00:50<03:09,  4.30s/it]
# Processed prompts:  33%|███▎      | 21/64 [00:55<03:14,  4.52s/it]
# Processed prompts:  34%|███▍      | 22/64 [00:55<02:14,  3.21s/it]
# Processed prompts:  36%|███▌      | 23/64 [01:04<03:25,  5.01s/it]
# Processed prompts:  38%|███▊      | 24/64 [01:15<04:25,  6.63s/it]
# Processed prompts:  39%|███▉      | 25/64 [01:17<03:23,  5.22s/it]
# Processed prompts:  41%|████      | 26/64 [01:24<03:38,  5.76s/it]
# Processed prompts:  42%|████▏     | 27/64 [01:27<03:05,  5.02s/it]
# Processed prompts:  44%|████▍     | 28/64 [01:35<03:29,  5.82s/it]
# Processed prompts:  45%|████▌     | 29/64 [02:17<09:44, 16.70s/it]
# Processed prompts:  47%|████▋     | 30/64 [02:40<10:32, 18.62s/it]
# Processed prompts:  48%|████▊     | 31/64 [02:49<08:40, 15.78s/it]
# Processed prompts:  52%|█████▏    | 33/64 [02:57<05:22, 10.41s/it]
# Processed prompts:  53%|█████▎    | 34/64 [03:00<04:14,  8.47s/it]
# Processed prompts:  55%|█████▍    | 35/64 [03:01<03:09,  6.55s/it]
# Processed prompts:  56%|█████▋    | 36/64 [03:04<02:37,  5.64s/it]
# Processed prompts:  58%|█████▊    | 37/64 [03:07<02:10,  4.83s/it]
# Processed prompts:  61%|██████    | 39/64 [03:11<01:28,  3.52s/it]
# Processed prompts:  62%|██████▎   | 40/64 [03:13<01:15,  3.16s/it]
# Processed prompts:  64%|██████▍   | 41/64 [03:17<01:19,  3.47s/it]
# Processed prompts:  66%|██████▌   | 42/64 [03:40<03:11,  8.68s/it]
# Processed prompts:  67%|██████▋   | 43/64 [03:44<02:36,  7.46s/it]
# Processed prompts:  69%|██████▉   | 44/64 [03:57<02:56,  8.84s/it]
# Processed prompts:  70%|███████   | 45/64 [04:00<02:18,  7.29s/it]
# Processed prompts:  72%|███████▏  | 46/64 [04:04<01:55,  6.40s/it]
# Processed prompts:  73%|███████▎  | 47/64 [04:07<01:27,  5.17s/it]
# Processed prompts:  75%|███████▌  | 48/64 [04:23<02:14,  8.40s/it]
# Processed prompts:  77%|███████▋  | 49/64 [04:37<02:30, 10.01s/it]
# Processed prompts:  78%|███████▊  | 50/64 [04:55<02:55, 12.56s/it]
# Processed prompts:  80%|███████▉  | 51/64 [04:58<02:07,  9.79s/it]
# Processed prompts:  81%|████████▏ | 52/64 [05:03<01:39,  8.32s/it]
# Processed prompts:  83%|████████▎ | 53/64 [05:10<01:25,  7.80s/it]
# Processed prompts:  84%|████████▍ | 54/64 [05:14<01:07,  6.79s/it]
# Processed prompts:  86%|████████▌ | 55/64 [05:26<01:15,  8.37s/it]
# Processed prompts:  88%|████████▊ | 56/64 [05:30<00:55,  6.88s/it]
# Processed prompts:  89%|████████▉ | 57/64 [05:32<00:38,  5.43s/it]
# Processed prompts:  91%|█████████ | 58/64 [05:34<00:25,  4.31s/it]
# Processed prompts:  92%|█████████▏| 59/64 [05:36<00:18,  3.71s/it]
# Processed prompts:  94%|█████████▍| 60/64 [05:56<00:34,  8.53s/it]
# Processed prompts:  95%|█████████▌| 61/64 [05:58<00:20,  6.78s/it]
# Processed prompts:  97%|█████████▋| 62/64 [06:11<00:16,  8.41s/it]
# Processed prompts:  98%|█████████▊| 63/64 [06:11<00:06,  6.06s/it]
# Processed prompts: 100%|██████████| 64/64 [06:22<00:00,  5.97s/it]
#   5%|▌         | 5/100 [13:55<4:52:46, 184.91s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:16<17:22, 16.55s/it]
# Processed prompts:   3%|▎         | 2/64 [00:22<10:22, 10.04s/it]
# Processed prompts:   5%|▍         | 3/64 [00:30<09:27,  9.31s/it]
# Processed prompts:   6%|▋         | 4/64 [00:38<08:41,  8.70s/it]
# Processed prompts:   8%|▊         | 5/64 [00:43<07:10,  7.30s/it]
# Processed prompts:   9%|▉         | 6/64 [00:50<07:09,  7.41s/it]
# Processed prompts:  11%|█         | 7/64 [00:52<05:19,  5.60s/it]
# Processed prompts:  12%|█▎        | 8/64 [00:54<04:11,  4.49s/it]
# Processed prompts:  14%|█▍        | 9/64 [00:55<02:59,  3.26s/it]
# Processed prompts:  16%|█▌        | 10/64 [00:59<03:15,  3.61s/it]
# Processed prompts:  17%|█▋        | 11/64 [00:59<02:15,  2.56s/it]
# Processed prompts:  20%|██        | 13/64 [01:02<01:40,  1.98s/it]
# Processed prompts:  22%|██▏       | 14/64 [01:11<03:04,  3.70s/it]
# Processed prompts:  23%|██▎       | 15/64 [01:11<02:16,  2.78s/it]
# Processed prompts:  25%|██▌       | 16/64 [01:16<02:44,  3.42s/it]
# Processed prompts:  27%|██▋       | 17/64 [01:19<02:32,  3.23s/it]
# Processed prompts:  28%|██▊       | 18/64 [01:22<02:32,  3.32s/it]
# Processed prompts:  30%|██▉       | 19/64 [01:26<02:26,  3.26s/it]
# Processed prompts:  31%|███▏      | 20/64 [01:26<01:52,  2.57s/it]
# Processed prompts:  33%|███▎      | 21/64 [01:27<01:26,  2.01s/it]
# Processed prompts:  34%|███▍      | 22/64 [01:32<01:57,  2.80s/it]
# Processed prompts:  36%|███▌      | 23/64 [01:37<02:29,  3.64s/it]
# Processed prompts:  38%|███▊      | 24/64 [01:51<04:24,  6.62s/it]
# Processed prompts:  39%|███▉      | 25/64 [01:55<03:45,  5.79s/it]
# Processed prompts:  41%|████      | 26/64 [02:13<05:59,  9.47s/it]
# Processed prompts:  42%|████▏     | 27/64 [02:27<06:46, 10.98s/it]
# Processed prompts:  44%|████▍     | 28/64 [02:40<06:57, 11.59s/it]
# Processed prompts:  45%|████▌     | 29/64 [02:49<06:13, 10.66s/it]
# Processed prompts:  47%|████▋     | 30/64 [02:58<05:50, 10.30s/it]
# Processed prompts:  50%|█████     | 32/64 [03:02<03:27,  6.48s/it]
# Processed prompts:  52%|█████▏    | 33/64 [03:12<03:44,  7.23s/it]
# Processed prompts:  53%|█████▎    | 34/64 [03:13<02:51,  5.70s/it]
# Processed prompts:  55%|█████▍    | 35/64 [03:28<03:58,  8.23s/it]
# Processed prompts:  56%|█████▋    | 36/64 [03:29<02:54,  6.25s/it]
# Processed prompts:  58%|█████▊    | 37/64 [03:32<02:20,  5.19s/it]
# Processed prompts:  59%|█████▉    | 38/64 [03:34<01:52,  4.33s/it]
# Processed prompts:  61%|██████    | 39/64 [03:37<01:37,  3.91s/it]
# Processed prompts:  62%|██████▎   | 40/64 [03:38<01:13,  3.08s/it]
# Processed prompts:  64%|██████▍   | 41/64 [03:39<00:55,  2.43s/it]
# Processed prompts:  67%|██████▋   | 43/64 [03:40<00:34,  1.62s/it]
# Processed prompts:  69%|██████▉   | 44/64 [03:41<00:25,  1.30s/it]
# Processed prompts:  70%|███████   | 45/64 [03:45<00:36,  1.94s/it]
# Processed prompts:  72%|███████▏  | 46/64 [03:45<00:26,  1.45s/it]
# Processed prompts:  73%|███████▎  | 47/64 [03:45<00:20,  1.23s/it]
# Processed prompts:  75%|███████▌  | 48/64 [03:48<00:25,  1.58s/it]
# Processed prompts:  77%|███████▋  | 49/64 [03:51<00:32,  2.18s/it]
# Processed prompts:  78%|███████▊  | 50/64 [03:53<00:26,  1.92s/it]
# Processed prompts:  80%|███████▉  | 51/64 [03:55<00:24,  1.89s/it]
# Processed prompts:  81%|████████▏ | 52/64 [03:56<00:22,  1.89s/it]
# Processed prompts:  83%|████████▎ | 53/64 [03:57<00:15,  1.36s/it]
# Processed prompts:  84%|████████▍ | 54/64 [03:58<00:12,  1.29s/it]
# Processed prompts:  86%|████████▌ | 55/64 [03:59<00:11,  1.26s/it]
# Processed prompts:  88%|████████▊ | 56/64 [04:09<00:31,  3.88s/it]
# Processed prompts:  89%|████████▉ | 57/64 [04:09<00:19,  2.83s/it]
# Processed prompts:  91%|█████████ | 58/64 [04:11<00:15,  2.56s/it]
# Processed prompts:  92%|█████████▏| 59/64 [04:13<00:11,  2.20s/it]
# Processed prompts:  94%|█████████▍| 60/64 [04:14<00:07,  1.86s/it]
# Processed prompts:  95%|█████████▌| 61/64 [04:15<00:05,  1.76s/it]
# Processed prompts:  97%|█████████▋| 62/64 [04:17<00:03,  1.84s/it]
# Processed prompts:  98%|█████████▊| 63/64 [04:21<00:02,  2.54s/it]
# Processed prompts: 100%|██████████| 64/64 [04:24<00:00,  4.13s/it]
#   7%|▋         | 7/100 [18:54<4:23:02, 169.70s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:13<14:18, 13.63s/it]
# Processed prompts:   3%|▎         | 2/64 [00:17<08:18,  8.04s/it]
# Processed prompts:   5%|▍         | 3/64 [00:18<04:52,  4.80s/it]
# Processed prompts:   6%|▋         | 4/64 [00:21<04:05,  4.09s/it]
# Processed prompts:   8%|▊         | 5/64 [00:22<02:59,  3.05s/it]
# Processed prompts:   9%|▉         | 6/64 [00:24<02:19,  2.41s/it]
# Processed prompts:  11%|█         | 7/64 [00:30<03:36,  3.80s/it]
# Processed prompts:  12%|█▎        | 8/64 [00:33<03:09,  3.39s/it]
# Processed prompts:  14%|█▍        | 9/64 [00:35<02:44,  2.99s/it]
# Processed prompts:  16%|█▌        | 10/64 [00:42<03:42,  4.12s/it]
# Processed prompts:  17%|█▋        | 11/64 [00:44<03:11,  3.61s/it]
# Processed prompts:  19%|█▉        | 12/64 [00:50<03:39,  4.22s/it]
# Processed prompts:  20%|██        | 13/64 [00:56<04:10,  4.92s/it]
# Processed prompts:  22%|██▏       | 14/64 [00:57<03:05,  3.71s/it]
# Processed prompts:  23%|██▎       | 15/64 [01:02<03:16,  4.02s/it]
# Processed prompts:  25%|██▌       | 16/64 [01:07<03:32,  4.42s/it]
# Processed prompts:  27%|██▋       | 17/64 [01:10<03:02,  3.88s/it]
# Processed prompts:  28%|██▊       | 18/64 [01:13<02:49,  3.68s/it]
# Processed prompts:  31%|███▏      | 20/64 [01:17<02:07,  2.90s/it]
# Processed prompts:  33%|███▎      | 21/64 [01:19<01:57,  2.73s/it]
# Processed prompts:  34%|███▍      | 22/64 [01:27<02:48,  4.00s/it]
# Processed prompts:  36%|███▌      | 23/64 [01:35<03:34,  5.22s/it]
# Processed prompts:  38%|███▊      | 24/64 [01:38<03:04,  4.62s/it]
# Processed prompts:  39%|███▉      | 25/64 [01:42<02:49,  4.35s/it]
# Processed prompts:  41%|████      | 26/64 [01:45<02:33,  4.05s/it]
# Processed prompts:  42%|████▏     | 27/64 [01:49<02:29,  4.03s/it]
# Processed prompts:  44%|████▍     | 28/64 [01:53<02:16,  3.80s/it]
# Processed prompts:  45%|████▌     | 29/64 [01:54<01:46,  3.03s/it]
# Processed prompts:  47%|████▋     | 30/64 [01:59<02:08,  3.79s/it]
# Processed prompts:  48%|████▊     | 31/64 [02:02<01:51,  3.38s/it]
# Processed prompts:  50%|█████     | 32/64 [02:04<01:41,  3.18s/it]
# Processed prompts:  52%|█████▏    | 33/64 [02:09<01:50,  3.57s/it]
# Processed prompts:  53%|█████▎    | 34/64 [02:11<01:35,  3.18s/it]
# Processed prompts:  55%|█████▍    | 35/64 [02:12<01:14,  2.59s/it]
# Processed prompts:  56%|█████▋    | 36/64 [02:15<01:10,  2.51s/it]
# Processed prompts:  58%|█████▊    | 37/64 [02:20<01:29,  3.32s/it]
# Processed prompts:  59%|█████▉    | 38/64 [02:25<01:39,  3.83s/it]
# Processed prompts:  61%|██████    | 39/64 [02:29<01:34,  3.77s/it]
# Processed prompts:  62%|██████▎   | 40/64 [02:37<02:06,  5.29s/it]
# Processed prompts:  64%|██████▍   | 41/64 [02:40<01:46,  4.61s/it]
# Processed prompts:  66%|██████▌   | 42/64 [02:42<01:19,  3.60s/it]
# Processed prompts:  67%|██████▋   | 43/64 [02:47<01:28,  4.19s/it]
# Processed prompts:  69%|██████▉   | 44/64 [03:02<02:28,  7.41s/it]
# Processed prompts:  77%|███████▋  | 49/64 [03:10<00:52,  3.47s/it]
# Processed prompts:  78%|███████▊  | 50/64 [03:15<00:51,  3.71s/it]
# Processed prompts:  80%|███████▉  | 51/64 [03:22<00:54,  4.22s/it]
# Processed prompts:  81%|████████▏ | 52/64 [03:26<00:51,  4.30s/it]
# Processed prompts:  83%|████████▎ | 53/64 [03:29<00:43,  3.98s/it]
# Processed prompts:  84%|████████▍ | 54/64 [03:30<00:31,  3.11s/it]
# Processed prompts:  86%|████████▌ | 55/64 [03:34<00:29,  3.32s/it]
# Processed prompts:  88%|████████▊ | 56/64 [03:37<00:26,  3.32s/it]
# Processed prompts:  89%|████████▉ | 57/64 [03:40<00:22,  3.26s/it]
# Processed prompts:  91%|█████████ | 58/64 [03:40<00:14,  2.46s/it]
# Processed prompts:  92%|█████████▏| 59/64 [03:42<00:11,  2.32s/it]
# Processed prompts:  94%|█████████▍| 60/64 [03:45<00:09,  2.30s/it]
# Processed prompts:  95%|█████████▌| 61/64 [03:49<00:08,  2.89s/it]
# Processed prompts:  97%|█████████▋| 62/64 [04:11<00:17,  8.70s/it]
# Processed prompts: 100%|██████████| 64/64 [04:21<00:00,  4.08s/it]
#   8%|▊         | 8/100 [23:59<5:08:56, 201.49s/it]Token indices sequence length is longer than the specified maximum sequence length for this model (4340 > 4096). Running this sequence through the model will result in indexing errors
#
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:19<20:08, 19.18s/it]
# Processed prompts:   3%|▎         | 2/64 [00:20<08:54,  8.62s/it]
# Processed prompts:   5%|▍         | 3/64 [00:27<07:51,  7.73s/it]
# Processed prompts:   6%|▋         | 4/64 [00:34<07:39,  7.66s/it]
# Processed prompts:   8%|▊         | 5/64 [00:37<05:49,  5.93s/it]
# Processed prompts:   9%|▉         | 6/64 [00:44<06:14,  6.45s/it]
# Processed prompts:  14%|█▍        | 9/64 [00:47<02:48,  3.07s/it]
# Processed prompts:  16%|█▌        | 10/64 [00:48<02:20,  2.60s/it]
# Processed prompts:  17%|█▋        | 11/64 [00:50<02:11,  2.47s/it]
# Processed prompts:  19%|█▉        | 12/64 [00:51<01:59,  2.29s/it]
# Processed prompts:  22%|██▏       | 14/64 [00:53<01:18,  1.56s/it]
# Processed prompts:  23%|██▎       | 15/64 [00:53<01:01,  1.25s/it]
# Processed prompts:  25%|██▌       | 16/64 [00:53<00:48,  1.01s/it]
# Processed prompts:  27%|██▋       | 17/64 [00:56<01:04,  1.38s/it]
# Processed prompts:  28%|██▊       | 18/64 [00:57<01:05,  1.43s/it]
# Processed prompts:  30%|██▉       | 19/64 [00:57<00:50,  1.13s/it]
# Processed prompts:  31%|███▏      | 20/64 [00:59<00:52,  1.19s/it]
# Processed prompts:  33%|███▎      | 21/64 [01:01<01:09,  1.62s/it]
# Processed prompts:  34%|███▍      | 22/64 [01:10<02:32,  3.64s/it]
# Processed prompts:  36%|███▌      | 23/64 [01:12<02:08,  3.12s/it]
# Processed prompts:  38%|███▊      | 24/64 [01:13<01:36,  2.41s/it]
# Processed prompts:  39%|███▉      | 25/64 [01:26<03:45,  5.79s/it]
# Processed prompts:  41%|████      | 26/64 [01:36<04:18,  6.81s/it]
# Processed prompts:  42%|████▏     | 27/64 [01:53<06:08,  9.97s/it]
# Processed prompts:  44%|████▍     | 28/64 [01:58<05:05,  8.48s/it]
# Processed prompts:  45%|████▌     | 29/64 [02:02<04:11,  7.20s/it]
# Processed prompts:  47%|████▋     | 30/64 [02:05<03:22,  5.96s/it]
# WARNING 10-27 09:14:50 scheduler.py:245] Input prompt (4340 tokens) is too long and exceeds limit of 4096
# Processed prompts:  48%|████▊     | 31/64 [02:06<02:26,  4.43s/it]
# Processed prompts:  50%|█████     | 32/64 [02:09<02:06,  3.94s/it]
# Processed prompts:  52%|█████▏    | 33/64 [02:18<02:49,  5.45s/it]
# Processed prompts:  53%|█████▎    | 34/64 [02:23<02:45,  5.52s/it]
# Processed prompts:  55%|█████▍    | 35/64 [02:28<02:29,  5.16s/it]
# Processed prompts:  56%|█████▋    | 36/64 [02:29<01:52,  4.04s/it]
# Processed prompts:  58%|█████▊    | 37/64 [02:32<01:37,  3.61s/it]
# Processed prompts:  59%|█████▉    | 38/64 [02:37<01:44,  4.03s/it]
# Processed prompts:  61%|██████    | 39/64 [02:46<02:19,  5.60s/it]
# Processed prompts:  62%|██████▎   | 40/64 [02:51<02:11,  5.50s/it]
# Processed prompts:  64%|██████▍   | 41/64 [03:03<02:45,  7.20s/it]
# Processed prompts:  66%|██████▌   | 42/64 [03:15<03:13,  8.82s/it]
# Processed prompts:  67%|██████▋   | 43/64 [03:16<02:13,  6.35s/it]
# Processed prompts:  69%|██████▉   | 44/64 [03:28<02:43,  8.15s/it]
# Processed prompts:  70%|███████   | 45/64 [03:31<02:07,  6.72s/it]
# Processed prompts:  72%|███████▏  | 46/64 [03:33<01:33,  5.19s/it]
# Processed prompts:  73%|███████▎  | 47/64 [03:37<01:22,  4.84s/it]
# Processed prompts:  75%|███████▌  | 48/64 [03:39<01:02,  3.94s/it]
# Processed prompts:  77%|███████▋  | 49/64 [03:42<00:57,  3.82s/it]
# Processed prompts:  78%|███████▊  | 50/64 [04:16<02:59, 12.82s/it]
# Processed prompts:  80%|███████▉  | 51/64 [04:28<02:42, 12.54s/it]
# Processed prompts:  81%|████████▏ | 52/64 [04:35<02:08, 10.68s/it]
# Processed prompts:  83%|████████▎ | 53/64 [04:38<01:33,  8.51s/it]
# Processed prompts:  84%|████████▍ | 54/64 [04:45<01:20,  8.06s/it]
# Processed prompts:  86%|████████▌ | 55/64 [04:51<01:05,  7.30s/it]
# Processed prompts:  88%|████████▊ | 56/64 [04:57<00:57,  7.15s/it]
# Processed prompts:  89%|████████▉ | 57/64 [05:08<00:56,  8.08s/it]
# Processed prompts:  91%|█████████ | 58/64 [05:10<00:38,  6.40s/it]
# Processed prompts:  92%|█████████▏| 59/64 [05:12<00:25,  5.06s/it]
# Processed prompts:  94%|█████████▍| 60/64 [05:30<00:35,  8.97s/it]
# Processed prompts:  95%|█████████▌| 61/64 [05:43<00:30, 10.25s/it]
# Processed prompts:  97%|█████████▋| 62/64 [05:45<00:15,  7.55s/it]
# Processed prompts:  98%|█████████▊| 63/64 [06:15<00:14, 14.53s/it]
# Processed prompts: 100%|██████████| 64/64 [06:19<00:00,  5.93s/it]
#   9%|▉         | 9/100 [30:42<6:22:19, 252.09s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:14<15:10, 14.46s/it]
# Processed prompts:   3%|▎         | 2/64 [00:16<07:10,  6.94s/it]
# Processed prompts:   5%|▍         | 3/64 [00:17<04:20,  4.26s/it]
# Processed prompts:   6%|▋         | 4/64 [00:20<03:44,  3.74s/it]
# Processed prompts:   8%|▊         | 5/64 [00:35<07:48,  7.94s/it]
# Processed prompts:   9%|▉         | 6/64 [00:40<06:44,  6.97s/it]
# Processed prompts:  11%|█         | 7/64 [00:42<04:58,  5.23s/it]
# Processed prompts:  12%|█▎        | 8/64 [00:45<04:10,  4.47s/it]
# Processed prompts:  14%|█▍        | 9/64 [00:47<03:25,  3.73s/it]
# Processed prompts:  16%|█▌        | 10/64 [00:48<02:33,  2.84s/it]
# Processed prompts:  17%|█▋        | 11/64 [00:48<01:52,  2.12s/it]
# Processed prompts:  19%|█▉        | 12/64 [00:49<01:28,  1.70s/it]
# Processed prompts:  20%|██        | 13/64 [00:52<01:42,  2.01s/it]
# Processed prompts:  22%|██▏       | 14/64 [00:53<01:29,  1.80s/it]
# Processed prompts:  23%|██▎       | 15/64 [00:53<01:05,  1.33s/it]
# Processed prompts:  25%|██▌       | 16/64 [00:54<00:59,  1.24s/it]
# Processed prompts:  27%|██▋       | 17/64 [00:55<00:50,  1.08s/it]
# Processed prompts:  28%|██▊       | 18/64 [00:55<00:36,  1.25it/s]
# Processed prompts:  31%|███▏      | 20/64 [00:57<00:42,  1.04it/s]
# Processed prompts:  33%|███▎      | 21/64 [00:58<00:40,  1.05it/s]
# Processed prompts:  34%|███▍      | 22/64 [00:59<00:37,  1.13it/s]
# WARNING 10-27 09:20:26 scheduler.py:245] Input prompt (4360 tokens) is too long and exceeds limit of 4096
# Processed prompts:  36%|███▌      | 23/64 [01:00<00:33,  1.21it/s]
# Processed prompts:  38%|███▊      | 24/64 [01:00<00:28,  1.41it/s]
# Processed prompts:  39%|███▉      | 25/64 [01:01<00:30,  1.28it/s]
# Processed prompts:  41%|████      | 26/64 [01:02<00:32,  1.17it/s]
# Processed prompts:  42%|████▏     | 27/64 [01:05<00:54,  1.47s/it]
# Processed prompts:  44%|████▍     | 28/64 [01:11<01:43,  2.86s/it]
# Processed prompts:  45%|████▌     | 29/64 [01:12<01:18,  2.24s/it]
# Processed prompts:  47%|████▋     | 30/64 [01:13<01:03,  1.86s/it]
# Processed prompts:  48%|████▊     | 31/64 [01:19<01:42,  3.12s/it]
# Processed prompts:  50%|█████     | 32/64 [01:21<01:33,  2.93s/it]
# Processed prompts:  52%|█████▏    | 33/64 [01:43<04:23,  8.51s/it]
# Processed prompts:  53%|█████▎    | 34/64 [01:50<04:04,  8.14s/it]
# Processed prompts:  55%|█████▍    | 35/64 [01:57<03:45,  7.76s/it]
# Processed prompts:  56%|█████▋    | 36/64 [02:01<03:08,  6.72s/it]
# Processed prompts:  58%|█████▊    | 37/64 [02:05<02:37,  5.84s/it]
# Processed prompts:  59%|█████▉    | 38/64 [02:09<02:14,  5.17s/it]
# Processed prompts:  61%|██████    | 39/64 [02:11<01:45,  4.20s/it]
# Processed prompts:  62%|██████▎   | 40/64 [02:31<03:35,  8.98s/it]
# Processed prompts:  64%|██████▍   | 41/64 [02:34<02:49,  7.37s/it]
# Processed prompts:  67%|██████▋   | 43/64 [02:55<03:05,  8.82s/it]
# Processed prompts:  69%|██████▉   | 44/64 [02:57<02:21,  7.06s/it]
# Processed prompts:  70%|███████   | 45/64 [02:58<01:43,  5.45s/it]
# Processed prompts:  72%|███████▏  | 46/64 [03:00<01:18,  4.36s/it]
# Processed prompts:  75%|███████▌  | 48/64 [03:00<00:40,  2.50s/it]
# Processed prompts:  77%|███████▋  | 49/64 [03:10<01:03,  4.25s/it]
# Processed prompts:  78%|███████▊  | 50/64 [03:12<00:51,  3.67s/it]
# Processed prompts:  80%|███████▉  | 51/64 [03:16<00:49,  3.85s/it]
# Processed prompts:  81%|████████▏ | 52/64 [03:21<00:51,  4.28s/it]
# Processed prompts:  84%|████████▍ | 54/64 [03:25<00:31,  3.11s/it]
# Processed prompts:  86%|████████▌ | 55/64 [03:31<00:35,  4.00s/it]
# Processed prompts:  88%|████████▊ | 56/64 [03:33<00:26,  3.28s/it]
# Processed prompts:  89%|████████▉ | 57/64 [03:34<00:18,  2.71s/it]
# Processed prompts:  91%|█████████ | 58/64 [03:36<00:15,  2.52s/it]
# Processed prompts:  92%|█████████▏| 59/64 [03:37<00:10,  2.18s/it]
# Processed prompts:  94%|█████████▍| 60/64 [03:39<00:08,  2.04s/it]
# Processed prompts:  95%|█████████▌| 61/64 [03:39<00:04,  1.51s/it]
# Processed prompts:  97%|█████████▋| 62/64 [03:50<00:08,  4.29s/it]
# Processed prompts:  98%|█████████▊| 63/64 [04:21<00:12, 12.24s/it]
# Processed prompts: 100%|██████████| 64/64 [04:25<00:00,  4.15s/it]
#  10%|█         | 10/100 [35:52<6:41:06, 267.40s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:12<12:48, 12.20s/it]
# Processed prompts:   3%|▎         | 2/64 [00:13<05:57,  5.77s/it]
# Processed prompts:   5%|▍         | 3/64 [00:14<03:36,  3.55s/it]
# WARNING 10-27 09:24:52 scheduler.py:245] Input prompt (12426 tokens) is too long and exceeds limit of 4096
# Processed prompts:   8%|▊         | 5/64 [00:15<01:43,  1.75s/it]
# Processed prompts:   9%|▉         | 6/64 [00:16<01:33,  1.62s/it]
# Processed prompts:  12%|█▎        | 8/64 [00:16<00:52,  1.06it/s]
# Processed prompts:  16%|█▌        | 10/64 [00:18<00:46,  1.16it/s]
# Processed prompts:  17%|█▋        | 11/64 [00:18<00:38,  1.38it/s]
# Processed prompts:  20%|██        | 13/64 [00:20<00:47,  1.07it/s]
# Processed prompts:  22%|██▏       | 14/64 [00:21<00:40,  1.23it/s]
# Processed prompts:  23%|██▎       | 15/64 [00:30<02:12,  2.71s/it]
# Processed prompts:  25%|██▌       | 16/64 [00:32<02:08,  2.68s/it]
# Processed prompts:  27%|██▋       | 17/64 [00:35<02:11,  2.81s/it]
# Processed prompts:  28%|██▊       | 18/64 [00:39<02:16,  2.97s/it]
# Processed prompts:  30%|██▉       | 19/64 [00:41<01:59,  2.66s/it]
# Processed prompts:  31%|███▏      | 20/64 [00:42<01:38,  2.24s/it]
# Processed prompts:  33%|███▎      | 21/64 [00:56<04:02,  5.64s/it]
# Processed prompts:  34%|███▍      | 22/64 [00:56<02:53,  4.13s/it]
# Processed prompts:  36%|███▌      | 23/64 [01:07<04:08,  6.06s/it]
# Processed prompts:  38%|███▊      | 24/64 [01:17<04:49,  7.23s/it]
# Processed prompts:  39%|███▉      | 25/64 [01:22<04:19,  6.66s/it]
# Processed prompts:  41%|████      | 26/64 [01:32<04:45,  7.51s/it]
# Processed prompts:  42%|████▏     | 27/64 [01:35<03:51,  6.26s/it]
# Processed prompts:  44%|████▍     | 28/64 [01:41<03:39,  6.10s/it]
# Processed prompts:  45%|████▌     | 29/64 [01:48<03:47,  6.51s/it]
# Processed prompts:  47%|████▋     | 30/64 [01:51<03:00,  5.31s/it]
# Processed prompts:  48%|████▊     | 31/64 [01:59<03:27,  6.30s/it]
# Processed prompts:  50%|█████     | 32/64 [02:04<03:01,  5.66s/it]
# Processed prompts:  52%|█████▏    | 33/64 [02:06<02:27,  4.75s/it]
# Processed prompts:  53%|█████▎    | 34/64 [02:09<02:02,  4.07s/it]
# Processed prompts:  55%|█████▍    | 35/64 [02:16<02:26,  5.05s/it]
# Processed prompts:  56%|█████▋    | 36/64 [02:18<01:56,  4.15s/it]
# Processed prompts:  58%|█████▊    | 37/64 [02:24<02:09,  4.80s/it]
# Processed prompts:  59%|█████▉    | 38/64 [02:27<01:50,  4.24s/it]
# Processed prompts:  61%|██████    | 39/64 [02:32<01:49,  4.40s/it]
# Processed prompts:  62%|██████▎   | 40/64 [02:40<02:08,  5.36s/it]
# Processed prompts:  64%|██████▍   | 41/64 [02:41<01:37,  4.25s/it]
# Processed prompts:  66%|██████▌   | 42/64 [02:47<01:40,  4.57s/it]
# Processed prompts:  67%|██████▋   | 43/64 [02:54<01:51,  5.33s/it]
# Processed prompts:  69%|██████▉   | 44/64 [02:56<01:28,  4.42s/it]
# Processed prompts:  70%|███████   | 45/64 [02:57<01:02,  3.28s/it]
# Processed prompts:  72%|███████▏  | 46/64 [03:00<01:00,  3.38s/it]
# Processed prompts:  73%|███████▎  | 47/64 [03:03<00:54,  3.19s/it]
# Processed prompts:  75%|███████▌  | 48/64 [03:05<00:44,  2.79s/it]
# Processed prompts:  77%|███████▋  | 49/64 [03:06<00:36,  2.40s/it]
# Processed prompts:  78%|███████▊  | 50/64 [03:08<00:29,  2.11s/it]
# Processed prompts:  80%|███████▉  | 51/64 [03:09<00:24,  1.89s/it]
# Processed prompts:  81%|████████▏ | 52/64 [03:11<00:22,  1.85s/it]
# Processed prompts:  83%|████████▎ | 53/64 [03:13<00:19,  1.80s/it]
# Processed prompts:  84%|████████▍ | 54/64 [03:13<00:13,  1.37s/it]
# Processed prompts:  86%|████████▌ | 55/64 [03:15<00:14,  1.62s/it]
# Processed prompts:  88%|████████▊ | 56/64 [03:16<00:11,  1.47s/it]
# Processed prompts:  89%|████████▉ | 57/64 [03:17<00:07,  1.08s/it]
# Processed prompts:  91%|█████████ | 58/64 [03:18<00:06,  1.11s/it]
# Processed prompts:  92%|█████████▏| 59/64 [03:21<00:08,  1.78s/it]
# Processed prompts:  94%|█████████▍| 60/64 [03:23<00:07,  1.81s/it]
# Processed prompts:  95%|█████████▌| 61/64 [03:27<00:07,  2.52s/it]
# Processed prompts:  97%|█████████▋| 62/64 [03:28<00:03,  1.92s/it]
# Processed prompts:  98%|█████████▊| 63/64 [03:29<00:01,  1.66s/it]
# Processed prompts: 100%|██████████| 64/64 [03:39<00:00,  3.42s/it]
#  11%|█         | 11/100 [39:59<6:28:03, 261.61s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:12<13:07, 12.50s/it]
# Processed prompts:   3%|▎         | 2/64 [00:16<07:38,  7.40s/it]
# Processed prompts:   5%|▍         | 3/64 [00:28<09:46,  9.62s/it]
# Processed prompts:   6%|▋         | 4/64 [00:39<10:07, 10.12s/it]
# Processed prompts:   8%|▊         | 5/64 [00:45<08:20,  8.49s/it]
# Processed prompts:   9%|▉         | 6/64 [00:45<05:35,  5.79s/it]
# WARNING 10-27 09:29:29 scheduler.py:245] Input prompt (4391 tokens) is too long and exceeds limit of 4096
# Processed prompts:  11%|█         | 7/64 [00:46<04:02,  4.26s/it]
# Processed prompts:  12%|█▎        | 8/64 [00:47<02:47,  2.99s/it]
# WARNING 10-27 09:29:31 scheduler.py:245] Input prompt (4365 tokens) is too long and exceeds limit of 4096
# Processed prompts:  14%|█▍        | 9/64 [00:47<02:08,  2.34s/it]
# Processed prompts:  16%|█▌        | 10/64 [01:01<05:08,  5.72s/it]
# Processed prompts:  17%|█▋        | 11/64 [01:03<04:02,  4.57s/it]
# Processed prompts:  19%|█▉        | 12/64 [01:06<03:31,  4.07s/it]
# Processed prompts:  20%|██        | 13/64 [01:14<04:35,  5.41s/it]
# Processed prompts:  22%|██▏       | 14/64 [01:20<04:31,  5.42s/it]
# Processed prompts:  23%|██▎       | 15/64 [01:22<03:45,  4.61s/it]
# Processed prompts:  25%|██▌       | 16/64 [01:37<06:09,  7.69s/it]
# Processed prompts:  27%|██▋       | 17/64 [01:44<05:43,  7.31s/it]
# Processed prompts:  28%|██▊       | 18/64 [01:46<04:24,  5.74s/it]
# Processed prompts:  30%|██▉       | 19/64 [01:51<04:10,  5.56s/it]
# Processed prompts:  31%|███▏      | 20/64 [01:52<03:01,  4.14s/it]
# Processed prompts:  33%|███▎      | 21/64 [01:55<02:48,  3.92s/it]
# Processed prompts:  34%|███▍      | 22/64 [02:01<03:04,  4.39s/it]
# Processed prompts:  36%|███▌      | 23/64 [02:01<02:11,  3.20s/it]
# Processed prompts:  38%|███▊      | 24/64 [02:10<03:19,  4.98s/it]
# Processed prompts:  39%|███▉      | 25/64 [02:26<05:21,  8.25s/it]
# Processed prompts:  41%|████      | 26/64 [02:29<04:14,  6.69s/it]
# Processed prompts:  42%|████▏     | 27/64 [02:31<03:19,  5.39s/it]
# Processed prompts:  44%|████▍     | 28/64 [02:52<06:01, 10.04s/it]
# Processed prompts:  48%|████▊     | 31/64 [02:58<03:02,  5.53s/it]
# Processed prompts:  50%|█████     | 32/64 [03:07<03:19,  6.22s/it]
# Processed prompts:  52%|█████▏    | 33/64 [03:16<03:29,  6.75s/it]
# Processed prompts:  53%|█████▎    | 34/64 [03:18<02:48,  5.61s/it]
# Processed prompts:  55%|█████▍    | 35/64 [03:20<02:20,  4.84s/it]
# Processed prompts:  56%|█████▋    | 36/64 [03:22<01:53,  4.07s/it]
# Processed prompts:  58%|█████▊    | 37/64 [03:25<01:41,  3.76s/it]
# Processed prompts:  59%|█████▉    | 38/64 [03:28<01:28,  3.42s/it]
# Processed prompts:  61%|██████    | 39/64 [03:30<01:16,  3.04s/it]
# Processed prompts:  62%|██████▎   | 40/64 [03:30<00:53,  2.25s/it]
# Processed prompts:  64%|██████▍   | 41/64 [03:31<00:40,  1.77s/it]
# Processed prompts:  66%|██████▌   | 42/64 [03:33<00:38,  1.74s/it]
# Processed prompts:  67%|██████▋   | 43/64 [03:33<00:29,  1.43s/it]
# Processed prompts:  70%|███████   | 45/64 [03:34<00:17,  1.10it/s]
# Processed prompts:  72%|███████▏  | 46/64 [03:37<00:25,  1.43s/it]
# Processed prompts:  73%|███████▎  | 47/64 [03:38<00:23,  1.36s/it]
# Processed prompts:  75%|███████▌  | 48/64 [03:39<00:17,  1.09s/it]
# Processed prompts:  77%|███████▋  | 49/64 [03:45<00:38,  2.58s/it]
# Processed prompts:  78%|███████▊  | 50/64 [03:48<00:39,  2.82s/it]
# Processed prompts:  80%|███████▉  | 51/64 [03:49<00:26,  2.04s/it]
# Processed prompts:  81%|████████▏ | 52/64 [03:59<00:52,  4.35s/it]
# Processed prompts:  83%|████████▎ | 53/64 [03:59<00:35,  3.24s/it]
# Processed prompts:  84%|████████▍ | 54/64 [04:02<00:30,  3.06s/it]
# Processed prompts:  86%|████████▌ | 55/64 [04:02<00:19,  2.19s/it]
# Processed prompts:  88%|████████▊ | 56/64 [04:02<00:12,  1.57s/it]
# Processed prompts:  89%|████████▉ | 57/64 [04:05<00:13,  1.91s/it]
# Processed prompts:  91%|█████████ | 58/64 [04:05<00:08,  1.37s/it]
# Processed prompts:  92%|█████████▏| 59/64 [04:12<00:15,  3.18s/it]
# Processed prompts:  94%|█████████▍| 60/64 [04:12<00:09,  2.30s/it]
# Processed prompts:  95%|█████████▌| 61/64 [04:16<00:08,  2.72s/it]
# Processed prompts:  97%|█████████▋| 62/64 [04:20<00:06,  3.14s/it]
# Processed prompts:  98%|█████████▊| 63/64 [04:39<00:07,  7.92s/it]
# Processed prompts: 100%|██████████| 64/64 [04:46<00:00,  4.48s/it]
#  13%|█▎        | 13/100 [45:16<5:13:51, 216.46s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:34<35:51, 34.16s/it]
# Processed prompts:   3%|▎         | 2/64 [00:38<17:22, 16.81s/it]
# Processed prompts:   5%|▍         | 3/64 [00:39<09:34,  9.42s/it]
# Processed prompts:   6%|▋         | 4/64 [00:41<06:20,  6.34s/it]
# Processed prompts:   8%|▊         | 5/64 [00:41<04:02,  4.11s/it]
# Processed prompts:   9%|▉         | 6/64 [00:43<03:15,  3.38s/it]
# Processed prompts:  11%|█         | 7/64 [00:43<02:15,  2.37s/it]
# Processed prompts:  12%|█▎        | 8/64 [00:44<01:47,  1.92s/it]
# Processed prompts:  14%|█▍        | 9/64 [00:46<01:42,  1.87s/it]
# Processed prompts:  17%|█▋        | 11/64 [00:46<00:56,  1.07s/it]
# Processed prompts:  19%|█▉        | 12/64 [00:48<01:11,  1.38s/it]
# Processed prompts:  20%|██        | 13/64 [00:49<01:00,  1.18s/it]
# Processed prompts:  22%|██▏       | 14/64 [00:54<01:49,  2.18s/it]
# Processed prompts:  23%|██▎       | 15/64 [00:55<01:29,  1.82s/it]
# Processed prompts:  25%|██▌       | 16/64 [00:55<01:07,  1.40s/it]
# Processed prompts:  27%|██▋       | 17/64 [01:00<02:00,  2.57s/it]
# Processed prompts:  28%|██▊       | 18/64 [01:01<01:30,  1.97s/it]
# Processed prompts:  30%|██▉       | 19/64 [01:03<01:22,  1.84s/it]
# Processed prompts:  31%|███▏      | 20/64 [01:06<01:48,  2.46s/it]
# Processed prompts:  33%|███▎      | 21/64 [01:09<01:48,  2.51s/it]
# Processed prompts:  34%|███▍      | 22/64 [01:28<05:08,  7.33s/it]
# Processed prompts:  36%|███▌      | 23/64 [01:32<04:17,  6.29s/it]
# Processed prompts:  38%|███▊      | 24/64 [01:45<05:34,  8.35s/it]
# Processed prompts:  39%|███▉      | 25/64 [01:47<04:08,  6.38s/it]
# Processed prompts:  41%|████      | 26/64 [01:50<03:25,  5.40s/it]
# Processed prompts:  42%|████▏     | 27/64 [01:51<02:39,  4.30s/it]
# Processed prompts:  44%|████▍     | 28/64 [01:57<02:50,  4.74s/it]
# Processed prompts:  45%|████▌     | 29/64 [02:03<02:56,  5.03s/it]
# Processed prompts:  47%|████▋     | 30/64 [02:14<03:49,  6.74s/it]
# Processed prompts:  48%|████▊     | 31/64 [02:17<03:07,  5.67s/it]
# Processed prompts:  52%|█████▏    | 33/64 [02:19<01:48,  3.49s/it]
# Processed prompts:  53%|█████▎    | 34/64 [02:20<01:26,  2.87s/it]
# Processed prompts:  55%|█████▍    | 35/64 [02:21<01:12,  2.52s/it]
# Processed prompts:  56%|█████▋    | 36/64 [02:29<01:49,  3.90s/it]
# Processed prompts:  58%|█████▊    | 37/64 [02:40<02:41,  5.97s/it]
# Processed prompts:  59%|█████▉    | 38/64 [02:43<02:15,  5.22s/it]
# Processed prompts:  61%|██████    | 39/64 [02:45<01:42,  4.12s/it]
# Processed prompts:  62%|██████▎   | 40/64 [02:48<01:28,  3.70s/it]
# Processed prompts:  64%|██████▍   | 41/64 [02:49<01:09,  3.04s/it]
# Processed prompts:  66%|██████▌   | 42/64 [02:58<01:43,  4.69s/it]
# Processed prompts:  67%|██████▋   | 43/64 [03:16<03:03,  8.76s/it]
# Processed prompts:  69%|██████▉   | 44/64 [03:31<03:32, 10.63s/it]
# Processed prompts:  70%|███████   | 45/64 [03:43<03:28, 10.95s/it]
# Processed prompts:  72%|███████▏  | 46/64 [03:45<02:28,  8.28s/it]
# Processed prompts:  73%|███████▎  | 47/64 [03:46<01:43,  6.11s/it]
# Processed prompts:  75%|███████▌  | 48/64 [03:56<01:55,  7.25s/it]
# Processed prompts:  77%|███████▋  | 49/64 [04:01<01:41,  6.74s/it]
# Processed prompts:  80%|███████▉  | 51/64 [04:03<00:53,  4.09s/it]
# Processed prompts:  81%|████████▏ | 52/64 [04:04<00:40,  3.34s/it]
# Processed prompts:  83%|████████▎ | 53/64 [04:05<00:29,  2.68s/it]
# Processed prompts:  84%|████████▍ | 54/64 [04:09<00:28,  2.88s/it]
# Processed prompts:  86%|████████▌ | 55/64 [04:09<00:19,  2.21s/it]
# Processed prompts:  88%|████████▊ | 56/64 [04:10<00:14,  1.84s/it]
# Processed prompts:  89%|████████▉ | 57/64 [04:11<00:10,  1.56s/it]
# Processed prompts:  91%|█████████ | 58/64 [04:12<00:09,  1.52s/it]
# Processed prompts:  92%|█████████▏| 59/64 [04:21<00:18,  3.62s/it]
# Processed prompts:  94%|█████████▍| 60/64 [04:28<00:18,  4.53s/it]
# Processed prompts:  95%|█████████▌| 61/64 [04:39<00:19,  6.48s/it]
# Processed prompts:  97%|█████████▋| 62/64 [04:54<00:18,  9.21s/it]
# Processed prompts:  98%|█████████▊| 63/64 [04:56<00:07,  7.04s/it]
# Processed prompts: 100%|██████████| 64/64 [05:02<00:00,  4.72s/it]
#  14%|█▍        | 14/100 [50:52<5:51:11, 245.02s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:15<15:57, 15.19s/it]
# Processed prompts:   3%|▎         | 2/64 [00:19<09:21,  9.05s/it]
# Processed prompts:   5%|▍         | 3/64 [00:23<06:30,  6.40s/it]
# Processed prompts:   6%|▋         | 4/64 [00:25<04:39,  4.65s/it]
# Processed prompts:   8%|▊         | 5/64 [00:28<04:11,  4.26s/it]
# Processed prompts:   9%|▉         | 6/64 [00:29<02:54,  3.00s/it]
# Processed prompts:  11%|█         | 7/64 [00:30<02:21,  2.48s/it]
# Processed prompts:  12%|█▎        | 8/64 [00:32<02:10,  2.33s/it]
# Processed prompts:  14%|█▍        | 9/64 [00:33<01:45,  1.92s/it]
# Processed prompts:  16%|█▌        | 10/64 [00:35<01:43,  1.91s/it]
# WARNING 10-27 09:40:13 scheduler.py:245] Input prompt (4440 tokens) is too long and exceeds limit of 4096
# Processed prompts:  17%|█▋        | 11/64 [00:36<01:21,  1.53s/it]
# Processed prompts:  19%|█▉        | 12/64 [00:36<01:04,  1.24s/it]
# Processed prompts:  20%|██        | 13/64 [00:38<01:14,  1.46s/it]
# Processed prompts:  22%|██▏       | 14/64 [00:39<00:59,  1.19s/it]
# Processed prompts:  23%|██▎       | 15/64 [00:42<01:23,  1.71s/it]
# Processed prompts:  25%|██▌       | 16/64 [00:42<00:59,  1.24s/it]
# Processed prompts:  27%|██▋       | 17/64 [00:42<00:44,  1.06it/s]
# Processed prompts:  28%|██▊       | 18/64 [00:44<00:55,  1.20s/it]
# Processed prompts:  30%|██▉       | 19/64 [00:45<00:52,  1.16s/it]
# Processed prompts:  31%|███▏      | 20/64 [00:45<00:38,  1.14it/s]
# Processed prompts:  33%|███▎      | 21/64 [00:46<00:35,  1.22it/s]
# Processed prompts:  34%|███▍      | 22/64 [00:48<00:55,  1.32s/it]
# Processed prompts:  36%|███▌      | 23/64 [00:53<01:36,  2.36s/it]
# Processed prompts:  38%|███▊      | 24/64 [00:54<01:15,  1.88s/it]
# Processed prompts:  39%|███▉      | 25/64 [01:04<02:53,  4.45s/it]
# Processed prompts:  41%|████      | 26/64 [01:08<02:41,  4.25s/it]
# Processed prompts:  42%|████▏     | 27/64 [01:15<03:01,  4.91s/it]
# Processed prompts:  44%|████▍     | 28/64 [01:18<02:39,  4.44s/it]
# Processed prompts:  45%|████▌     | 29/64 [01:30<03:50,  6.59s/it]
# Processed prompts:  47%|████▋     | 30/64 [01:37<03:56,  6.95s/it]
# Processed prompts:  48%|████▊     | 31/64 [01:41<03:20,  6.06s/it]
# Processed prompts:  50%|█████     | 32/64 [01:51<03:45,  7.05s/it]
# Processed prompts:  52%|█████▏    | 33/64 [01:56<03:26,  6.65s/it]
# Processed prompts:  53%|█████▎    | 34/64 [01:58<02:35,  5.19s/it]
# Processed prompts:  55%|█████▍    | 35/64 [02:00<02:00,  4.16s/it]
# Processed prompts:  56%|█████▋    | 36/64 [02:00<01:24,  3.01s/it]
# Processed prompts:  58%|█████▊    | 37/64 [02:02<01:13,  2.73s/it]
# Processed prompts:  59%|█████▉    | 38/64 [02:04<01:01,  2.38s/it]
# Processed prompts:  61%|██████    | 39/64 [02:08<01:09,  2.80s/it]
# Processed prompts:  62%|██████▎   | 40/64 [02:09<00:55,  2.30s/it]
# Processed prompts:  64%|██████▍   | 41/64 [02:11<00:49,  2.16s/it]
# Processed prompts:  66%|██████▌   | 42/64 [02:17<01:14,  3.38s/it]
# Processed prompts:  67%|██████▋   | 43/64 [02:43<03:31, 10.07s/it]
# Processed prompts:  69%|██████▉   | 44/64 [02:49<02:57,  8.89s/it]
# Processed prompts:  70%|███████   | 45/64 [02:50<02:05,  6.61s/it]
# Processed prompts:  72%|███████▏  | 46/64 [02:59<02:12,  7.36s/it]
# Processed prompts:  75%|███████▌  | 48/64 [03:01<01:08,  4.28s/it]
# Processed prompts:  77%|███████▋  | 49/64 [03:03<00:55,  3.73s/it]
# Processed prompts:  78%|███████▊  | 50/64 [03:04<00:45,  3.22s/it]
# Processed prompts:  80%|███████▉  | 51/64 [03:06<00:37,  2.85s/it]
# Processed prompts:  81%|████████▏ | 52/64 [03:08<00:29,  2.46s/it]
# Processed prompts:  83%|████████▎ | 53/64 [03:09<00:22,  2.03s/it]
# Processed prompts:  84%|████████▍ | 54/64 [03:09<00:15,  1.53s/it]
# Processed prompts:  86%|████████▌ | 55/64 [03:13<00:21,  2.34s/it]
# Processed prompts:  88%|████████▊ | 56/64 [03:14<00:15,  1.96s/it]
# Processed prompts:  89%|████████▉ | 57/64 [03:16<00:13,  2.00s/it]
# Processed prompts:  91%|█████████ | 58/64 [03:17<00:10,  1.69s/it]
# Processed prompts:  92%|█████████▏| 59/64 [03:22<00:12,  2.52s/it]
# Processed prompts:  94%|█████████▍| 60/64 [03:24<00:10,  2.51s/it]
# Processed prompts:  95%|█████████▌| 61/64 [03:31<00:11,  3.75s/it]
# Processed prompts:  97%|█████████▋| 62/64 [03:32<00:05,  2.96s/it]
# Processed prompts:  98%|█████████▊| 63/64 [03:32<00:02,  2.17s/it]
# Processed prompts: 100%|██████████| 64/64 [03:56<00:00,  3.70s/it]
#  15%|█▌        | 15/100 [55:18<5:54:26, 250.19s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:14<14:44, 14.04s/it]
# Processed prompts:   3%|▎         | 2/64 [00:18<08:50,  8.55s/it]
# Processed prompts:   5%|▍         | 3/64 [00:18<04:48,  4.72s/it]
# Processed prompts:   6%|▋         | 4/64 [00:20<03:27,  3.46s/it]
# Processed prompts:   8%|▊         | 5/64 [00:22<02:53,  2.95s/it]
# Processed prompts:   9%|▉         | 6/64 [00:24<02:38,  2.74s/it]
# Processed prompts:  11%|█         | 7/64 [00:25<02:02,  2.15s/it]
# Processed prompts:  12%|█▎        | 8/64 [00:27<01:51,  2.00s/it]
# Processed prompts:  14%|█▍        | 9/64 [00:28<01:34,  1.72s/it]
# Processed prompts:  16%|█▌        | 10/64 [00:28<01:11,  1.33s/it]
# Processed prompts:  17%|█▋        | 11/64 [00:37<03:05,  3.49s/it]
# Processed prompts:  19%|█▉        | 12/64 [00:52<06:06,  7.06s/it]
# Processed prompts:  20%|██        | 13/64 [00:57<05:22,  6.32s/it]
# Processed prompts:  22%|██▏       | 14/64 [01:00<04:37,  5.55s/it]
# Processed prompts:  23%|██▎       | 15/64 [01:03<03:48,  4.66s/it]
# Processed prompts:  25%|██▌       | 16/64 [01:07<03:37,  4.53s/it]
# Processed prompts:  27%|██▋       | 17/64 [01:09<02:49,  3.60s/it]
# Processed prompts:  28%|██▊       | 18/64 [01:21<04:52,  6.35s/it]
# Processed prompts:  30%|██▉       | 19/64 [01:26<04:20,  5.80s/it]
# Processed prompts:  31%|███▏      | 20/64 [01:29<03:41,  5.05s/it]
# Processed prompts:  33%|███▎      | 21/64 [01:31<02:57,  4.12s/it]
# Processed prompts:  34%|███▍      | 22/64 [01:40<03:57,  5.65s/it]
# ...
# Processed prompts:  41%|████      | 26/64 [01:35<02:46,  4.38s/it]
# Processed prompts:  42%|████▏     | 27/64 [01:43<03:30,  5.69s/it]
# Processed prompts:  44%|████▍     | 28/64 [02:09<06:59, 11.65s/it]
# Processed prompts:  45%|████▌     | 29/64 [02:18<06:24, 10.99s/it]
# Processed prompts:  47%|████▋     | 30/64 [02:52<10:06, 17.82s/it]
# Processed prompts:  55%|█████▍    | 35/64 [03:07<03:41,  7.65s/it]
# Processed prompts:  56%|█████▋    | 36/64 [03:08<03:05,  6.62s/it]
# Processed prompts:  58%|█████▊    | 37/64 [03:09<02:30,  5.57s/it]
# Processed prompts:  59%|█████▉    | 38/64 [03:12<02:09,  4.98s/it]
# Processed prompts:  61%|██████    | 39/64 [03:16<01:57,  4.69s/it]
# Processed prompts:  62%|██████▎   | 40/64 [03:22<02:05,  5.22s/it]
# Processed prompts:  64%|██████▍   | 41/64 [03:26<01:49,  4.75s/it]
# Processed prompts:  66%|██████▌   | 42/64 [03:27<01:22,  3.76s/it]
# Processed prompts:  67%|██████▋   | 43/64 [03:30<01:14,  3.53s/it]
# Processed prompts:  69%|██████▉   | 44/64 [03:42<01:59,  5.96s/it]
# Processed prompts:  72%|███████▏  | 46/64 [03:45<01:12,  4.05s/it]
# Processed prompts:  73%|███████▎  | 47/64 [03:53<01:22,  4.84s/it]
# Processed prompts:  75%|███████▌  | 48/64 [03:54<01:01,  3.85s/it]
# Processed prompts:  77%|███████▋  | 49/64 [03:54<00:43,  2.90s/it]
# Processed prompts:  78%|███████▊  | 50/64 [03:55<00:33,  2.37s/it]
# Processed prompts:  80%|███████▉  | 51/64 [04:03<00:50,  3.92s/it]
# Processed prompts:  81%|████████▏ | 52/64 [04:03<00:34,  2.92s/it]
# Processed prompts:  83%|████████▎ | 53/64 [04:06<00:32,  2.94s/it]
# Processed prompts:  84%|████████▍ | 54/64 [04:12<00:37,  3.71s/it]
# Processed prompts:  86%|████████▌ | 55/64 [04:12<00:24,  2.75s/it]
# Processed prompts:  88%|████████▊ | 56/64 [04:15<00:21,  2.74s/it]
# Processed prompts:  89%|████████▉ | 57/64 [04:15<00:13,  1.99s/it]
# Processed prompts:  91%|█████████ | 58/64 [04:15<00:08,  1.47s/it]
# Processed prompts:  92%|█████████▏| 59/64 [04:19<00:10,  2.06s/it]
# Processed prompts:  94%|█████████▍| 60/64 [04:28<00:16,  4.04s/it]
# Processed prompts:  95%|█████████▌| 61/64 [04:28<00:09,  3.08s/it]
# Processed prompts:  97%|█████████▋| 62/64 [04:30<00:05,  2.62s/it]
# Processed prompts:  98%|█████████▊| 63/64 [04:48<00:07,  7.34s/it]
# Processed prompts: 100%|██████████| 64/64 [04:59<00:00,  4.69s/it]
#  96%|█████████▌| 96/100 [6:26:21<16:39, 249.82s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# WARNING 10-27 15:16:53 scheduler.py:245] Input prompt (16718315 tokens) is too long and exceeds limit of 4096
# Processed prompts:   2%|▏         | 1/64 [00:09<09:35,  9.14s/it]
# Processed prompts:   3%|▎         | 2/64 [00:11<05:35,  5.41s/it]
# Processed prompts:   5%|▍         | 3/64 [00:13<03:50,  3.78s/it]
# Processed prompts:   6%|▋         | 4/64 [00:15<02:55,  2.92s/it]
# Processed prompts:   8%|▊         | 5/64 [00:18<02:51,  2.91s/it]
# Processed prompts:   9%|▉         | 6/64 [00:19<02:21,  2.44s/it]
# Processed prompts:  11%|█         | 7/64 [00:22<02:27,  2.58s/it]
# Processed prompts:  12%|█▎        | 8/64 [00:23<01:52,  2.02s/it]
# Processed prompts:  14%|█▍        | 9/64 [00:27<02:32,  2.78s/it]
# Processed prompts:  16%|█▌        | 10/64 [00:30<02:33,  2.85s/it]
# Processed prompts:  17%|█▋        | 11/64 [00:46<06:01,  6.82s/it]
# Processed prompts:  19%|█▉        | 12/64 [00:49<04:42,  5.44s/it]
# Processed prompts:  20%|██        | 13/64 [00:59<05:51,  6.90s/it]
# Processed prompts:  22%|██▏       | 14/64 [01:00<04:15,  5.11s/it]
# Processed prompts:  23%|██▎       | 15/64 [01:03<03:42,  4.54s/it]
# Processed prompts:  25%|██▌       | 16/64 [01:14<05:14,  6.55s/it]
# Processed prompts:  27%|██▋       | 17/64 [01:15<03:50,  4.90s/it]
# Processed prompts:  28%|██▊       | 18/64 [01:19<03:30,  4.57s/it]
# Processed prompts:  30%|██▉       | 19/64 [01:23<03:11,  4.26s/it]
# Processed prompts:  31%|███▏      | 20/64 [01:27<03:15,  4.43s/it]
# Processed prompts:  33%|███▎      | 21/64 [01:29<02:29,  3.48s/it]
# Processed prompts:  34%|███▍      | 22/64 [01:31<02:10,  3.10s/it]
# Processed prompts:  36%|███▌      | 23/64 [01:38<02:50,  4.16s/it]
# Processed prompts:  38%|███▊      | 24/64 [01:41<02:39,  3.98s/it]
# Processed prompts:  39%|███▉      | 25/64 [01:43<02:06,  3.24s/it]
# Processed prompts:  41%|████      | 26/64 [01:47<02:10,  3.44s/it]
# Processed prompts:  42%|████▏     | 27/64 [01:50<02:06,  3.41s/it]
# Processed prompts:  44%|████▍     | 28/64 [01:54<02:08,  3.57s/it]
# Processed prompts:  45%|████▌     | 29/64 [01:56<01:50,  3.15s/it]
# Processed prompts:  47%|████▋     | 30/64 [02:04<02:41,  4.74s/it]
# Processed prompts:  48%|████▊     | 31/64 [02:23<04:57,  9.00s/it]
# Processed prompts:  50%|█████     | 32/64 [02:30<04:21,  8.18s/it]
# Processed prompts:  52%|█████▏    | 33/64 [02:34<03:33,  6.88s/it]
# Processed prompts:  53%|█████▎    | 34/64 [02:34<02:32,  5.10s/it]
# Processed prompts:  55%|█████▍    | 35/64 [02:38<02:12,  4.58s/it]
# Processed prompts:  56%|█████▋    | 36/64 [02:39<01:37,  3.47s/it]
# Processed prompts:  58%|█████▊    | 37/64 [02:42<01:36,  3.57s/it]
# Processed prompts:  59%|█████▉    | 38/64 [02:51<02:09,  4.96s/it]
# Processed prompts:  61%|██████    | 39/64 [02:56<02:09,  5.19s/it]
# Processed prompts:  66%|██████▌   | 42/64 [03:16<02:11,  5.97s/it]
# Processed prompts:  67%|██████▋   | 43/64 [03:18<01:48,  5.17s/it]
# Processed prompts:  69%|██████▉   | 44/64 [03:24<01:47,  5.40s/it]
# Processed prompts:  70%|███████   | 45/64 [03:29<01:36,  5.06s/it]
# Processed prompts:  72%|███████▏  | 46/64 [03:30<01:13,  4.07s/it]
# Processed prompts:  73%|███████▎  | 47/64 [03:34<01:08,  4.01s/it]
# Processed prompts:  75%|███████▌  | 48/64 [03:35<00:53,  3.34s/it]
# Processed prompts:  77%|███████▋  | 49/64 [03:36<00:40,  2.72s/it]
# Processed prompts:  78%|███████▊  | 50/64 [03:42<00:48,  3.44s/it]
# Processed prompts:  80%|███████▉  | 51/64 [03:42<00:32,  2.49s/it]
# Processed prompts:  81%|████████▏ | 52/64 [03:43<00:26,  2.17s/it]
# Processed prompts:  83%|████████▎ | 53/64 [03:45<00:22,  2.01s/it]
# Processed prompts:  84%|████████▍ | 54/64 [03:48<00:22,  2.27s/it]
# Processed prompts:  86%|████████▌ | 55/64 [03:48<00:16,  1.78s/it]
# Processed prompts:  88%|████████▊ | 56/64 [03:49<00:11,  1.45s/it]
# Processed prompts:  89%|████████▉ | 57/64 [03:54<00:16,  2.36s/it]
# Processed prompts:  91%|█████████ | 58/64 [03:55<00:12,  2.11s/it]
# Processed prompts:  92%|█████████▏| 59/64 [03:57<00:10,  2.02s/it]
# Processed prompts:  94%|█████████▍| 60/64 [03:59<00:07,  1.93s/it]
# Processed prompts:  95%|█████████▌| 61/64 [03:59<00:04,  1.39s/it]
# Processed prompts:  97%|█████████▋| 62/64 [03:59<00:02,  1.03s/it]
# Processed prompts:  98%|█████████▊| 63/64 [04:05<00:02,  2.58s/it]
# Processed prompts: 100%|██████████| 64/64 [04:12<00:00,  3.94s/it]
#  98%|█████████▊| 98/100 [6:32:40<07:27, 223.99s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# Processed prompts:   2%|▏         | 1/64 [00:13<13:55, 13.26s/it]
# Processed prompts:   3%|▎         | 2/64 [00:17<08:22,  8.10s/it]
# Processed prompts:   5%|▍         | 3/64 [00:18<05:02,  4.96s/it]
# Processed prompts:   6%|▋         | 4/64 [00:25<05:44,  5.74s/it]
# Processed prompts:   8%|▊         | 5/64 [00:28<04:41,  4.78s/it]
# Processed prompts:   9%|▉         | 6/64 [00:40<06:53,  7.13s/it]
# Processed prompts:  11%|█         | 7/64 [00:49<07:14,  7.62s/it]
# Processed prompts:  12%|█▎        | 8/64 [00:53<06:12,  6.66s/it]
# Processed prompts:  14%|█▍        | 9/64 [00:58<05:37,  6.14s/it]
# Processed prompts:  16%|█▌        | 10/64 [01:02<04:41,  5.22s/it]
# Processed prompts:  19%|█▉        | 12/64 [01:07<03:34,  4.13s/it]
# Processed prompts:  20%|██        | 13/64 [01:08<02:44,  3.23s/it]
# Processed prompts:  22%|██▏       | 14/64 [01:09<02:16,  2.73s/it]
# Processed prompts:  23%|██▎       | 15/64 [01:17<03:15,  3.99s/it]
# Processed prompts:  25%|██▌       | 16/64 [01:18<02:39,  3.33s/it]
# Processed prompts:  27%|██▋       | 17/64 [01:21<02:34,  3.30s/it]
# Processed prompts:  28%|██▊       | 18/64 [01:26<02:47,  3.64s/it]
# Processed prompts:  30%|██▉       | 19/64 [01:27<02:16,  3.03s/it]
# Processed prompts:  31%|███▏      | 20/64 [01:30<02:08,  2.91s/it]
# Processed prompts:  33%|███▎      | 21/64 [01:43<04:06,  5.74s/it]
# Processed prompts:  34%|███▍      | 22/64 [01:45<03:24,  4.88s/it]
# Processed prompts:  36%|███▌      | 23/64 [01:47<02:41,  3.94s/it]
# Processed prompts:  38%|███▊      | 24/64 [01:51<02:36,  3.91s/it]
# Processed prompts:  39%|███▉      | 25/64 [02:00<03:36,  5.56s/it]
# Processed prompts:  41%|████      | 26/64 [02:13<04:57,  7.82s/it]
# Processed prompts:  42%|████▏     | 27/64 [02:22<04:53,  7.93s/it]
# Processed prompts:  44%|████▍     | 28/64 [02:27<04:19,  7.21s/it]
# Processed prompts:  45%|████▌     | 29/64 [02:36<04:28,  7.66s/it]
# Processed prompts:  47%|████▋     | 30/64 [02:38<03:24,  6.00s/it]
# Processed prompts:  48%|████▊     | 31/64 [02:43<03:09,  5.73s/it]
# Processed prompts:  50%|█████     | 32/64 [02:47<02:44,  5.15s/it]
# Processed prompts:  52%|█████▏    | 33/64 [02:49<02:10,  4.21s/it]
# Processed prompts:  53%|█████▎    | 34/64 [02:54<02:17,  4.59s/it]
# Processed prompts:  61%|██████    | 39/64 [03:02<01:03,  2.55s/it]
# Processed prompts:  62%|██████▎   | 40/64 [03:03<00:53,  2.22s/it]
# Processed prompts:  64%|██████▍   | 41/64 [03:08<01:04,  2.80s/it]
# Processed prompts:  66%|██████▌   | 42/64 [03:10<00:54,  2.49s/it]
# Processed prompts:  67%|██████▋   | 43/64 [03:13<00:56,  2.67s/it]
# Processed prompts:  69%|██████▉   | 44/64 [03:14<00:47,  2.39s/it]
# Processed prompts:  70%|███████   | 45/64 [03:16<00:43,  2.27s/it]
# Processed prompts:  72%|███████▏  | 46/64 [03:22<00:57,  3.18s/it]
# Processed prompts:  73%|███████▎  | 47/64 [03:38<01:57,  6.91s/it]
# Processed prompts:  75%|███████▌  | 48/64 [03:40<01:24,  5.30s/it]
# Processed prompts:  77%|███████▋  | 49/64 [03:41<01:02,  4.18s/it]
# Processed prompts:  78%|███████▊  | 50/64 [03:42<00:44,  3.15s/it]
# Processed prompts:  81%|████████▏ | 52/64 [03:42<00:21,  1.79s/it]
# Processed prompts:  83%|████████▎ | 53/64 [03:43<00:16,  1.48s/it]
# Processed prompts:  84%|████████▍ | 54/64 [03:44<00:14,  1.45s/it]
# Processed prompts:  86%|████████▌ | 55/64 [03:44<00:09,  1.11s/it]
# Processed prompts:  88%|████████▊ | 56/64 [03:48<00:14,  1.78s/it]
# Processed prompts:  89%|████████▉ | 57/64 [03:49<00:10,  1.52s/it]
# Processed prompts:  91%|█████████ | 58/64 [04:07<00:38,  6.43s/it]
# Processed prompts:  92%|█████████▏| 59/64 [04:10<00:27,  5.42s/it]
# Processed prompts:  94%|█████████▍| 60/64 [04:40<00:50, 12.66s/it]
# Processed prompts:  95%|█████████▌| 61/64 [05:04<00:48, 16.01s/it]
# Processed prompts: 100%|██████████| 64/64 [05:05<00:00,  4.77s/it]
#  99%|█████████▉| 99/100 [6:38:10<04:08, 248.81s/it]
# Processed prompts:   0%|          | 0/64 [00:00<?, ?it/s]
# WARNING 10-27 15:27:03 scheduler.py:245] Input prompt (4365 tokens) is too long and exceeds limit of 4096
# WARNING 10-27 15:27:03 scheduler.py:245] Input prompt (4388 tokens) is too long and exceeds limit of 4096
# Processed prompts:   2%|▏         | 1/64 [00:08<09:02,  8.61s/it]
# Processed prompts:   5%|▍         | 3/64 [00:15<04:43,  4.66s/it]
# Processed prompts:   6%|▋         | 4/64 [00:16<03:25,  3.43s/it]
# Processed prompts:   8%|▊         | 5/64 [00:20<03:41,  3.75s/it]
# Processed prompts:   9%|▉         | 6/64 [00:24<03:31,  3.64s/it]
# Processed prompts:  11%|█         | 7/64 [00:36<05:59,  6.30s/it]
# Processed prompts:  12%|█▎        | 8/64 [00:38<04:42,  5.04s/it]
# Processed prompts:  14%|█▍        | 9/64 [00:38<03:20,  3.64s/it]
# Processed prompts:  16%|█▌        | 10/64 [00:39<02:20,  2.61s/it]
# Processed prompts:  17%|█▋        | 11/64 [00:40<01:55,  2.17s/it]
# Processed prompts:  19%|█▉        | 12/64 [00:41<01:43,  1.98s/it]
# Processed prompts:  20%|██        | 13/64 [00:42<01:16,  1.50s/it]
# Processed prompts:  22%|██▏       | 14/64 [00:43<01:12,  1.44s/it]
# Processed prompts:  23%|██▎       | 15/64 [00:44<01:06,  1.35s/it]
# Processed prompts:  25%|██▌       | 16/64 [00:45<00:58,  1.22s/it]
# Processed prompts:  27%|██▋       | 17/64 [00:46<00:50,  1.06s/it]
# Processed prompts:  28%|██▊       | 18/64 [00:46<00:40,  1.12it/s]
# Processed prompts:  30%|██▉       | 19/64 [00:51<01:29,  2.00s/it]
# Processed prompts:  31%|███▏      | 20/64 [00:52<01:22,  1.88s/it]
# Processed prompts:  33%|███▎      | 21/64 [00:56<01:43,  2.40s/it]
# Processed prompts:  34%|███▍      | 22/64 [00:58<01:37,  2.31s/it]
# Processed prompts:  36%|███▌      | 23/64 [00:59<01:19,  1.95s/it]
# Processed prompts:  38%|███▊      | 24/64 [01:00<01:07,  1.69s/it]
# WARNING 10-27 15:27:56 scheduler.py:245] Input prompt (4161 tokens) is too long and exceeds limit of 4096
# WARNING 10-27 15:27:56 scheduler.py:245] Input prompt (4600 tokens) is too long and exceeds limit of 4096
# Processed prompts:  39%|███▉      | 25/64 [01:02<01:00,  1.56s/it]
# Processed prompts:  42%|████▏     | 27/64 [01:03<00:44,  1.21s/it]
# Processed prompts:  44%|████▍     | 28/64 [01:06<00:56,  1.56s/it]
# Processed prompts:  45%|████▌     | 29/64 [01:20<02:52,  4.94s/it]
# Processed prompts:  47%|████▋     | 30/64 [01:22<02:19,  4.10s/it]
# WARNING 10-27 15:28:19 scheduler.py:245] Input prompt (4185 tokens) is too long and exceeds limit of 4096
# Processed prompts:  48%|████▊     | 31/64 [01:24<01:57,  3.56s/it]
# Processed prompts:  50%|█████     | 32/64 [01:38<03:29,  6.56s/it]
# Processed prompts:  52%|█████▏    | 33/64 [01:40<02:40,  5.19s/it]
# Processed prompts:  53%|█████▎    | 34/64 [01:58<04:25,  8.86s/it]
# Processed prompts:  55%|█████▍    | 35/64 [02:00<03:16,  6.78s/it]
# Processed prompts:  56%|█████▋    | 36/64 [02:04<02:46,  5.95s/it]
# Processed prompts:  58%|█████▊    | 37/64 [02:06<02:07,  4.74s/it]
# Processed prompts:  59%|█████▉    | 38/64 [02:06<01:29,  3.42s/it]
# Processed prompts:  61%|██████    | 39/64 [02:07<01:05,  2.61s/it]
# Processed prompts:  62%|██████▎   | 40/64 [02:19<02:11,  5.47s/it]
# Processed prompts:  64%|██████▍   | 41/64 [02:22<01:46,  4.64s/it]
# Processed prompts:  66%|██████▌   | 42/64 [02:24<01:26,  3.94s/it]
# Processed prompts:  67%|██████▋   | 43/64 [02:27<01:20,  3.85s/it]
# Processed prompts:  69%|██████▉   | 44/64 [02:44<02:32,  7.65s/it]
# Processed prompts:  70%|███████   | 45/64 [02:48<02:03,  6.51s/it]
# Processed prompts:  72%|███████▏  | 46/64 [02:48<01:22,  4.60s/it]
# Processed prompts:  73%|███████▎  | 47/64 [02:48<00:55,  3.29s/it]
# Processed prompts:  75%|███████▌  | 48/64 [02:51<00:49,  3.12s/it]
# Processed prompts:  77%|███████▋  | 49/64 [02:53<00:43,  2.93s/it]
# Processed prompts:  80%|███████▉  | 51/64 [02:55<00:23,  1.82s/it]
# Processed prompts:  81%|████████▏ | 52/64 [02:58<00:27,  2.27s/it]
# Processed prompts:  83%|████████▎ | 53/64 [02:59<00:20,  1.90s/it]
# Processed prompts:  84%|████████▍ | 54/64 [03:00<00:17,  1.74s/it]
# Processed prompts:  86%|████████▌ | 55/64 [03:01<00:13,  1.55s/it]
# Processed prompts:  88%|████████▊ | 56/64 [03:02<00:09,  1.19s/it]
# Processed prompts:  89%|████████▉ | 57/64 [03:29<01:02,  8.89s/it]
# Processed prompts:  91%|█████████ | 58/64 [03:34<00:46,  7.69s/it]
# Processed prompts:  92%|█████████▏| 59/64 [03:56<00:59, 11.96s/it]
# Processed prompts:  94%|█████████▍| 60/64 [04:03<00:41, 10.42s/it]
# Processed prompts:  95%|█████████▌| 61/64 [04:06<00:24,  8.23s/it]
# Processed prompts:  98%|█████████▊| 63/64 [04:07<00:04,  4.67s/it]
# Processed prompts: 100%|██████████| 64/64 [04:16<00:00,  4.00s/it]
# 100%|██████████| 100/100 [6:42:51<00:00, 241.72s/it]
# Processed prompts:   0%|          | 0/44 [00:00<?, ?it/s]
# WARNING 10-27 15:31:42 scheduler.py:245] Input prompt (4548 tokens) is too long and exceeds limit of 4096
# Processed prompts: 100%|██████████| 44/44 [04:02<00:00,  5.50s/it]
# Processed prompts:  43%|████▎     | 9/21 [01:40<02:56, 14.67s/it]
# WARNING 10-27 15:37:38 scheduler.py:245] Input prompt (4243 tokens) is too long and exceeds limit of 4096
# Processed prompts: 100%|██████████| 21/21 [03:12<00:00,  9.15s/it]
# Processed prompts:   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING 10-27 15:39:10 scheduler.py:245] Input prompt (4162 tokens) is too long and exceeds limit of 4096
# Processed prompts: 100%|██████████| 2/2 [00:09<00:00,  4.77s/it]
# CPU times: user 6h 12min 21s, sys: 1min 45s, total: 6h 14min 6s
# Wall time: 6h 50min 35s

# %% [markdown]
# ## Write to submission file

# %%
for id, answer in boxed_answers.items():
    submission.writerow([id, answer])

# %% [markdown]
# ## Close files

# %%
   
file.close()
log_file.close()

# %% [markdown]
# Combined Prompts inference

# %%
# import pandas as pd
# import torch

# # Load the CSV file with problems and prompts
# df = pd.read_csv("pruned_prompts.csv")

# # Specify the ID of the test problem (change as needed)
# test_id = 0  # Example test case ID
# test_problem = df.loc[test_id, 'Problem']
# similar_problems_solutions = df.loc[test_id, 'prompts']  # Get the related problems and solutions
# print(test_problem)

# # Create the prompt for the model
# prompt = f"""Here is a math problem in Bengali:
# {test_problem}. Here is a problem and solution that might or might not help you to solve the problem:{similar_problems_solutions})
# The answer is a non-negative integer. Please reason step by step to solve the problem above. 
# Put your final integer answer within \\boxed{{}}."""

# prompts = [{"role": "system", "content": "You are a helpful math assistant."},{"role": "user", "content": prompt}]

# # Tokenize the input prompt
# tokens = tokenizer.apply_chat_template(
#             prompts,
#             tokenize=False,
#             add_generation_prompt=True
#         )

# # Generate the solution using the model
# generated_solution = llm.generate(tokens,sampling_params)

# # Output the generated solution
# print(f"Generated solution for test problem {test_id}:")
# print(generated_solution[0].outputs[0].text)

# %%
# import pandas as pd

# # Load the CSV file
# df = pd.read_csv("pruned_prompts.csv")

# # Define a function to prune the 5th problem and its solution from each 'prompts' entry
# def prune_fifth_problem(prompts_text):
#     # Split the prompts into individual problems/solutions
#     problems = prompts_text.split("Problem:")
    
#     # Check if there are at least 5 problems
#     if len(problems) > 2:
#         # Remove the 5th problem (index 5 is actually the 6th element, as index starts from 0)
#         del problems[2]
        
#     # Rejoin the remaining problems and solutions
#     return "Problem:".join(problems)

# # Apply the function to the 'prompts' column
# df['prompts'] = df['prompts'].apply(prune_fifth_problem)

# # Now the 'pruned_prompts' column contains the updated text with the 5th problem removed
# print(df[['ID', 'prompts']].head())  # Display the updated prompts for the first few rows

# # You can save the updated DataFrame to a new CSV if needed
# # df.to_csv("pruned_prompts.csv", index=False)

# %%
# df.to_csv("pruned_prompts.csv", index=False)

# %%
# df['prompts'] = df['prompts'].str.replace("Here are a list of math problems and solutions:", "", regex=False)

# # Display the updated DataFrame to confirm the string has been removed
# print(df.head())

# %%
# df.to_csv("pruned_prompts.csv", index=False)
